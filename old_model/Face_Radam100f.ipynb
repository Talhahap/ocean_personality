# %%
import tensorflow as tf 
from tensorflow import keras 
import tensorflow_addons as tfa
import tensorflow_hub as hub 
from sklearn.metrics import mean_absolute_error 
import numpy as np 
import datetime
from deepface import DeepFace
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, PReLU
import os
import warnings

# Ignore irrelevant warning messages for cleaner output
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//train_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//val_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds, valid_ds
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>)

# %% [markdown]
# Load Arcface

# %%
from models import create_arcface_model

# Load dengan weights (default)
arcface_112 = create_arcface_model(load_weights=True)
arcface_112.trainable = False

arcface_112.summary()
# Out:
# ✓ Successfully loaded weights from C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//arcface_weights.h5
# Model: "ArcFace"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 112, 112, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 114, 114, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         1728      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_prelu (PReLU)         (None, 112, 112, 64)         64        ['conv1_bn[0][0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 112, 112, 64)         256       ['conv1_prelu[0][0]']
#  rmalization)
#
#  conv2_block1_1_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_bn[0][0]']
#  dding2D)
#
#  conv2_block1_1_conv (Conv2  (None, 112, 112, 64)         36864     ['conv2_block1_1_pad[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 112, 112, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_prelu (PReL  (None, 112, 112, 64)         64        ['conv2_block1_2_bn[0][0]']
#  U)
#
#  conv2_block1_2_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 64)           4096      ['conv1_prelu[0][0]']
#  D)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_add[0][0]']
#  rmalization)
#
#  conv2_block2_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_bn[0][0]']
#  dding2D)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_1_pad[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block2_2_bn[0][0]']
#  U)
#
#  conv2_block2_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_add[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_add[0][0]']
#  rmalization)
#
#  conv2_block3_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_bn[0][0]']
#  dding2D)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_1_pad[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block3_2_bn[0][0]']
#  U)
#
#  conv2_block3_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_2_pad[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 64)           0         ['conv2_block2_add[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_add[0][0]']
#  rmalization)
#
#  conv3_block1_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv3_block1_1_bn[0][0]']
#  dding2D)
#
#  conv3_block1_1_conv (Conv2  (None, 56, 56, 128)          73728     ['conv3_block1_1_pad[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 56, 56, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_prelu (PReL  (None, 56, 56, 128)          128       ['conv3_block1_2_bn[0][0]']
#  U)
#
#  conv3_block1_2_pad (ZeroPa  (None, 58, 58, 128)          0         ['conv3_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 128)          8192      ['conv2_block3_add[0][0]']
#  D)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_add[0][0]']
#  rmalization)
#
#  conv3_block2_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_bn[0][0]']
#  dding2D)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_1_pad[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block2_2_bn[0][0]']
#  U)
#
#  conv3_block2_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_add[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_add[0][0]']
#  rmalization)
#
#  conv3_block3_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_bn[0][0]']
#  dding2D)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_1_pad[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block3_2_bn[0][0]']
#  U)
#
#  conv3_block3_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 128)          0         ['conv3_block2_add[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_add[0][0]']
#  rmalization)
#
#  conv3_block4_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_bn[0][0]']
#  dding2D)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_1_pad[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block4_2_bn[0][0]']
#  U)
#
#  conv3_block4_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_2_pad[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 128)          0         ['conv3_block3_add[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_add[0][0]']
#  rmalization)
#
#  conv4_block1_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv4_block1_1_bn[0][0]']
#  dding2D)
#
#  conv4_block1_1_conv (Conv2  (None, 28, 28, 256)          294912    ['conv4_block1_1_pad[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_prelu (PReL  (None, 28, 28, 256)          256       ['conv4_block1_2_bn[0][0]']
#  U)
#
#  conv4_block1_2_pad (ZeroPa  (None, 30, 30, 256)          0         ['conv4_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 256)          32768     ['conv3_block4_add[0][0]']
#  D)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block1_2_pad[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_add[0][0]']
#  rmalization)
#
#  conv4_block2_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  dding2D)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_1_pad[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block2_2_bn[0][0]']
#  U)
#
#  conv4_block2_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_2_pad[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_add[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_add[0][0]']
#  rmalization)
#
#  conv4_block3_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  dding2D)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_1_pad[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block3_2_bn[0][0]']
#  U)
#
#  conv4_block3_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_2_pad[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 256)          0         ['conv4_block2_add[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_add[0][0]']
#  rmalization)
#
#  conv4_block4_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  dding2D)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_1_pad[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block4_2_bn[0][0]']
#  U)
#
#  conv4_block4_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_2_pad[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 256)          0         ['conv4_block3_add[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_add[0][0]']
#  rmalization)
#
#  conv4_block5_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_bn[0][0]']
#  dding2D)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_1_pad[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block5_2_bn[0][0]']
#  U)
#
#  conv4_block5_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_2_pad[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 256)          0         ['conv4_block4_add[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_add[0][0]']
#  rmalization)
#
#  conv4_block6_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_bn[0][0]']
#  dding2D)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_1_pad[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block6_2_bn[0][0]']
#  U)
#
#  conv4_block6_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_2_pad[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 256)          0         ['conv4_block5_add[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv5_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_add[0][0]']
#  rmalization)
#
#  conv5_block1_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv5_block1_1_bn[0][0]']
#  dding2D)
#
#  conv5_block1_1_conv (Conv2  (None, 14, 14, 512)          1179648   ['conv5_block1_1_pad[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 14, 14, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_prelu (PReL  (None, 14, 14, 512)          512       ['conv5_block1_2_bn[0][0]']
#  U)
#
#  conv5_block1_2_pad (ZeroPa  (None, 16, 16, 512)          0         ['conv5_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 512)            131072    ['conv4_block6_add[0][0]']
#  D)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block1_2_pad[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_add[0][0]']
#  rmalization)
#
#  conv5_block2_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_bn[0][0]']
#  dding2D)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_1_pad[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block2_2_bn[0][0]']
#  U)
#
#  conv5_block2_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_2_pad[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_add[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_add[0][0]']
#  rmalization)
#
#  conv5_block3_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_bn[0][0]']
#  dding2D)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_1_pad[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block3_2_bn[0][0]']
#  U)
#
#  conv5_block3_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_2_pad[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 512)            0         ['conv5_block2_add[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  batch_normalization (Batch  (None, 7, 7, 512)            2048      ['conv5_block3_add[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 7, 7, 512)            0         ['batch_normalization[0][0]']
#
#  flatten (Flatten)           (None, 25088)                0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 512)                  1284556   ['flatten[0][0]']
#                                                           8
#
#  embedding (BatchNormalizat  (None, 512)                  2048      ['dense[0][0]']
#  ion)
#
#  norm_layer (Lambda)         (None, 512)                  0         ['embedding[0][0]']
#
# ==================================================================================================
# Total params: 34165184 (130.33 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 34165184 (130.33 MB)
# __________________________________________________________________________________________________

# %%
from models import create_arcface_model
from tensorflow.keras import regularizers

# Load ArcFace model
arcface_112 = create_arcface_model()
arcface_112.trainable = False

# Build model dengan TimeDistributed untuk sequence input
inputs = keras.layers.Input(shape=(10, 112, 112, 3), name='Input')

# Preprocessing
x = keras.layers.TimeDistributed(keras.layers.Rescaling(scale=1./255.0), name='Rescaling')(inputs)

# ArcFace feature extractor (tetap dibekukan)
x = keras.layers.TimeDistributed(arcface_112, name='arcface')(x)

# LSTM layers
x = keras.layers.LSTM(units=128, return_sequences=True)(x)
x = keras.layers.LSTM(units=64)(x)

# Dense + Dropout + Regularization
x = keras.layers.Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.5)(x)

# Output
x = keras.layers.Dense(5, activation='sigmoid')(x)

# Build model
model = keras.models.Model(inputs=inputs, outputs=x)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ✓ Successfully loaded weights from C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//arcface_weights.h5

# %%
t = datetime.datetime.now().strftime("%m%d_%H%M%S")

# optimizer = keras.optimizers.Adam(learning_rate=0.001)
# optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
optimizer = tfa.optimizers.RectifiedAdam(learning_rate=0.0001)
# optimizer = keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)


early_stopping = keras.callbacks.EarlyStopping(patience=10, verbose=1)
check_point    = keras.callbacks.ModelCheckpoint(filepath='./weights/faces/'+str(t)+'/face.t5',
                            monitor='val_mae',
                            mode='min',
                            save_best_only=True,
                            save_weights_only=True,
                            verbose=1)

model.compile(loss='mse', optimizer=optimizer, metrics=['mae'])

# %%
history = model.fit(train_ds, validation_data=valid_ds, batch_size=8, epochs=100, callbacks=[early_stopping, check_point])
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 11.6852 - mae: 0.5020
# Epoch 1: val_mae improved from inf to 0.50130, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 38s 4s/step - loss: 11.6852 - mae: 0.5020 - val_loss: 11.6801 - val_mae: 0.5013
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 11.6718 - mae: 0.5018
# Epoch 2: val_mae improved from 0.50130 to 0.50115, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 11.6718 - mae: 0.5018 - val_loss: 11.6568 - val_mae: 0.5012
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 11.6427 - mae: 0.5017
# Epoch 3: val_mae improved from 0.50115 to 0.50094, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 11.6427 - mae: 0.5017 - val_loss: 11.6229 - val_mae: 0.5009
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 11.6069 - mae: 0.5013
# Epoch 4: val_mae improved from 0.50094 to 0.50068, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 11.6069 - mae: 0.5013 - val_loss: 11.5811 - val_mae: 0.5007
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 11.5610 - mae: 0.5010
# Epoch 5: val_mae improved from 0.50068 to 0.50039, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 11.5610 - mae: 0.5010 - val_loss: 11.5327 - val_mae: 0.5004
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 11.5097 - mae: 0.5007
# Epoch 6: val_mae improved from 0.50039 to 0.50008, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 11.5097 - mae: 0.5007 - val_loss: 11.4786 - val_mae: 0.5001
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 11.4542 - mae: 0.5002
# Epoch 7: val_mae improved from 0.50008 to 0.49975, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 11.4542 - mae: 0.5002 - val_loss: 11.4196 - val_mae: 0.4997
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 11.3935 - mae: 0.5001
# Epoch 8: val_mae improved from 0.49975 to 0.49940, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 11.3935 - mae: 0.5001 - val_loss: 11.3562 - val_mae: 0.4994
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 11.3257 - mae: 0.4994
# Epoch 9: val_mae improved from 0.49940 to 0.49902, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 11.3257 - mae: 0.4994 - val_loss: 11.2886 - val_mae: 0.4990
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 11.2602 - mae: 0.4992
# Epoch 10: val_mae improved from 0.49902 to 0.49862, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 11.2602 - mae: 0.4992 - val_loss: 11.2174 - val_mae: 0.4986
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 11.1839 - mae: 0.4987
# Epoch 11: val_mae improved from 0.49862 to 0.49819, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 27s 3s/step - loss: 11.1839 - mae: 0.4987 - val_loss: 11.1429 - val_mae: 0.4982
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 11.1092 - mae: 0.4984
# Epoch 12: val_mae improved from 0.49819 to 0.49775, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 11.1092 - mae: 0.4984 - val_loss: 11.0652 - val_mae: 0.4977
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 11.0281 - mae: 0.4978
# Epoch 13: val_mae improved from 0.49775 to 0.49729, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 4s/step - loss: 11.0281 - mae: 0.4978 - val_loss: 10.9847 - val_mae: 0.4973
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 10.9487 - mae: 0.4976
# Epoch 14: val_mae improved from 0.49729 to 0.49681, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 10.9487 - mae: 0.4976 - val_loss: 10.9015 - val_mae: 0.4968
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 10.8651 - mae: 0.4972
# Epoch 15: val_mae improved from 0.49681 to 0.49631, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 10.8651 - mae: 0.4972 - val_loss: 10.8159 - val_mae: 0.4963
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 10.7776 - mae: 0.4965
# Epoch 16: val_mae improved from 0.49631 to 0.49578, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 10.7776 - mae: 0.4965 - val_loss: 10.7280 - val_mae: 0.4958
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 10.6879 - mae: 0.4958
# Epoch 17: val_mae improved from 0.49578 to 0.49522, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 10.6879 - mae: 0.4958 - val_loss: 10.6380 - val_mae: 0.4952
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 10.5962 - mae: 0.4951
# Epoch 18: val_mae improved from 0.49522 to 0.49461, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 10.5962 - mae: 0.4951 - val_loss: 10.5461 - val_mae: 0.4946
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 10.5057 - mae: 0.4945
# Epoch 19: val_mae improved from 0.49461 to 0.49394, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 27s 3s/step - loss: 10.5057 - mae: 0.4945 - val_loss: 10.4523 - val_mae: 0.4939
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 10.4082 - mae: 0.4939
# Epoch 20: val_mae improved from 0.49394 to 0.49322, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 10.4082 - mae: 0.4939 - val_loss: 10.3569 - val_mae: 0.4932
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 10.3145 - mae: 0.4932
# Epoch 21: val_mae improved from 0.49322 to 0.49245, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 10.3145 - mae: 0.4932 - val_loss: 10.2599 - val_mae: 0.4925
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 10.2169 - mae: 0.4925
# Epoch 22: val_mae improved from 0.49245 to 0.49162, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 10.2169 - mae: 0.4925 - val_loss: 10.1614 - val_mae: 0.4916
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 10.1193 - mae: 0.4914
# Epoch 23: val_mae improved from 0.49162 to 0.49072, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 10.1193 - mae: 0.4914 - val_loss: 10.0617 - val_mae: 0.4907
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 10.0201 - mae: 0.4907
# Epoch 24: val_mae improved from 0.49072 to 0.48975, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 10.0201 - mae: 0.4907 - val_loss: 9.9607 - val_mae: 0.4897
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 9.9165 - mae: 0.4900
# Epoch 25: val_mae improved from 0.48975 to 0.48870, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 9.9165 - mae: 0.4900 - val_loss: 9.8587 - val_mae: 0.4887
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 9.8136 - mae: 0.4886
# Epoch 26: val_mae improved from 0.48870 to 0.48758, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 9.8136 - mae: 0.4886 - val_loss: 9.7556 - val_mae: 0.4876
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 9.7092 - mae: 0.4874
# Epoch 27: val_mae improved from 0.48758 to 0.48635, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 9.7092 - mae: 0.4874 - val_loss: 9.6515 - val_mae: 0.4864
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 9.6066 - mae: 0.4862
# Epoch 28: val_mae improved from 0.48635 to 0.48501, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 9.6066 - mae: 0.4862 - val_loss: 9.5466 - val_mae: 0.4850
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 9.5005 - mae: 0.4848
# Epoch 29: val_mae improved from 0.48501 to 0.48350, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 9.5005 - mae: 0.4848 - val_loss: 9.4409 - val_mae: 0.4835
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 9.3975 - mae: 0.4837
# Epoch 30: val_mae improved from 0.48350 to 0.48180, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 9.3975 - mae: 0.4837 - val_loss: 9.3345 - val_mae: 0.4818
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 9.2886 - mae: 0.4815
# Epoch 31: val_mae improved from 0.48180 to 0.47992, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 9.2886 - mae: 0.4815 - val_loss: 9.2273 - val_mae: 0.4799
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 9.1814 - mae: 0.4797
# Epoch 32: val_mae improved from 0.47992 to 0.47770, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 9.1814 - mae: 0.4797 - val_loss: 9.1195 - val_mae: 0.4777
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 9.0740 - mae: 0.4772
# Epoch 33: val_mae improved from 0.47770 to 0.47508, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 9.0740 - mae: 0.4772 - val_loss: 9.0109 - val_mae: 0.4751
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 8.9627 - mae: 0.4746
# Epoch 34: val_mae improved from 0.47508 to 0.47188, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 8.9627 - mae: 0.4746 - val_loss: 8.9016 - val_mae: 0.4719
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 8.8585 - mae: 0.4722
# Epoch 35: val_mae improved from 0.47188 to 0.46794, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 8.8585 - mae: 0.4722 - val_loss: 8.7915 - val_mae: 0.4679
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 8.7476 - mae: 0.4674
# Epoch 36: val_mae improved from 0.46794 to 0.46287, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 8.7476 - mae: 0.4674 - val_loss: 8.6803 - val_mae: 0.4629
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 8.6296 - mae: 0.4607
# Epoch 37: val_mae improved from 0.46287 to 0.45602, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 8.6296 - mae: 0.4607 - val_loss: 8.5675 - val_mae: 0.4560
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 8.5185 - mae: 0.4545
# Epoch 38: val_mae improved from 0.45602 to 0.44585, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 8.5185 - mae: 0.4545 - val_loss: 8.4522 - val_mae: 0.4458
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 8.4003 - mae: 0.4416
# Epoch 39: val_mae improved from 0.44585 to 0.43112, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 8.4003 - mae: 0.4416 - val_loss: 8.3334 - val_mae: 0.4311
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 8.2777 - mae: 0.4229
# Epoch 40: val_mae improved from 0.43112 to 0.40772, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 4s/step - loss: 8.2777 - mae: 0.4229 - val_loss: 8.2086 - val_mae: 0.4077
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 8.1585 - mae: 0.3974
# Epoch 41: val_mae improved from 0.40772 to 0.37056, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 8.1585 - mae: 0.3974 - val_loss: 8.0755 - val_mae: 0.3706
# Epoch 42/100
# 8/8 [==============================] - ETA: 0s - loss: 8.0223 - mae: 0.3538
# Epoch 42: val_mae improved from 0.37056 to 0.31608, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 8.0223 - mae: 0.3538 - val_loss: 7.9351 - val_mae: 0.3161
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 7.8852 - mae: 0.3008
# Epoch 43: val_mae improved from 0.31608 to 0.24705, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 7.8852 - mae: 0.3008 - val_loss: 7.7936 - val_mae: 0.2471
# Epoch 44/100
# 8/8 [==============================] - ETA: 0s - loss: 7.7436 - mae: 0.2289
# Epoch 44: val_mae improved from 0.24705 to 0.17622, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 7.7436 - mae: 0.2289 - val_loss: 7.6606 - val_mae: 0.1762
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 7.6137 - mae: 0.1649
# Epoch 45: val_mae improved from 0.17622 to 0.12056, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 7.6137 - mae: 0.1649 - val_loss: 7.5403 - val_mae: 0.1206
# Epoch 46/100
# 8/8 [==============================] - ETA: 0s - loss: 7.4989 - mae: 0.1196
# Epoch 46: val_mae improved from 0.12056 to 0.08408, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 7.4989 - mae: 0.1196 - val_loss: 7.4287 - val_mae: 0.0841
# Epoch 47/100
# 8/8 [==============================] - ETA: 0s - loss: 7.3850 - mae: 0.0951
# Epoch 47: val_mae improved from 0.08408 to 0.06276, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 7.3850 - mae: 0.0951 - val_loss: 7.3214 - val_mae: 0.0628
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 7.2764 - mae: 0.0686
# Epoch 48: val_mae improved from 0.06276 to 0.05087, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 7.2764 - mae: 0.0686 - val_loss: 7.2157 - val_mae: 0.0509
# Epoch 49/100
# 8/8 [==============================] - ETA: 0s - loss: 7.1705 - mae: 0.0579
# Epoch 49: val_mae improved from 0.05087 to 0.04464, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 7.1705 - mae: 0.0579 - val_loss: 7.1108 - val_mae: 0.0446
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 7.0653 - mae: 0.0552
# Epoch 50: val_mae improved from 0.04464 to 0.04122, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 7.0653 - mae: 0.0552 - val_loss: 7.0064 - val_mae: 0.0412
# Epoch 51/100
# 8/8 [==============================] - ETA: 0s - loss: 6.9610 - mae: 0.0554
# Epoch 51: val_mae improved from 0.04122 to 0.03907, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 6.9610 - mae: 0.0554 - val_loss: 6.9025 - val_mae: 0.0391
# Epoch 52/100
# 8/8 [==============================] - ETA: 0s - loss: 6.8620 - mae: 0.0493
# Epoch 52: val_mae improved from 0.03907 to 0.03778, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 6.8620 - mae: 0.0493 - val_loss: 6.7992 - val_mae: 0.0378
# Epoch 53/100
# 8/8 [==============================] - ETA: 0s - loss: 6.7546 - mae: 0.0543
# Epoch 53: val_mae improved from 0.03778 to 0.03661, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 6.7546 - mae: 0.0543 - val_loss: 6.6964 - val_mae: 0.0366
# Epoch 54/100
# 8/8 [==============================] - ETA: 0s - loss: 6.6569 - mae: 0.0475
# Epoch 54: val_mae improved from 0.03661 to 0.03590, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 6.6569 - mae: 0.0475 - val_loss: 6.5942 - val_mae: 0.0359
# Epoch 55/100
# 8/8 [==============================] - ETA: 0s - loss: 6.5526 - mae: 0.0484
# Epoch 55: val_mae improved from 0.03590 to 0.03559, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 6.5526 - mae: 0.0484 - val_loss: 6.4927 - val_mae: 0.0356
# Epoch 56/100
# 8/8 [==============================] - ETA: 0s - loss: 6.4506 - mae: 0.0522
# Epoch 56: val_mae improved from 0.03559 to 0.03502, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 6.4506 - mae: 0.0522 - val_loss: 6.3918 - val_mae: 0.0350
# Epoch 57/100
# 8/8 [==============================] - ETA: 0s - loss: 6.3515 - mae: 0.0537
# Epoch 57: val_mae improved from 0.03502 to 0.03440, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 6.3515 - mae: 0.0537 - val_loss: 6.2916 - val_mae: 0.0344
# Epoch 58/100
# 8/8 [==============================] - ETA: 0s - loss: 6.2493 - mae: 0.0469
# Epoch 58: val_mae improved from 0.03440 to 0.03397, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 6.2493 - mae: 0.0469 - val_loss: 6.1921 - val_mae: 0.0340
# Epoch 59/100
# 8/8 [==============================] - ETA: 0s - loss: 6.1541 - mae: 0.0513
# Epoch 59: val_mae improved from 0.03397 to 0.03378, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 6.1541 - mae: 0.0513 - val_loss: 6.0933 - val_mae: 0.0338
# Epoch 60/100
# 8/8 [==============================] - ETA: 0s - loss: 6.0497 - mae: 0.0449
# Epoch 60: val_mae improved from 0.03378 to 0.03362, saving model to ./weights/faces/1019_221314\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 6.0497 - mae: 0.0449 - val_loss: 5.9953 - val_mae: 0.0336
# Epoch 61/100
# 8/8 [==============================] - ETA: 0s - loss: 5.9519 - mae: 0.0456
# Epoch 61: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 5.9519 - mae: 0.0456 - val_loss: 5.8980 - val_mae: 0.0340
# Epoch 62/100
# 8/8 [==============================] - ETA: 0s - loss: 5.8591 - mae: 0.0508
# Epoch 62: val_mae did not improve from 0.03362
# 8/8 [==============================] - 23s 3s/step - loss: 5.8591 - mae: 0.0508 - val_loss: 5.8015 - val_mae: 0.0341
# Epoch 63/100
# 8/8 [==============================] - ETA: 0s - loss: 5.7605 - mae: 0.0455
# Epoch 63: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 5.7605 - mae: 0.0455 - val_loss: 5.7058 - val_mae: 0.0342
# Epoch 64/100
# 8/8 [==============================] - ETA: 0s - loss: 5.6647 - mae: 0.0422
# Epoch 64: val_mae did not improve from 0.03362
# 8/8 [==============================] - 23s 3s/step - loss: 5.6647 - mae: 0.0422 - val_loss: 5.6109 - val_mae: 0.0350
# Epoch 65/100
# 8/8 [==============================] - ETA: 0s - loss: 5.5717 - mae: 0.0581
# Epoch 65: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 5.5717 - mae: 0.0581 - val_loss: 5.5169 - val_mae: 0.0347
# Epoch 66/100
# 8/8 [==============================] - ETA: 0s - loss: 5.4787 - mae: 0.0484
# Epoch 66: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 5.4787 - mae: 0.0484 - val_loss: 5.4237 - val_mae: 0.0344
# Epoch 67/100
# 8/8 [==============================] - ETA: 0s - loss: 5.3872 - mae: 0.0400
# Epoch 67: val_mae did not improve from 0.03362
# 8/8 [==============================] - 23s 3s/step - loss: 5.3872 - mae: 0.0400 - val_loss: 5.3314 - val_mae: 0.0347
# Epoch 68/100
# 8/8 [==============================] - ETA: 0s - loss: 5.2911 - mae: 0.0499
# Epoch 68: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 5.2911 - mae: 0.0499 - val_loss: 5.2399 - val_mae: 0.0352
# Epoch 69/100
# 8/8 [==============================] - ETA: 0s - loss: 5.2039 - mae: 0.0533
# Epoch 69: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 5.2039 - mae: 0.0533 - val_loss: 5.1494 - val_mae: 0.0350
# Epoch 70/100
# 8/8 [==============================] - ETA: 0s - loss: 5.1103 - mae: 0.0511
# Epoch 70: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 5.1103 - mae: 0.0511 - val_loss: 5.0598 - val_mae: 0.0343
# Epoch 71/100
# 8/8 [==============================] - ETA: 0s - loss: 5.0213 - mae: 0.0426
# Epoch 71: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 5.0213 - mae: 0.0426 - val_loss: 4.9710 - val_mae: 0.0344
# Epoch 72/100
# 8/8 [==============================] - ETA: 0s - loss: 4.9354 - mae: 0.0453
# Epoch 72: val_mae did not improve from 0.03362
# 8/8 [==============================] - 23s 3s/step - loss: 4.9354 - mae: 0.0453 - val_loss: 4.8831 - val_mae: 0.0352
# Epoch 73/100
# 8/8 [==============================] - ETA: 0s - loss: 4.8470 - mae: 0.0450
# Epoch 73: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 4.8470 - mae: 0.0450 - val_loss: 4.7962 - val_mae: 0.0358
# Epoch 74/100
# 8/8 [==============================] - ETA: 0s - loss: 4.7602 - mae: 0.0475
# Epoch 74: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 4.7602 - mae: 0.0475 - val_loss: 4.7102 - val_mae: 0.0363
# Epoch 75/100
# 8/8 [==============================] - ETA: 0s - loss: 4.6755 - mae: 0.0488
# Epoch 75: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 4.6755 - mae: 0.0488 - val_loss: 4.6252 - val_mae: 0.0366
# Epoch 76/100
# 8/8 [==============================] - ETA: 0s - loss: 4.5913 - mae: 0.0515
# Epoch 76: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 4.5913 - mae: 0.0515 - val_loss: 4.5411 - val_mae: 0.0365
# Epoch 77/100
# 8/8 [==============================] - ETA: 0s - loss: 4.5057 - mae: 0.0516
# Epoch 77: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 4.5057 - mae: 0.0516 - val_loss: 4.4581 - val_mae: 0.0363
# Epoch 78/100
# 8/8 [==============================] - ETA: 0s - loss: 4.4217 - mae: 0.0447
# Epoch 78: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 4.4217 - mae: 0.0447 - val_loss: 4.3759 - val_mae: 0.0365
# Epoch 79/100
# 8/8 [==============================] - ETA: 0s - loss: 4.3441 - mae: 0.0479
# Epoch 79: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 4.3441 - mae: 0.0479 - val_loss: 4.2947 - val_mae: 0.0369
# Epoch 80/100
# 8/8 [==============================] - ETA: 0s - loss: 4.2602 - mae: 0.0491
# Epoch 80: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 4.2602 - mae: 0.0491 - val_loss: 4.2145 - val_mae: 0.0369
# Epoch 81/100
# 8/8 [==============================] - ETA: 0s - loss: 4.1825 - mae: 0.0502
# Epoch 81: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 4.1825 - mae: 0.0502 - val_loss: 4.1353 - val_mae: 0.0369
# Epoch 82/100
# 8/8 [==============================] - ETA: 0s - loss: 4.1044 - mae: 0.0500
# Epoch 82: val_mae did not improve from 0.03362
# 8/8 [==============================] - 23s 3s/step - loss: 4.1044 - mae: 0.0500 - val_loss: 4.0570 - val_mae: 0.0366
# Epoch 83/100
# 8/8 [==============================] - ETA: 0s - loss: 4.0264 - mae: 0.0506
# Epoch 83: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 4.0264 - mae: 0.0506 - val_loss: 3.9798 - val_mae: 0.0365
# Epoch 84/100
# 8/8 [==============================] - ETA: 0s - loss: 3.9489 - mae: 0.0487
# Epoch 84: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 3.9489 - mae: 0.0487 - val_loss: 3.9035 - val_mae: 0.0365
# Epoch 85/100
# 8/8 [==============================] - ETA: 0s - loss: 3.8718 - mae: 0.0466
# Epoch 85: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 3.8718 - mae: 0.0466 - val_loss: 3.8282 - val_mae: 0.0367
# Epoch 86/100
# 8/8 [==============================] - ETA: 0s - loss: 3.7955 - mae: 0.0474
# Epoch 86: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 3.7955 - mae: 0.0474 - val_loss: 3.7539 - val_mae: 0.0368
# Epoch 87/100
# 8/8 [==============================] - ETA: 0s - loss: 3.7236 - mae: 0.0504
# Epoch 87: val_mae did not improve from 0.03362
# 8/8 [==============================] - 23s 3s/step - loss: 3.7236 - mae: 0.0504 - val_loss: 3.6805 - val_mae: 0.0372
# Epoch 88/100
# 8/8 [==============================] - ETA: 0s - loss: 3.6503 - mae: 0.0462
# Epoch 88: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 3.6503 - mae: 0.0462 - val_loss: 3.6081 - val_mae: 0.0378
# Epoch 89/100
# 8/8 [==============================] - ETA: 0s - loss: 3.5768 - mae: 0.0464
# Epoch 89: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 3.5768 - mae: 0.0464 - val_loss: 3.5367 - val_mae: 0.0384
# Epoch 90/100
# 8/8 [==============================] - ETA: 0s - loss: 3.5068 - mae: 0.0485
# Epoch 90: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 3.5068 - mae: 0.0485 - val_loss: 3.4663 - val_mae: 0.0388
# Epoch 91/100
# 8/8 [==============================] - ETA: 0s - loss: 3.4391 - mae: 0.0570
# Epoch 91: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 3.4391 - mae: 0.0570 - val_loss: 3.3969 - val_mae: 0.0385
# Epoch 92/100
# 8/8 [==============================] - ETA: 0s - loss: 3.3708 - mae: 0.0517
# Epoch 92: val_mae did not improve from 0.03362
# 8/8 [==============================] - 23s 3s/step - loss: 3.3708 - mae: 0.0517 - val_loss: 3.3285 - val_mae: 0.0375
# Epoch 93/100
# 8/8 [==============================] - ETA: 0s - loss: 3.3016 - mae: 0.0510
# Epoch 93: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 3.3016 - mae: 0.0510 - val_loss: 3.2611 - val_mae: 0.0371
# Epoch 94/100
# 8/8 [==============================] - ETA: 0s - loss: 3.2331 - mae: 0.0458
# Epoch 94: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 3.2331 - mae: 0.0458 - val_loss: 3.1946 - val_mae: 0.0373
# Epoch 95/100
# 8/8 [==============================] - ETA: 0s - loss: 3.1696 - mae: 0.0496
# Epoch 95: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 3.1696 - mae: 0.0496 - val_loss: 3.1291 - val_mae: 0.0378
# Epoch 96/100
# 8/8 [==============================] - ETA: 0s - loss: 3.1052 - mae: 0.0524
# Epoch 96: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 3.1052 - mae: 0.0524 - val_loss: 3.0646 - val_mae: 0.0374
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 3.0385 - mae: 0.0474
# Epoch 97: val_mae did not improve from 0.03362
# 8/8 [==============================] - 23s 3s/step - loss: 3.0385 - mae: 0.0474 - val_loss: 3.0010 - val_mae: 0.0374
# Epoch 98/100
# 8/8 [==============================] - ETA: 0s - loss: 2.9748 - mae: 0.0464
# Epoch 98: val_mae did not improve from 0.03362
# 8/8 [==============================] - 25s 3s/step - loss: 2.9748 - mae: 0.0464 - val_loss: 2.9384 - val_mae: 0.0377
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 2.9127 - mae: 0.0504
# Epoch 99: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 2.9127 - mae: 0.0504 - val_loss: 2.8767 - val_mae: 0.0377
# Epoch 100/100
# 8/8 [==============================] - ETA: 0s - loss: 2.8516 - mae: 0.0434
# Epoch 100: val_mae did not improve from 0.03362
# 8/8 [==============================] - 24s 3s/step - loss: 2.8516 - mae: 0.0434 - val_loss: 2.8160 - val_mae: 0.0383

# %% [markdown]
# ### Load weights

# %%
model.load_weights('./weights/faces/1019_221314/face.t5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training data

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//train_ds') 
loss, mae = model.evaluate(train_ds)
(1-mae)*100
# Out:
# 8/8 [==============================] - 15s 2s/step - loss: 5.9953 - mae: 0.0335
# 96.6451358050108

# %%
y_true = np.concatenate([y for x,y in train_ds])
y_pred = model.predict(train_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 8/8 [==============================] - 17s 2s/step
# (array([98.23269 , 95.71194 , 96.43709 , 96.51657 , 96.327385],
#        dtype=float32),
#  96.64513543248177)

# %% [markdown]
# ### Validation data

# %%
valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//val_ds') 
loss, mae = model.evaluate(valid_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 5.9953 - mae: 0.0336
# 96.63818404078484

# %%
y_true = np.concatenate([y for x,y in valid_ds])
y_pred = model.predict(valid_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 5s 2s/step
# (array([98.231186, 95.70309 , 96.42984 , 96.50888 , 96.31793 ],
#        dtype=float32),
#  96.63818404078484)

# %% [markdown]
# ### Test data

# %%
test_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//test_ds')
loss, mae = model.evaluate(test_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 5.9954 - mae: 0.0349
# 96.50507494807243

# %%
y_true = np.concatenate([y for x,y in test_ds])
y_pred = model.predict(test_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 5s 2s/step
# (array([98.14413 , 95.54715 , 96.289635, 96.36921 , 96.17525 ],
#        dtype=float32),
#  96.50507532060146)

# %%
import matplotlib.pyplot as plt

# 1) Plot Loss
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'],    label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# 2) Plot MAE (atau metric lain yang kamu pakai)
plt.figure(figsize=(8,4))
plt.plot(history.history['mae'],     label='train_mae')
plt.plot(history.history['val_mae'], label='val_mae')
plt.title('Training & Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()
