# %%
import tensorflow as tf 
from tensorflow import keras 
import tensorflow_addons as tfa
import tensorflow_hub as hub 
from sklearn.metrics import mean_absolute_error 
import numpy as np 
import datetime
from deepface import DeepFace
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, PReLU
import os
import warnings

# Ignore irrelevant warning messages for cleaner output
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//train_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//val_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds, valid_ds
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>)

# %% [markdown]
# Load Arcface

# %%
from models import create_arcface_model

# Load dengan weights (default)
arcface_112 = create_arcface_model(load_weights=True)
arcface_112.trainable = False

arcface_112.summary()
# Out:
# ✓ Successfully loaded weights from C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//arcface_weights.h5
# Model: "ArcFace"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 112, 112, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 114, 114, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         1728      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_prelu (PReLU)         (None, 112, 112, 64)         64        ['conv1_bn[0][0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 112, 112, 64)         256       ['conv1_prelu[0][0]']
#  rmalization)
#
#  conv2_block1_1_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_bn[0][0]']
#  dding2D)
#
#  conv2_block1_1_conv (Conv2  (None, 112, 112, 64)         36864     ['conv2_block1_1_pad[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 112, 112, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_prelu (PReL  (None, 112, 112, 64)         64        ['conv2_block1_2_bn[0][0]']
#  U)
#
#  conv2_block1_2_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 64)           4096      ['conv1_prelu[0][0]']
#  D)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_add[0][0]']
#  rmalization)
#
#  conv2_block2_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_bn[0][0]']
#  dding2D)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_1_pad[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block2_2_bn[0][0]']
#  U)
#
#  conv2_block2_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_add[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_add[0][0]']
#  rmalization)
#
#  conv2_block3_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_bn[0][0]']
#  dding2D)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_1_pad[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block3_2_bn[0][0]']
#  U)
#
#  conv2_block3_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_2_pad[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 64)           0         ['conv2_block2_add[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_add[0][0]']
#  rmalization)
#
#  conv3_block1_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv3_block1_1_bn[0][0]']
#  dding2D)
#
#  conv3_block1_1_conv (Conv2  (None, 56, 56, 128)          73728     ['conv3_block1_1_pad[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 56, 56, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_prelu (PReL  (None, 56, 56, 128)          128       ['conv3_block1_2_bn[0][0]']
#  U)
#
#  conv3_block1_2_pad (ZeroPa  (None, 58, 58, 128)          0         ['conv3_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 128)          8192      ['conv2_block3_add[0][0]']
#  D)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_add[0][0]']
#  rmalization)
#
#  conv3_block2_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_bn[0][0]']
#  dding2D)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_1_pad[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block2_2_bn[0][0]']
#  U)
#
#  conv3_block2_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_add[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_add[0][0]']
#  rmalization)
#
#  conv3_block3_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_bn[0][0]']
#  dding2D)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_1_pad[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block3_2_bn[0][0]']
#  U)
#
#  conv3_block3_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 128)          0         ['conv3_block2_add[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_add[0][0]']
#  rmalization)
#
#  conv3_block4_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_bn[0][0]']
#  dding2D)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_1_pad[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block4_2_bn[0][0]']
#  U)
#
#  conv3_block4_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_2_pad[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 128)          0         ['conv3_block3_add[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_add[0][0]']
#  rmalization)
#
#  conv4_block1_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv4_block1_1_bn[0][0]']
#  dding2D)
#
#  conv4_block1_1_conv (Conv2  (None, 28, 28, 256)          294912    ['conv4_block1_1_pad[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_prelu (PReL  (None, 28, 28, 256)          256       ['conv4_block1_2_bn[0][0]']
#  U)
#
#  conv4_block1_2_pad (ZeroPa  (None, 30, 30, 256)          0         ['conv4_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 256)          32768     ['conv3_block4_add[0][0]']
#  D)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block1_2_pad[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_add[0][0]']
#  rmalization)
#
#  conv4_block2_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  dding2D)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_1_pad[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block2_2_bn[0][0]']
#  U)
#
#  conv4_block2_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_2_pad[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_add[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_add[0][0]']
#  rmalization)
#
#  conv4_block3_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  dding2D)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_1_pad[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block3_2_bn[0][0]']
#  U)
#
#  conv4_block3_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_2_pad[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 256)          0         ['conv4_block2_add[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_add[0][0]']
#  rmalization)
#
#  conv4_block4_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  dding2D)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_1_pad[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block4_2_bn[0][0]']
#  U)
#
#  conv4_block4_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_2_pad[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 256)          0         ['conv4_block3_add[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_add[0][0]']
#  rmalization)
#
#  conv4_block5_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_bn[0][0]']
#  dding2D)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_1_pad[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block5_2_bn[0][0]']
#  U)
#
#  conv4_block5_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_2_pad[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 256)          0         ['conv4_block4_add[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_add[0][0]']
#  rmalization)
#
#  conv4_block6_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_bn[0][0]']
#  dding2D)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_1_pad[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block6_2_bn[0][0]']
#  U)
#
#  conv4_block6_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_2_pad[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 256)          0         ['conv4_block5_add[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv5_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_add[0][0]']
#  rmalization)
#
#  conv5_block1_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv5_block1_1_bn[0][0]']
#  dding2D)
#
#  conv5_block1_1_conv (Conv2  (None, 14, 14, 512)          1179648   ['conv5_block1_1_pad[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 14, 14, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_prelu (PReL  (None, 14, 14, 512)          512       ['conv5_block1_2_bn[0][0]']
#  U)
#
#  conv5_block1_2_pad (ZeroPa  (None, 16, 16, 512)          0         ['conv5_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 512)            131072    ['conv4_block6_add[0][0]']
#  D)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block1_2_pad[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_add[0][0]']
#  rmalization)
#
#  conv5_block2_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_bn[0][0]']
#  dding2D)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_1_pad[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block2_2_bn[0][0]']
#  U)
#
#  conv5_block2_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_2_pad[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_add[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_add[0][0]']
#  rmalization)
#
#  conv5_block3_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_bn[0][0]']
#  dding2D)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_1_pad[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block3_2_bn[0][0]']
#  U)
#
#  conv5_block3_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_2_pad[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 512)            0         ['conv5_block2_add[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  batch_normalization (Batch  (None, 7, 7, 512)            2048      ['conv5_block3_add[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 7, 7, 512)            0         ['batch_normalization[0][0]']
#
#  flatten (Flatten)           (None, 25088)                0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 512)                  1284556   ['flatten[0][0]']
#                                                           8
#
#  embedding (BatchNormalizat  (None, 512)                  2048      ['dense[0][0]']
#  ion)
#
#  norm_layer (Lambda)         (None, 512)                  0         ['embedding[0][0]']
#
# ==================================================================================================
# Total params: 34165184 (130.33 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 34165184 (130.33 MB)
# __________________________________________________________________________________________________

# %%
from models import create_arcface_model
from tensorflow.keras import regularizers

# Load ArcFace model
arcface_112 = create_arcface_model()
arcface_112.trainable = False

# Build model dengan TimeDistributed untuk sequence input
inputs = keras.layers.Input(shape=(10, 112, 112, 3), name='Input')

# Preprocessing
x = keras.layers.TimeDistributed(keras.layers.Rescaling(scale=1./255.0), name='Rescaling')(inputs)

# ArcFace feature extractor (tetap dibekukan)
x = keras.layers.TimeDistributed(arcface_112, name='arcface')(x)

# LSTM layers
x = keras.layers.LSTM(units=128, return_sequences=True)(x)
x = keras.layers.LSTM(units=64)(x)

# Dense + Dropout + Regularization
x = keras.layers.Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.5)(x)

# Output
x = keras.layers.Dense(5, activation='sigmoid')(x)

# Build model
model = keras.models.Model(inputs=inputs, outputs=x)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ✓ Successfully loaded weights from C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//arcface_weights.h5

# %%
t = datetime.datetime.now().strftime("%m%d_%H%M%S")

# optimizer = keras.optimizers.Adam(learning_rate=0.001)
# optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
# optimizer = tfa.optimizers.RectifiedAdam(learning_rate=0.001)
optimizer = keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)


early_stopping = keras.callbacks.EarlyStopping(patience=10, verbose=1)
check_point    = keras.callbacks.ModelCheckpoint(filepath='./weights/faces/'+str(t)+'/face.t5',
                            monitor='val_mae',
                            mode='min',
                            save_best_only=True,
                            save_weights_only=True,
                            verbose=1)

model.compile(loss='mse', optimizer=optimizer, metrics=['mae'])

# %%
history = model.fit(train_ds, validation_data=valid_ds, batch_size=8, epochs=100, callbacks=[early_stopping, check_point])
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 9.2948 - mae: 0.4705
# Epoch 1: val_mae improved from inf to 0.41828, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 30s 3s/step - loss: 9.2948 - mae: 0.4705 - val_loss: 6.9872 - val_mae: 0.4183
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 5.8714 - mae: 0.2956
# Epoch 2: val_mae improved from 0.41828 to 0.08983, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 5.8714 - mae: 0.2956 - val_loss: 4.5722 - val_mae: 0.0898
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 3.8271 - mae: 0.0852
# Epoch 3: val_mae improved from 0.08983 to 0.06810, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 3.8271 - mae: 0.0852 - val_loss: 3.0449 - val_mae: 0.0681
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5812 - mae: 0.0714
# Epoch 4: val_mae improved from 0.06810 to 0.06588, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.5812 - mae: 0.0714 - val_loss: 1.9841 - val_mae: 0.0659
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6461 - mae: 0.0670
# Epoch 5: val_mae improved from 0.06588 to 0.05555, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.6461 - mae: 0.0670 - val_loss: 1.2517 - val_mae: 0.0556
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0202 - mae: 0.0631
# Epoch 6: val_mae improved from 0.05555 to 0.05088, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 1.0202 - mae: 0.0631 - val_loss: 0.7602 - val_mae: 0.0509
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6151 - mae: 0.0574
# Epoch 7: val_mae improved from 0.05088 to 0.04647, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 0.6151 - mae: 0.0574 - val_loss: 0.4440 - val_mae: 0.0465
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3546 - mae: 0.0532
# Epoch 8: val_mae did not improve from 0.04647
# 8/8 [==============================] - 23s 3s/step - loss: 0.3546 - mae: 0.0532 - val_loss: 0.2502 - val_mae: 0.0504
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1941 - mae: 0.0519
# Epoch 9: val_mae did not improve from 0.04647
# 8/8 [==============================] - 23s 3s/step - loss: 0.1941 - mae: 0.0519 - val_loss: 0.1376 - val_mae: 0.0510
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1102 - mae: 0.0533
# Epoch 10: val_mae improved from 0.04647 to 0.03640, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 0.1102 - mae: 0.0533 - val_loss: 0.0759 - val_mae: 0.0364
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0597 - mae: 0.0489
# Epoch 11: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0597 - mae: 0.0489 - val_loss: 0.0430 - val_mae: 0.0391
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0351 - mae: 0.0449
# Epoch 12: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0351 - mae: 0.0449 - val_loss: 0.0264 - val_mae: 0.0499
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0226 - mae: 0.0469
# Epoch 13: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0226 - mae: 0.0469 - val_loss: 0.0184 - val_mae: 0.0451
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0169 - mae: 0.0464
# Epoch 14: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0169 - mae: 0.0464 - val_loss: 0.0144 - val_mae: 0.0411
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0136 - mae: 0.0441
# Epoch 15: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0136 - mae: 0.0441 - val_loss: 0.0121 - val_mae: 0.0413
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0121 - mae: 0.0441
# Epoch 16: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0121 - mae: 0.0441 - val_loss: 0.0106 - val_mae: 0.0404
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0109 - mae: 0.0446
# Epoch 17: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0109 - mae: 0.0446 - val_loss: 0.0095 - val_mae: 0.0372
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0098 - mae: 0.0429
# Epoch 18: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0098 - mae: 0.0429 - val_loss: 0.0085 - val_mae: 0.0366
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0086 - mae: 0.0411
# Epoch 19: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0086 - mae: 0.0411 - val_loss: 0.0075 - val_mae: 0.0386
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0076 - mae: 0.0414
# Epoch 20: val_mae did not improve from 0.03640
# 8/8 [==============================] - 24s 3s/step - loss: 0.0076 - mae: 0.0414 - val_loss: 0.0067 - val_mae: 0.0368
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0065 - mae: 0.0387
# Epoch 21: val_mae did not improve from 0.03640
# 8/8 [==============================] - 23s 3s/step - loss: 0.0065 - mae: 0.0387 - val_loss: 0.0058 - val_mae: 0.0383
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0061 - mae: 0.0407
# Epoch 22: val_mae improved from 0.03640 to 0.03511, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 0.0061 - mae: 0.0407 - val_loss: 0.0051 - val_mae: 0.0351
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0373
# Epoch 23: val_mae did not improve from 0.03511
# 8/8 [==============================] - 22s 3s/step - loss: 0.0051 - mae: 0.0373 - val_loss: 0.0044 - val_mae: 0.0372
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0043 - mae: 0.0372
# Epoch 24: val_mae did not improve from 0.03511
# 8/8 [==============================] - 23s 3s/step - loss: 0.0043 - mae: 0.0372 - val_loss: 0.0038 - val_mae: 0.0362
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0037 - mae: 0.0363
# Epoch 25: val_mae improved from 0.03511 to 0.03429, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0037 - mae: 0.0363 - val_loss: 0.0032 - val_mae: 0.0343
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0357
# Epoch 26: val_mae improved from 0.03429 to 0.03192, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0034 - mae: 0.0357 - val_loss: 0.0027 - val_mae: 0.0319
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0028 - mae: 0.0327
# Epoch 27: val_mae improved from 0.03192 to 0.03080, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0028 - mae: 0.0327 - val_loss: 0.0023 - val_mae: 0.0308
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0023 - mae: 0.0310
# Epoch 28: val_mae improved from 0.03080 to 0.02994, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 0.0023 - mae: 0.0310 - val_loss: 0.0020 - val_mae: 0.0299
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0020 - mae: 0.0306
# Epoch 29: val_mae improved from 0.02994 to 0.02825, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0020 - mae: 0.0306 - val_loss: 0.0017 - val_mae: 0.0282
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0294
# Epoch 30: val_mae improved from 0.02825 to 0.02662, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0018 - mae: 0.0294 - val_loss: 0.0014 - val_mae: 0.0266
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0279
# Epoch 31: val_mae improved from 0.02662 to 0.02479, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 0.0015 - mae: 0.0279 - val_loss: 0.0012 - val_mae: 0.0248
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0244
# Epoch 32: val_mae improved from 0.02479 to 0.02413, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0012 - mae: 0.0244 - val_loss: 0.0010 - val_mae: 0.0241
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0264
# Epoch 33: val_mae improved from 0.02413 to 0.02217, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0012 - mae: 0.0264 - val_loss: 8.9524e-04 - val_mae: 0.0222
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0250
# Epoch 34: val_mae improved from 0.02217 to 0.02076, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0011 - mae: 0.0250 - val_loss: 7.7281e-04 - val_mae: 0.0208
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 7.6116e-04 - mae: 0.0202
# Epoch 35: val_mae improved from 0.02076 to 0.02065, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 7.6116e-04 - mae: 0.0202 - val_loss: 6.7326e-04 - val_mae: 0.0206
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 8.1012e-04 - mae: 0.0226
# Epoch 36: val_mae improved from 0.02065 to 0.01917, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 8.1012e-04 - mae: 0.0226 - val_loss: 5.9067e-04 - val_mae: 0.0192
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 6.1077e-04 - mae: 0.0195
# Epoch 37: val_mae improved from 0.01917 to 0.01866, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 6.1077e-04 - mae: 0.0195 - val_loss: 5.2144e-04 - val_mae: 0.0187
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 5.8204e-04 - mae: 0.0190
# Epoch 38: val_mae improved from 0.01866 to 0.01787, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 5.8204e-04 - mae: 0.0190 - val_loss: 4.6399e-04 - val_mae: 0.0179
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 5.5921e-04 - mae: 0.0191
# Epoch 39: val_mae improved from 0.01787 to 0.01685, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 5.5921e-04 - mae: 0.0191 - val_loss: 4.1447e-04 - val_mae: 0.0168
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 4.7318e-04 - mae: 0.0176
# Epoch 40: val_mae improved from 0.01685 to 0.01619, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 4.7318e-04 - mae: 0.0176 - val_loss: 3.7123e-04 - val_mae: 0.0162
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 4.1943e-04 - mae: 0.0167
# Epoch 41: val_mae improved from 0.01619 to 0.01568, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 4.1943e-04 - mae: 0.0167 - val_loss: 3.3490e-04 - val_mae: 0.0157
# Epoch 42/100
# 8/8 [==============================] - ETA: 0s - loss: 4.0298e-04 - mae: 0.0167
# Epoch 42: val_mae improved from 0.01568 to 0.01506, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 4.0298e-04 - mae: 0.0167 - val_loss: 3.0337e-04 - val_mae: 0.0151
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 3.8702e-04 - mae: 0.0163
# Epoch 43: val_mae improved from 0.01506 to 0.01434, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.8702e-04 - mae: 0.0163 - val_loss: 2.7614e-04 - val_mae: 0.0143
# Epoch 44/100
# 8/8 [==============================] - ETA: 0s - loss: 3.4401e-04 - mae: 0.0157
# Epoch 44: val_mae improved from 0.01434 to 0.01381, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 3.4401e-04 - mae: 0.0157 - val_loss: 2.5174e-04 - val_mae: 0.0138
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 3.6712e-04 - mae: 0.0159
# Epoch 45: val_mae improved from 0.01381 to 0.01314, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 3.6712e-04 - mae: 0.0159 - val_loss: 2.3002e-04 - val_mae: 0.0131
# Epoch 46/100
# 8/8 [==============================] - ETA: 0s - loss: 2.8171e-04 - mae: 0.0141
# Epoch 46: val_mae improved from 0.01314 to 0.01278, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 2.8171e-04 - mae: 0.0141 - val_loss: 2.1132e-04 - val_mae: 0.0128
# Epoch 47/100
# 8/8 [==============================] - ETA: 0s - loss: 2.7007e-04 - mae: 0.0139
# Epoch 47: val_mae improved from 0.01278 to 0.01240, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 2.7007e-04 - mae: 0.0139 - val_loss: 1.9500e-04 - val_mae: 0.0124
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3031e-04 - mae: 0.0130
# Epoch 48: val_mae improved from 0.01240 to 0.01211, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 2.3031e-04 - mae: 0.0130 - val_loss: 1.8098e-04 - val_mae: 0.0121
# Epoch 49/100
# 8/8 [==============================] - ETA: 0s - loss: 2.2787e-04 - mae: 0.0129
# Epoch 49: val_mae improved from 0.01211 to 0.01173, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.2787e-04 - mae: 0.0129 - val_loss: 1.6830e-04 - val_mae: 0.0117
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 2.2473e-04 - mae: 0.0126
# Epoch 50: val_mae improved from 0.01173 to 0.01138, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 2.2473e-04 - mae: 0.0126 - val_loss: 1.5707e-04 - val_mae: 0.0114
# Epoch 51/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0017e-04 - mae: 0.0124
# Epoch 51: val_mae improved from 0.01138 to 0.01104, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 2.0017e-04 - mae: 0.0124 - val_loss: 1.4678e-04 - val_mae: 0.0110
# Epoch 52/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9969e-04 - mae: 0.0120
# Epoch 52: val_mae improved from 0.01104 to 0.01073, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.9969e-04 - mae: 0.0120 - val_loss: 1.3765e-04 - val_mae: 0.0107
# Epoch 53/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0938e-04 - mae: 0.0121
# Epoch 53: val_mae improved from 0.01073 to 0.01029, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 2.0938e-04 - mae: 0.0121 - val_loss: 1.2919e-04 - val_mae: 0.0103
# Epoch 54/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7389e-04 - mae: 0.0113
# Epoch 54: val_mae improved from 0.01029 to 0.01002, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.7389e-04 - mae: 0.0113 - val_loss: 1.2133e-04 - val_mae: 0.0100
# Epoch 55/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7918e-04 - mae: 0.0115
# Epoch 55: val_mae improved from 0.01002 to 0.00975, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.7918e-04 - mae: 0.0115 - val_loss: 1.1398e-04 - val_mae: 0.0098
# Epoch 56/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4004e-04 - mae: 0.0101
# Epoch 56: val_mae improved from 0.00975 to 0.00961, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.4004e-04 - mae: 0.0101 - val_loss: 1.0754e-04 - val_mae: 0.0096
# Epoch 57/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6402e-04 - mae: 0.0110
# Epoch 57: val_mae improved from 0.00961 to 0.00931, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.6402e-04 - mae: 0.0110 - val_loss: 1.0187e-04 - val_mae: 0.0093
# Epoch 58/100
# 8/8 [==============================] - ETA: 0s - loss: 1.2558e-04 - mae: 0.0099
# Epoch 58: val_mae improved from 0.00931 to 0.00919, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.2558e-04 - mae: 0.0099 - val_loss: 9.6724e-05 - val_mae: 0.0092
# Epoch 59/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6002e-04 - mae: 0.0110
# Epoch 59: val_mae improved from 0.00919 to 0.00888, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.6002e-04 - mae: 0.0110 - val_loss: 9.1904e-05 - val_mae: 0.0089
# Epoch 60/100
# 8/8 [==============================] - ETA: 0s - loss: 1.2862e-04 - mae: 0.0098
# Epoch 60: val_mae improved from 0.00888 to 0.00872, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.2862e-04 - mae: 0.0098 - val_loss: 8.7321e-05 - val_mae: 0.0087
# Epoch 61/100
# 8/8 [==============================] - ETA: 0s - loss: 9.9003e-05 - mae: 0.0087
# Epoch 61: val_mae improved from 0.00872 to 0.00864, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 9.9003e-05 - mae: 0.0087 - val_loss: 8.3530e-05 - val_mae: 0.0086
# Epoch 62/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3436e-04 - mae: 0.0100
# Epoch 62: val_mae improved from 0.00864 to 0.00840, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.3436e-04 - mae: 0.0100 - val_loss: 7.9891e-05 - val_mae: 0.0084
# Epoch 63/100
# 8/8 [==============================] - ETA: 0s - loss: 8.9046e-05 - mae: 0.0084
# Epoch 63: val_mae improved from 0.00840 to 0.00832, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 8.9046e-05 - mae: 0.0084 - val_loss: 7.6696e-05 - val_mae: 0.0083
# Epoch 64/100
# 8/8 [==============================] - ETA: 0s - loss: 8.9227e-05 - mae: 0.0084
# Epoch 64: val_mae improved from 0.00832 to 0.00822, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 8.9227e-05 - mae: 0.0084 - val_loss: 7.3856e-05 - val_mae: 0.0082
# Epoch 65/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0655e-04 - mae: 0.0092
# Epoch 65: val_mae improved from 0.00822 to 0.00801, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.0655e-04 - mae: 0.0092 - val_loss: 7.0979e-05 - val_mae: 0.0080
# Epoch 66/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0929e-04 - mae: 0.0093
# Epoch 66: val_mae improved from 0.00801 to 0.00781, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 1.0929e-04 - mae: 0.0093 - val_loss: 6.8203e-05 - val_mae: 0.0078
# Epoch 67/100
# 8/8 [==============================] - ETA: 0s - loss: 9.9327e-05 - mae: 0.0087
# Epoch 67: val_mae improved from 0.00781 to 0.00768, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 9.9327e-05 - mae: 0.0087 - val_loss: 6.5601e-05 - val_mae: 0.0077
# Epoch 68/100
# 8/8 [==============================] - ETA: 0s - loss: 9.1145e-05 - mae: 0.0084
# Epoch 68: val_mae improved from 0.00768 to 0.00756, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 9.1145e-05 - mae: 0.0084 - val_loss: 6.3209e-05 - val_mae: 0.0076
# Epoch 69/100
# 8/8 [==============================] - ETA: 0s - loss: 9.2720e-05 - mae: 0.0083
# Epoch 69: val_mae improved from 0.00756 to 0.00744, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 9.2720e-05 - mae: 0.0083 - val_loss: 6.0897e-05 - val_mae: 0.0074
# Epoch 70/100
# 8/8 [==============================] - ETA: 0s - loss: 9.7013e-05 - mae: 0.0083
# Epoch 70: val_mae improved from 0.00744 to 0.00730, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 9.7013e-05 - mae: 0.0083 - val_loss: 5.8701e-05 - val_mae: 0.0073
# Epoch 71/100
# 8/8 [==============================] - ETA: 0s - loss: 9.9565e-05 - mae: 0.0088
# Epoch 71: val_mae improved from 0.00730 to 0.00714, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 9.9565e-05 - mae: 0.0088 - val_loss: 5.6617e-05 - val_mae: 0.0071
# Epoch 72/100
# 8/8 [==============================] - ETA: 0s - loss: 7.5313e-05 - mae: 0.0077
# Epoch 72: val_mae improved from 0.00714 to 0.00705, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 7.5313e-05 - mae: 0.0077 - val_loss: 5.4697e-05 - val_mae: 0.0070
# Epoch 73/100
# 8/8 [==============================] - ETA: 0s - loss: 7.2723e-05 - mae: 0.0075
# Epoch 73: val_mae improved from 0.00705 to 0.00696, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 7.2723e-05 - mae: 0.0075 - val_loss: 5.2884e-05 - val_mae: 0.0070
# Epoch 74/100
# 8/8 [==============================] - ETA: 0s - loss: 7.6797e-05 - mae: 0.0078
# Epoch 74: val_mae improved from 0.00696 to 0.00684, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 7.6797e-05 - mae: 0.0078 - val_loss: 5.1194e-05 - val_mae: 0.0068
# Epoch 75/100
# 8/8 [==============================] - ETA: 0s - loss: 6.3731e-05 - mae: 0.0069
# Epoch 75: val_mae improved from 0.00684 to 0.00678, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 6.3731e-05 - mae: 0.0069 - val_loss: 4.9684e-05 - val_mae: 0.0068
# Epoch 76/100
# 8/8 [==============================] - ETA: 0s - loss: 7.4851e-05 - mae: 0.0074
# Epoch 76: val_mae improved from 0.00678 to 0.00668, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 7.4851e-05 - mae: 0.0074 - val_loss: 4.8216e-05 - val_mae: 0.0067
# Epoch 77/100
# 8/8 [==============================] - ETA: 0s - loss: 7.0175e-05 - mae: 0.0071
# Epoch 77: val_mae improved from 0.00668 to 0.00659, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 7.0175e-05 - mae: 0.0071 - val_loss: 4.6809e-05 - val_mae: 0.0066
# Epoch 78/100
# 8/8 [==============================] - ETA: 0s - loss: 7.6752e-05 - mae: 0.0076
# Epoch 78: val_mae improved from 0.00659 to 0.00648, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 7.6752e-05 - mae: 0.0076 - val_loss: 4.5417e-05 - val_mae: 0.0065
# Epoch 79/100
# 8/8 [==============================] - ETA: 0s - loss: 6.4170e-05 - mae: 0.0072
# Epoch 79: val_mae improved from 0.00648 to 0.00640, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 6.4170e-05 - mae: 0.0072 - val_loss: 4.4128e-05 - val_mae: 0.0064
# Epoch 80/100
# 8/8 [==============================] - ETA: 0s - loss: 5.9243e-05 - mae: 0.0067
# Epoch 80: val_mae improved from 0.00640 to 0.00633, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 5.9243e-05 - mae: 0.0067 - val_loss: 4.2961e-05 - val_mae: 0.0063
# Epoch 81/100
# 8/8 [==============================] - ETA: 0s - loss: 5.9860e-05 - mae: 0.0067
# Epoch 81: val_mae improved from 0.00633 to 0.00626, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 5.9860e-05 - mae: 0.0067 - val_loss: 4.1849e-05 - val_mae: 0.0063
# Epoch 82/100
# 8/8 [==============================] - ETA: 0s - loss: 7.8403e-05 - mae: 0.0076
# Epoch 82: val_mae improved from 0.00626 to 0.00614, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 7.8403e-05 - mae: 0.0076 - val_loss: 4.0753e-05 - val_mae: 0.0061
# Epoch 83/100
# 8/8 [==============================] - ETA: 0s - loss: 6.2243e-05 - mae: 0.0069
# Epoch 83: val_mae improved from 0.00614 to 0.00606, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 6.2243e-05 - mae: 0.0069 - val_loss: 3.9662e-05 - val_mae: 0.0061
# Epoch 84/100
# 8/8 [==============================] - ETA: 0s - loss: 8.9549e-05 - mae: 0.0078
# Epoch 84: val_mae improved from 0.00606 to 0.00593, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 8.9549e-05 - mae: 0.0078 - val_loss: 3.8720e-05 - val_mae: 0.0059
# Epoch 85/100
# 8/8 [==============================] - ETA: 0s - loss: 9.0492e-05 - mae: 0.0074
# Epoch 85: val_mae improved from 0.00593 to 0.00582, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 9.0492e-05 - mae: 0.0074 - val_loss: 3.7613e-05 - val_mae: 0.0058
# Epoch 86/100
# 8/8 [==============================] - ETA: 0s - loss: 5.4712e-05 - mae: 0.0064
# Epoch 86: val_mae improved from 0.00582 to 0.00579, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 5.4712e-05 - mae: 0.0064 - val_loss: 3.6387e-05 - val_mae: 0.0058
# Epoch 87/100
# 8/8 [==============================] - ETA: 0s - loss: 5.2821e-05 - mae: 0.0063
# Epoch 87: val_mae improved from 0.00579 to 0.00574, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 5.2821e-05 - mae: 0.0063 - val_loss: 3.5416e-05 - val_mae: 0.0057
# Epoch 88/100
# 8/8 [==============================] - ETA: 0s - loss: 4.3758e-05 - mae: 0.0058
# Epoch 88: val_mae improved from 0.00574 to 0.00570, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.3758e-05 - mae: 0.0058 - val_loss: 3.4544e-05 - val_mae: 0.0057
# Epoch 89/100
# 8/8 [==============================] - ETA: 0s - loss: 4.5906e-05 - mae: 0.0060
# Epoch 89: val_mae improved from 0.00570 to 0.00565, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.5906e-05 - mae: 0.0060 - val_loss: 3.3775e-05 - val_mae: 0.0056
# Epoch 90/100
# 8/8 [==============================] - ETA: 0s - loss: 4.3551e-05 - mae: 0.0060
# Epoch 90: val_mae improved from 0.00565 to 0.00561, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.3551e-05 - mae: 0.0060 - val_loss: 3.3078e-05 - val_mae: 0.0056
# Epoch 91/100
# 8/8 [==============================] - ETA: 0s - loss: 5.2508e-05 - mae: 0.0064
# Epoch 91: val_mae improved from 0.00561 to 0.00554, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 5.2508e-05 - mae: 0.0064 - val_loss: 3.2359e-05 - val_mae: 0.0055
# Epoch 92/100
# 8/8 [==============================] - ETA: 0s - loss: 4.1636e-05 - mae: 0.0057
# Epoch 92: val_mae improved from 0.00554 to 0.00550, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.1636e-05 - mae: 0.0057 - val_loss: 3.1731e-05 - val_mae: 0.0055
# Epoch 93/100
# 8/8 [==============================] - ETA: 0s - loss: 4.8376e-05 - mae: 0.0060
# Epoch 93: val_mae improved from 0.00550 to 0.00545, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.8376e-05 - mae: 0.0060 - val_loss: 3.1104e-05 - val_mae: 0.0054
# Epoch 94/100
# 8/8 [==============================] - ETA: 0s - loss: 4.7857e-05 - mae: 0.0062
# Epoch 94: val_mae improved from 0.00545 to 0.00539, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.7857e-05 - mae: 0.0062 - val_loss: 3.0462e-05 - val_mae: 0.0054
# Epoch 95/100
# 8/8 [==============================] - ETA: 0s - loss: 4.6840e-05 - mae: 0.0062
# Epoch 95: val_mae improved from 0.00539 to 0.00532, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.6840e-05 - mae: 0.0062 - val_loss: 2.9857e-05 - val_mae: 0.0053
# Epoch 96/100
# 8/8 [==============================] - ETA: 0s - loss: 4.0830e-05 - mae: 0.0057
# Epoch 96: val_mae improved from 0.00532 to 0.00529, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.0830e-05 - mae: 0.0057 - val_loss: 2.9281e-05 - val_mae: 0.0053
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 3.9175e-05 - mae: 0.0056
# Epoch 97: val_mae improved from 0.00529 to 0.00524, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 3.9175e-05 - mae: 0.0056 - val_loss: 2.8743e-05 - val_mae: 0.0052
# Epoch 98/100
# 8/8 [==============================] - ETA: 0s - loss: 4.8956e-05 - mae: 0.0060
# Epoch 98: val_mae improved from 0.00524 to 0.00518, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.8956e-05 - mae: 0.0060 - val_loss: 2.8192e-05 - val_mae: 0.0052
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 4.8488e-05 - mae: 0.0061
# Epoch 99: val_mae improved from 0.00518 to 0.00512, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 4.8488e-05 - mae: 0.0061 - val_loss: 2.7628e-05 - val_mae: 0.0051
# Epoch 100/100
# 8/8 [==============================] - ETA: 0s - loss: 3.7998e-05 - mae: 0.0054
# Epoch 100: val_mae improved from 0.00512 to 0.00508, saving model to ./weights/faces/1017_101557\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 3.7998e-05 - mae: 0.0054 - val_loss: 2.7110e-05 - val_mae: 0.0051

# %% [markdown]
# ### Load weights

# %%
model.load_weights('./weights/faces/1017_101557/face.t5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training data

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//train_ds') 
loss, mae = model.evaluate(train_ds)
(1-mae)*100
# Out:
# 8/8 [==============================] - 15s 2s/step - loss: 2.7110e-05 - mae: 0.0051
# 99.49192176572978

# %%
y_true = np.concatenate([y for x,y in train_ds])
y_pred = model.predict(train_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 8/8 [==============================] - 17s 2s/step
# (array([99.48737, 99.49316, 99.48512, 99.49556, 99.49839], dtype=float32),
#  99.49192176572978)

# %% [markdown]
# ### Validation data

# %%
valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//val_ds') 
loss, mae = model.evaluate(valid_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 2.7110e-05 - mae: 0.0051
# 99.49192171916366

# %%
y_true = np.concatenate([y for x,y in valid_ds])
y_pred = model.predict(valid_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 5s 2s/step
# (array([99.48737, 99.49316, 99.48512, 99.49556, 99.49839], dtype=float32),
#  99.49192181229591)

# %% [markdown]
# ### Test data

# %%
test_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//test_ds')
loss, mae = model.evaluate(test_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 2.7110e-05 - mae: 0.0051
# 99.49192171916366

# %%
y_true = np.concatenate([y for x,y in test_ds])
y_pred = model.predict(test_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 5s 2s/step
# (array([99.48737, 99.49316, 99.48512, 99.49556, 99.49839], dtype=float32),
#  99.49192181229591)

# %%
import matplotlib.pyplot as plt

# 1) Plot Loss
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'],    label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# 2) Plot MAE (atau metric lain yang kamu pakai)
plt.figure(figsize=(8,4))
plt.plot(history.history['mae'],     label='train_mae')
plt.plot(history.history['val_mae'], label='val_mae')
plt.title('Training & Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()
