# %%
import tensorflow as tf 
from tensorflow import keras 
import tensorflow_addons as tfa
import tensorflow_hub as hub 
from sklearn.metrics import mean_absolute_error 
import numpy as np 
import datetime
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, PReLU
import os
import warnings

# Ignore irrelevant warning messages for cleaner output
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//train_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//val_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds, valid_ds
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>)

# %% [markdown]
# Load Arcface

# %%
from models import create_arcface_model

# Load dengan weights (default)
arcface_112 = create_arcface_model(load_weights=True)
arcface_112.trainable = False

arcface_112.summary()
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# ✓ Successfully loaded weights from C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//arcface_weights.h5
# Model: "ArcFace"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 112, 112, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 114, 114, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         1728      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_prelu (PReLU)         (None, 112, 112, 64)         64        ['conv1_bn[0][0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 112, 112, 64)         256       ['conv1_prelu[0][0]']
#  rmalization)
#
#  conv2_block1_1_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_bn[0][0]']
#  dding2D)
#
#  conv2_block1_1_conv (Conv2  (None, 112, 112, 64)         36864     ['conv2_block1_1_pad[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 112, 112, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_prelu (PReL  (None, 112, 112, 64)         64        ['conv2_block1_2_bn[0][0]']
#  U)
#
#  conv2_block1_2_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 64)           4096      ['conv1_prelu[0][0]']
#  D)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_add[0][0]']
#  rmalization)
#
#  conv2_block2_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_bn[0][0]']
#  dding2D)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_1_pad[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block2_2_bn[0][0]']
#  U)
#
#  conv2_block2_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_add[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_add[0][0]']
#  rmalization)
#
#  conv2_block3_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_bn[0][0]']
#  dding2D)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_1_pad[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block3_2_bn[0][0]']
#  U)
#
#  conv2_block3_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_2_pad[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 64)           0         ['conv2_block2_add[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_add[0][0]']
#  rmalization)
#
#  conv3_block1_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv3_block1_1_bn[0][0]']
#  dding2D)
#
#  conv3_block1_1_conv (Conv2  (None, 56, 56, 128)          73728     ['conv3_block1_1_pad[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 56, 56, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_prelu (PReL  (None, 56, 56, 128)          128       ['conv3_block1_2_bn[0][0]']
#  U)
#
#  conv3_block1_2_pad (ZeroPa  (None, 58, 58, 128)          0         ['conv3_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 128)          8192      ['conv2_block3_add[0][0]']
#  D)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_add[0][0]']
#  rmalization)
#
#  conv3_block2_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_bn[0][0]']
#  dding2D)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_1_pad[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block2_2_bn[0][0]']
#  U)
#
#  conv3_block2_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_add[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_add[0][0]']
#  rmalization)
#
#  conv3_block3_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_bn[0][0]']
#  dding2D)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_1_pad[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block3_2_bn[0][0]']
#  U)
#
#  conv3_block3_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 128)          0         ['conv3_block2_add[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_add[0][0]']
#  rmalization)
#
#  conv3_block4_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_bn[0][0]']
#  dding2D)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_1_pad[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block4_2_bn[0][0]']
#  U)
#
#  conv3_block4_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_2_pad[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 128)          0         ['conv3_block3_add[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_add[0][0]']
#  rmalization)
#
#  conv4_block1_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv4_block1_1_bn[0][0]']
#  dding2D)
#
#  conv4_block1_1_conv (Conv2  (None, 28, 28, 256)          294912    ['conv4_block1_1_pad[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_prelu (PReL  (None, 28, 28, 256)          256       ['conv4_block1_2_bn[0][0]']
#  U)
#
#  conv4_block1_2_pad (ZeroPa  (None, 30, 30, 256)          0         ['conv4_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 256)          32768     ['conv3_block4_add[0][0]']
#  D)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block1_2_pad[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_add[0][0]']
#  rmalization)
#
#  conv4_block2_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  dding2D)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_1_pad[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block2_2_bn[0][0]']
#  U)
#
#  conv4_block2_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_2_pad[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_add[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_add[0][0]']
#  rmalization)
#
#  conv4_block3_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  dding2D)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_1_pad[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block3_2_bn[0][0]']
#  U)
#
#  conv4_block3_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_2_pad[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 256)          0         ['conv4_block2_add[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_add[0][0]']
#  rmalization)
#
#  conv4_block4_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  dding2D)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_1_pad[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block4_2_bn[0][0]']
#  U)
#
#  conv4_block4_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_2_pad[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 256)          0         ['conv4_block3_add[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_add[0][0]']
#  rmalization)
#
#  conv4_block5_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_bn[0][0]']
#  dding2D)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_1_pad[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block5_2_bn[0][0]']
#  U)
#
#  conv4_block5_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_2_pad[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 256)          0         ['conv4_block4_add[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_add[0][0]']
#  rmalization)
#
#  conv4_block6_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_bn[0][0]']
#  dding2D)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_1_pad[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block6_2_bn[0][0]']
#  U)
#
#  conv4_block6_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_2_pad[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 256)          0         ['conv4_block5_add[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv5_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_add[0][0]']
#  rmalization)
#
#  conv5_block1_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv5_block1_1_bn[0][0]']
#  dding2D)
#
#  conv5_block1_1_conv (Conv2  (None, 14, 14, 512)          1179648   ['conv5_block1_1_pad[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 14, 14, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_prelu (PReL  (None, 14, 14, 512)          512       ['conv5_block1_2_bn[0][0]']
#  U)
#
#  conv5_block1_2_pad (ZeroPa  (None, 16, 16, 512)          0         ['conv5_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 512)            131072    ['conv4_block6_add[0][0]']
#  D)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block1_2_pad[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_add[0][0]']
#  rmalization)
#
#  conv5_block2_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_bn[0][0]']
#  dding2D)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_1_pad[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block2_2_bn[0][0]']
#  U)
#
#  conv5_block2_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_2_pad[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_add[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_add[0][0]']
#  rmalization)
#
#  conv5_block3_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_bn[0][0]']
#  dding2D)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_1_pad[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block3_2_bn[0][0]']
#  U)
#
#  conv5_block3_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_2_pad[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 512)            0         ['conv5_block2_add[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  batch_normalization (Batch  (None, 7, 7, 512)            2048      ['conv5_block3_add[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 7, 7, 512)            0         ['batch_normalization[0][0]']
#
#  flatten (Flatten)           (None, 25088)                0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 512)                  1284556   ['flatten[0][0]']
#                                                           8
#
#  embedding (BatchNormalizat  (None, 512)                  2048      ['dense[0][0]']
#  ion)
#
#  norm_layer (Lambda)         (None, 512)                  0         ['embedding[0][0]']
#
# ==================================================================================================
# Total params: 34165184 (130.33 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 34165184 (130.33 MB)
# __________________________________________________________________________________________________

# %%
from models import create_arcface_model
from tensorflow.keras import regularizers

# Load ArcFace model
arcface_112 = create_arcface_model()
arcface_112.trainable = False

# Build model dengan TimeDistributed untuk sequence input
inputs = keras.layers.Input(shape=(10, 112, 112, 3), name='Input')

# Preprocessing
x = keras.layers.TimeDistributed(keras.layers.Rescaling(scale=1./255.0), name='Rescaling')(inputs)

# ArcFace feature extractor (tetap dibekukan)
x = keras.layers.TimeDistributed(arcface_112, name='arcface')(x)

# LSTM layers
x = keras.layers.LSTM(units=128, return_sequences=True)(x)
x = keras.layers.LSTM(units=64)(x)

# Dense + Dropout + Regularization
x = keras.layers.Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.5)(x)

# Output
x = keras.layers.Dense(5, activation='sigmoid')(x)

# Build model
model = keras.models.Model(inputs=inputs, outputs=x)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ✓ Successfully loaded weights from C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//arcface_weights.h5

# %%
t = datetime.datetime.now().strftime("%m%d_%H%M%S")

# optimizer = keras.optimizers.Adam(learning_rate=0.001)
# optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
# optimizer = tfa.optimizers.RectifiedAdam(learning_rate=0.001)
# optimizer = keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)


early_stopping = keras.callbacks.EarlyStopping(patience=10, verbose=1)
check_point    = keras.callbacks.ModelCheckpoint(filepath='./weights/faces/'+str(t)+'/face.t5',
                            monitor='val_mae',
                            mode='min',
                            save_best_only=True,
                            save_weights_only=True,
                            verbose=1)

model.compile(loss='mse', metrics=['mae'])
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(train_ds, validation_data=valid_ds, batch_size=8, epochs=100, callbacks=[early_stopping, check_point])
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - ETA: 0s - loss: 9.2922 - mae: 0.4764
# Epoch 1: val_mae improved from inf to 0.43339, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 3s/step - loss: 9.2922 - mae: 0.4764 - val_loss: 6.9911 - val_mae: 0.4334
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 5.8794 - mae: 0.3283
# Epoch 2: val_mae improved from 0.43339 to 0.10902, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 5.8794 - mae: 0.3283 - val_loss: 4.5680 - val_mae: 0.1090
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 3.8226 - mae: 0.0891
# Epoch 3: val_mae improved from 0.10902 to 0.07091, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.8226 - mae: 0.0891 - val_loss: 3.0407 - val_mae: 0.0709
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5779 - mae: 0.0716
# Epoch 4: val_mae improved from 0.07091 to 0.06682, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.5779 - mae: 0.0716 - val_loss: 1.9810 - val_mae: 0.0668
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6437 - mae: 0.0675
# Epoch 5: val_mae improved from 0.06682 to 0.05857, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.6437 - mae: 0.0675 - val_loss: 1.2494 - val_mae: 0.0586
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0183 - mae: 0.0630
# Epoch 6: val_mae improved from 0.05857 to 0.05121, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 28s 4s/step - loss: 1.0183 - mae: 0.0630 - val_loss: 0.7589 - val_mae: 0.0512
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6143 - mae: 0.0592
# Epoch 7: val_mae improved from 0.05121 to 0.04838, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 0.6143 - mae: 0.0592 - val_loss: 0.4433 - val_mae: 0.0484
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3549 - mae: 0.0556
# Epoch 8: val_mae did not improve from 0.04838
# 8/8 [==============================] - 27s 3s/step - loss: 0.3549 - mae: 0.0556 - val_loss: 0.2501 - val_mae: 0.0504
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1945 - mae: 0.0531
# Epoch 9: val_mae improved from 0.04838 to 0.04635, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 0.1945 - mae: 0.0531 - val_loss: 0.1379 - val_mae: 0.0463
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1099 - mae: 0.0501
# Epoch 10: val_mae did not improve from 0.04635
# 8/8 [==============================] - 26s 3s/step - loss: 0.1099 - mae: 0.0501 - val_loss: 0.0759 - val_mae: 0.0495
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0602 - mae: 0.0499
# Epoch 11: val_mae improved from 0.04635 to 0.04497, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 27s 3s/step - loss: 0.0602 - mae: 0.0499 - val_loss: 0.0434 - val_mae: 0.0450
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0360 - mae: 0.0481
# Epoch 12: val_mae improved from 0.04497 to 0.04237, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 27s 3s/step - loss: 0.0360 - mae: 0.0481 - val_loss: 0.0271 - val_mae: 0.0424
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0237 - mae: 0.0470
# Epoch 13: val_mae improved from 0.04237 to 0.04126, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 32s 4s/step - loss: 0.0237 - mae: 0.0470 - val_loss: 0.0191 - val_mae: 0.0413
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0174 - mae: 0.0439
# Epoch 14: val_mae did not improve from 0.04126
# 8/8 [==============================] - 34s 4s/step - loss: 0.0174 - mae: 0.0439 - val_loss: 0.0149 - val_mae: 0.0445
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0143 - mae: 0.0457
# Epoch 15: val_mae did not improve from 0.04126
# 8/8 [==============================] - 32s 4s/step - loss: 0.0143 - mae: 0.0457 - val_loss: 0.0127 - val_mae: 0.0431
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0126 - mae: 0.0453
# Epoch 16: val_mae improved from 0.04126 to 0.04023, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 0.0126 - mae: 0.0453 - val_loss: 0.0112 - val_mae: 0.0402
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0112 - mae: 0.0421
# Epoch 17: val_mae did not improve from 0.04023
# 8/8 [==============================] - 31s 4s/step - loss: 0.0112 - mae: 0.0421 - val_loss: 0.0100 - val_mae: 0.0417
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0100 - mae: 0.0442
# Epoch 18: val_mae improved from 0.04023 to 0.03898, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 0.0100 - mae: 0.0442 - val_loss: 0.0090 - val_mae: 0.0390
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0090 - mae: 0.0421
# Epoch 19: val_mae did not improve from 0.03898
# 8/8 [==============================] - 30s 4s/step - loss: 0.0090 - mae: 0.0421 - val_loss: 0.0080 - val_mae: 0.0402
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0082 - mae: 0.0427
# Epoch 20: val_mae improved from 0.03898 to 0.03738, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 0.0082 - mae: 0.0427 - val_loss: 0.0071 - val_mae: 0.0374
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0072 - mae: 0.0402
# Epoch 21: val_mae improved from 0.03738 to 0.03735, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 0.0072 - mae: 0.0402 - val_loss: 0.0063 - val_mae: 0.0373
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0406
# Epoch 22: val_mae improved from 0.03735 to 0.03591, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 0.0066 - mae: 0.0406 - val_loss: 0.0056 - val_mae: 0.0359
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0059 - mae: 0.0397
# Epoch 23: val_mae did not improve from 0.03591
# 8/8 [==============================] - 30s 4s/step - loss: 0.0059 - mae: 0.0397 - val_loss: 0.0048 - val_mae: 0.0361
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0048 - mae: 0.0370
# Epoch 24: val_mae did not improve from 0.03591
# 8/8 [==============================] - 30s 4s/step - loss: 0.0048 - mae: 0.0370 - val_loss: 0.0042 - val_mae: 0.0360
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0364
# Epoch 25: val_mae improved from 0.03591 to 0.03483, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 0.0042 - mae: 0.0364 - val_loss: 0.0036 - val_mae: 0.0348
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0038 - mae: 0.0368
# Epoch 26: val_mae improved from 0.03483 to 0.03273, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 0.0038 - mae: 0.0368 - val_loss: 0.0031 - val_mae: 0.0327
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0030 - mae: 0.0328
# Epoch 27: val_mae improved from 0.03273 to 0.03238, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 0.0030 - mae: 0.0328 - val_loss: 0.0026 - val_mae: 0.0324
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0027 - mae: 0.0332
# Epoch 28: val_mae improved from 0.03238 to 0.03055, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 0.0027 - mae: 0.0332 - val_loss: 0.0022 - val_mae: 0.0306
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0021 - mae: 0.0296
# Epoch 29: val_mae improved from 0.03055 to 0.03012, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 0.0021 - mae: 0.0296 - val_loss: 0.0019 - val_mae: 0.0301
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0021 - mae: 0.0313
# Epoch 30: val_mae improved from 0.03012 to 0.02753, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 0.0021 - mae: 0.0313 - val_loss: 0.0016 - val_mae: 0.0275
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0016 - mae: 0.0276
# Epoch 31: val_mae improved from 0.02753 to 0.02689, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 0.0016 - mae: 0.0276 - val_loss: 0.0014 - val_mae: 0.0269
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0016 - mae: 0.0283
# Epoch 32: val_mae improved from 0.02689 to 0.02490, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 0.0016 - mae: 0.0283 - val_loss: 0.0012 - val_mae: 0.0249
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0239
# Epoch 33: val_mae improved from 0.02490 to 0.02455, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 0.0012 - mae: 0.0239 - val_loss: 0.0010 - val_mae: 0.0245
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0249
# Epoch 34: val_mae improved from 0.02455 to 0.02291, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 0.0011 - mae: 0.0249 - val_loss: 8.9510e-04 - val_mae: 0.0229
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0010 - mae: 0.0239
# Epoch 35: val_mae improved from 0.02291 to 0.02144, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 0.0010 - mae: 0.0239 - val_loss: 7.8095e-04 - val_mae: 0.0214
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 8.2249e-04 - mae: 0.0217
# Epoch 36: val_mae improved from 0.02144 to 0.02096, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 8.2249e-04 - mae: 0.0217 - val_loss: 6.8454e-04 - val_mae: 0.0210
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 8.3803e-04 - mae: 0.0225
# Epoch 37: val_mae improved from 0.02096 to 0.01939, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 8.3803e-04 - mae: 0.0225 - val_loss: 6.0423e-04 - val_mae: 0.0194
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 6.0931e-04 - mae: 0.0190
# Epoch 38: val_mae improved from 0.01939 to 0.01900, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 27s 3s/step - loss: 6.0931e-04 - mae: 0.0190 - val_loss: 5.3672e-04 - val_mae: 0.0190
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 6.0663e-04 - mae: 0.0188
# Epoch 39: val_mae improved from 0.01900 to 0.01824, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 6.0663e-04 - mae: 0.0188 - val_loss: 4.7858e-04 - val_mae: 0.0182
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 5.4154e-04 - mae: 0.0187
# Epoch 40: val_mae improved from 0.01824 to 0.01741, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 5.4154e-04 - mae: 0.0187 - val_loss: 4.2790e-04 - val_mae: 0.0174
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 5.4114e-04 - mae: 0.0187
# Epoch 41: val_mae improved from 0.01741 to 0.01650, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 5.4114e-04 - mae: 0.0187 - val_loss: 3.8415e-04 - val_mae: 0.0165
# Epoch 42/100
# 8/8 [==============================] - ETA: 0s - loss: 4.0664e-04 - mae: 0.0163
# Epoch 42: val_mae improved from 0.01650 to 0.01603, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 4.0664e-04 - mae: 0.0163 - val_loss: 3.4779e-04 - val_mae: 0.0160
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 4.4698e-04 - mae: 0.0171
# Epoch 43: val_mae improved from 0.01603 to 0.01517, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 4.4698e-04 - mae: 0.0171 - val_loss: 3.1563e-04 - val_mae: 0.0152
# Epoch 44/100
# 8/8 [==============================] - ETA: 0s - loss: 3.2739e-04 - mae: 0.0148
# Epoch 44: val_mae improved from 0.01517 to 0.01490, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 3.2739e-04 - mae: 0.0148 - val_loss: 2.8808e-04 - val_mae: 0.0149
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 3.4976e-04 - mae: 0.0156
# Epoch 45: val_mae improved from 0.01490 to 0.01425, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 3.4976e-04 - mae: 0.0156 - val_loss: 2.6375e-04 - val_mae: 0.0142
# Epoch 46/100
# 8/8 [==============================] - ETA: 0s - loss: 3.5086e-04 - mae: 0.0154
# Epoch 46: val_mae improved from 0.01425 to 0.01350, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 32s 4s/step - loss: 3.5086e-04 - mae: 0.0154 - val_loss: 2.4193e-04 - val_mae: 0.0135
# Epoch 47/100
# 8/8 [==============================] - ETA: 0s - loss: 2.8737e-04 - mae: 0.0138
# Epoch 47: val_mae improved from 0.01350 to 0.01321, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 2.8737e-04 - mae: 0.0138 - val_loss: 2.2227e-04 - val_mae: 0.0132
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 3.1682e-04 - mae: 0.0151
# Epoch 48: val_mae improved from 0.01321 to 0.01256, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 33s 4s/step - loss: 3.1682e-04 - mae: 0.0151 - val_loss: 2.0507e-04 - val_mae: 0.0126
# Epoch 49/100
# 8/8 [==============================] - ETA: 0s - loss: 2.9237e-04 - mae: 0.0146
# Epoch 49: val_mae improved from 0.01256 to 0.01207, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 2.9237e-04 - mae: 0.0146 - val_loss: 1.8915e-04 - val_mae: 0.0121
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5148e-04 - mae: 0.0128
# Epoch 50: val_mae improved from 0.01207 to 0.01175, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 2.5148e-04 - mae: 0.0128 - val_loss: 1.7489e-04 - val_mae: 0.0118
# Epoch 51/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3538e-04 - mae: 0.0126
# Epoch 51: val_mae improved from 0.01175 to 0.01142, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 2.3538e-04 - mae: 0.0126 - val_loss: 1.6252e-04 - val_mae: 0.0114
# Epoch 52/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7908e-04 - mae: 0.0112
# Epoch 52: val_mae improved from 0.01142 to 0.01124, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.7908e-04 - mae: 0.0112 - val_loss: 1.5217e-04 - val_mae: 0.0112
# Epoch 53/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0796e-04 - mae: 0.0124
# Epoch 53: val_mae improved from 0.01124 to 0.01086, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 31s 4s/step - loss: 2.0796e-04 - mae: 0.0124 - val_loss: 1.4267e-04 - val_mae: 0.0109
# Epoch 54/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0180e-04 - mae: 0.0121
# Epoch 54: val_mae improved from 0.01086 to 0.01054, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 2.0180e-04 - mae: 0.0121 - val_loss: 1.3390e-04 - val_mae: 0.0105
# Epoch 55/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7635e-04 - mae: 0.0115
# Epoch 55: val_mae improved from 0.01054 to 0.01030, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.7635e-04 - mae: 0.0115 - val_loss: 1.2611e-04 - val_mae: 0.0103
# Epoch 56/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8400e-04 - mae: 0.0116
# Epoch 56: val_mae improved from 0.01030 to 0.00998, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.8400e-04 - mae: 0.0116 - val_loss: 1.1905e-04 - val_mae: 0.0100
# Epoch 57/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8847e-04 - mae: 0.0114
# Epoch 57: val_mae improved from 0.00998 to 0.00959, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.8847e-04 - mae: 0.0114 - val_loss: 1.1263e-04 - val_mae: 0.0096
# Epoch 58/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9066e-04 - mae: 0.0116
# Epoch 58: val_mae improved from 0.00959 to 0.00932, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.9066e-04 - mae: 0.0116 - val_loss: 1.0583e-04 - val_mae: 0.0093
# Epoch 59/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4971e-04 - mae: 0.0105
# Epoch 59: val_mae improved from 0.00932 to 0.00915, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.4971e-04 - mae: 0.0105 - val_loss: 9.9830e-05 - val_mae: 0.0091
# Epoch 60/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6935e-04 - mae: 0.0110
# Epoch 60: val_mae improved from 0.00915 to 0.00889, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.6935e-04 - mae: 0.0110 - val_loss: 9.4651e-05 - val_mae: 0.0089
# Epoch 61/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3866e-04 - mae: 0.0099
# Epoch 61: val_mae improved from 0.00889 to 0.00872, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.3866e-04 - mae: 0.0099 - val_loss: 8.9817e-05 - val_mae: 0.0087
# Epoch 62/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4168e-04 - mae: 0.0100
# Epoch 62: val_mae improved from 0.00872 to 0.00852, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 1.4168e-04 - mae: 0.0100 - val_loss: 8.5435e-05 - val_mae: 0.0085
# Epoch 63/100
# 8/8 [==============================] - ETA: 0s - loss: 9.0114e-05 - mae: 0.0083
# Epoch 63: val_mae improved from 0.00852 to 0.00850, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 9.0114e-05 - mae: 0.0083 - val_loss: 8.1437e-05 - val_mae: 0.0085
# Epoch 64/100
# 8/8 [==============================] - ETA: 0s - loss: 1.1716e-04 - mae: 0.0092
# Epoch 64: val_mae improved from 0.00850 to 0.00832, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.1716e-04 - mae: 0.0092 - val_loss: 7.7960e-05 - val_mae: 0.0083
# Epoch 65/100
# 8/8 [==============================] - ETA: 0s - loss: 1.2359e-04 - mae: 0.0096
# Epoch 65: val_mae improved from 0.00832 to 0.00812, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.2359e-04 - mae: 0.0096 - val_loss: 7.4776e-05 - val_mae: 0.0081
# Epoch 66/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3398e-04 - mae: 0.0098
# Epoch 66: val_mae improved from 0.00812 to 0.00790, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.3398e-04 - mae: 0.0098 - val_loss: 7.1694e-05 - val_mae: 0.0079
# Epoch 67/100
# 8/8 [==============================] - ETA: 0s - loss: 8.9943e-05 - mae: 0.0081
# Epoch 67: val_mae improved from 0.00790 to 0.00782, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 8.9943e-05 - mae: 0.0081 - val_loss: 6.8697e-05 - val_mae: 0.0078
# Epoch 68/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0694e-04 - mae: 0.0088
# Epoch 68: val_mae improved from 0.00782 to 0.00765, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 1.0694e-04 - mae: 0.0088 - val_loss: 6.5942e-05 - val_mae: 0.0077
# Epoch 69/100
# 8/8 [==============================] - ETA: 0s - loss: 8.1311e-05 - mae: 0.0078
# Epoch 69: val_mae improved from 0.00765 to 0.00757, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 8.1311e-05 - mae: 0.0078 - val_loss: 6.3477e-05 - val_mae: 0.0076
# Epoch 70/100
# 8/8 [==============================] - ETA: 0s - loss: 9.9382e-05 - mae: 0.0084
# Epoch 70: val_mae improved from 0.00757 to 0.00740, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 9.9382e-05 - mae: 0.0084 - val_loss: 6.1144e-05 - val_mae: 0.0074
# Epoch 71/100
# 8/8 [==============================] - ETA: 0s - loss: 8.8339e-05 - mae: 0.0083
# Epoch 71: val_mae improved from 0.00740 to 0.00729, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 8.8339e-05 - mae: 0.0083 - val_loss: 5.8888e-05 - val_mae: 0.0073
# Epoch 72/100
# 8/8 [==============================] - ETA: 0s - loss: 9.0806e-05 - mae: 0.0084
# Epoch 72: val_mae improved from 0.00729 to 0.00717, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 9.0806e-05 - mae: 0.0084 - val_loss: 5.6821e-05 - val_mae: 0.0072
# Epoch 73/100
# 8/8 [==============================] - ETA: 0s - loss: 8.2084e-05 - mae: 0.0078
# Epoch 73: val_mae improved from 0.00717 to 0.00706, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 28s 4s/step - loss: 8.2084e-05 - mae: 0.0078 - val_loss: 5.4920e-05 - val_mae: 0.0071
# Epoch 74/100
# 8/8 [==============================] - ETA: 0s - loss: 8.9295e-05 - mae: 0.0082
# Epoch 74: val_mae improved from 0.00706 to 0.00693, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 8.9295e-05 - mae: 0.0082 - val_loss: 5.3038e-05 - val_mae: 0.0069
# Epoch 75/100
# 8/8 [==============================] - ETA: 0s - loss: 7.6364e-05 - mae: 0.0077
# Epoch 75: val_mae improved from 0.00693 to 0.00684, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 7.6364e-05 - mae: 0.0077 - val_loss: 5.1328e-05 - val_mae: 0.0068
# Epoch 76/100
# 8/8 [==============================] - ETA: 0s - loss: 7.5122e-05 - mae: 0.0076
# Epoch 76: val_mae improved from 0.00684 to 0.00674, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 7.5122e-05 - mae: 0.0076 - val_loss: 4.9736e-05 - val_mae: 0.0067
# Epoch 77/100
# 8/8 [==============================] - ETA: 0s - loss: 6.9756e-05 - mae: 0.0070
# Epoch 77: val_mae improved from 0.00674 to 0.00666, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 6.9756e-05 - mae: 0.0070 - val_loss: 4.8249e-05 - val_mae: 0.0067
# Epoch 78/100
# 8/8 [==============================] - ETA: 0s - loss: 8.8818e-05 - mae: 0.0080
# Epoch 78: val_mae improved from 0.00666 to 0.00652, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 8.8818e-05 - mae: 0.0080 - val_loss: 4.6847e-05 - val_mae: 0.0065
# Epoch 79/100
# 8/8 [==============================] - ETA: 0s - loss: 6.0627e-05 - mae: 0.0068
# Epoch 79: val_mae improved from 0.00652 to 0.00648, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 6.0627e-05 - mae: 0.0068 - val_loss: 4.5399e-05 - val_mae: 0.0065
# Epoch 80/100
# 8/8 [==============================] - ETA: 0s - loss: 6.0520e-05 - mae: 0.0069
# Epoch 80: val_mae improved from 0.00648 to 0.00641, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 6.0520e-05 - mae: 0.0069 - val_loss: 4.4166e-05 - val_mae: 0.0064
# Epoch 81/100
# 8/8 [==============================] - ETA: 0s - loss: 5.9450e-05 - mae: 0.0067
# Epoch 81: val_mae improved from 0.00641 to 0.00635, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 25s 3s/step - loss: 5.9450e-05 - mae: 0.0067 - val_loss: 4.3033e-05 - val_mae: 0.0064
# Epoch 82/100
# 8/8 [==============================] - ETA: 0s - loss: 7.1965e-05 - mae: 0.0071
# Epoch 82: val_mae improved from 0.00635 to 0.00623, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 7.1965e-05 - mae: 0.0071 - val_loss: 4.1921e-05 - val_mae: 0.0062
# Epoch 83/100
# 8/8 [==============================] - ETA: 0s - loss: 6.0230e-05 - mae: 0.0068
# Epoch 83: val_mae improved from 0.00623 to 0.00617, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 6.0230e-05 - mae: 0.0068 - val_loss: 4.0785e-05 - val_mae: 0.0062
# Epoch 84/100
# 8/8 [==============================] - ETA: 0s - loss: 6.2377e-05 - mae: 0.0069
# Epoch 84: val_mae improved from 0.00617 to 0.00610, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 26s 3s/step - loss: 6.2377e-05 - mae: 0.0069 - val_loss: 3.9736e-05 - val_mae: 0.0061
# Epoch 85/100
# 8/8 [==============================] - ETA: 0s - loss: 4.6458e-05 - mae: 0.0060
# Epoch 85: val_mae improved from 0.00610 to 0.00605, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 4.6458e-05 - mae: 0.0060 - val_loss: 3.8813e-05 - val_mae: 0.0061
# Epoch 86/100
# 8/8 [==============================] - ETA: 0s - loss: 8.9588e-05 - mae: 0.0076
# Epoch 86: val_mae improved from 0.00605 to 0.00589, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 8.9588e-05 - mae: 0.0076 - val_loss: 3.7913e-05 - val_mae: 0.0059
# Epoch 87/100
# 8/8 [==============================] - ETA: 0s - loss: 5.4180e-05 - mae: 0.0063
# Epoch 87: val_mae improved from 0.00589 to 0.00585, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 5.4180e-05 - mae: 0.0063 - val_loss: 3.6837e-05 - val_mae: 0.0059
# Epoch 88/100
# 8/8 [==============================] - ETA: 0s - loss: 5.7280e-05 - mae: 0.0067
# Epoch 88: val_mae improved from 0.00585 to 0.00579, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 5.7280e-05 - mae: 0.0067 - val_loss: 3.5889e-05 - val_mae: 0.0058
# Epoch 89/100
# 8/8 [==============================] - ETA: 0s - loss: 6.1109e-05 - mae: 0.0066
# Epoch 89: val_mae improved from 0.00579 to 0.00570, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 6.1109e-05 - mae: 0.0066 - val_loss: 3.5012e-05 - val_mae: 0.0057
# Epoch 90/100
# 8/8 [==============================] - ETA: 0s - loss: 5.1579e-05 - mae: 0.0063
# Epoch 90: val_mae improved from 0.00570 to 0.00565, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 5.1579e-05 - mae: 0.0063 - val_loss: 3.4154e-05 - val_mae: 0.0057
# Epoch 91/100
# 8/8 [==============================] - ETA: 0s - loss: 4.7967e-05 - mae: 0.0061
# Epoch 91: val_mae improved from 0.00565 to 0.00561, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 4.7967e-05 - mae: 0.0061 - val_loss: 3.3373e-05 - val_mae: 0.0056
# Epoch 92/100
# 8/8 [==============================] - ETA: 0s - loss: 7.3680e-05 - mae: 0.0071
# Epoch 92: val_mae improved from 0.00561 to 0.00550, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 28s 4s/step - loss: 7.3680e-05 - mae: 0.0071 - val_loss: 3.2636e-05 - val_mae: 0.0055
# Epoch 93/100
# 8/8 [==============================] - ETA: 0s - loss: 4.7881e-05 - mae: 0.0059
# Epoch 93: val_mae improved from 0.00550 to 0.00546, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 28s 4s/step - loss: 4.7881e-05 - mae: 0.0059 - val_loss: 3.1847e-05 - val_mae: 0.0055
# Epoch 94/100
# 8/8 [==============================] - ETA: 0s - loss: 4.9093e-05 - mae: 0.0063
# Epoch 94: val_mae improved from 0.00546 to 0.00541, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 4.9093e-05 - mae: 0.0063 - val_loss: 3.1116e-05 - val_mae: 0.0054
# Epoch 95/100
# 8/8 [==============================] - ETA: 0s - loss: 4.4587e-05 - mae: 0.0058
# Epoch 95: val_mae improved from 0.00541 to 0.00536, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 29s 4s/step - loss: 4.4587e-05 - mae: 0.0058 - val_loss: 3.0453e-05 - val_mae: 0.0054
# Epoch 96/100
# 8/8 [==============================] - ETA: 0s - loss: 4.2447e-05 - mae: 0.0057
# Epoch 96: val_mae improved from 0.00536 to 0.00532, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 28s 4s/step - loss: 4.2447e-05 - mae: 0.0057 - val_loss: 2.9844e-05 - val_mae: 0.0053
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 5.2886e-05 - mae: 0.0062
# Epoch 97: val_mae improved from 0.00532 to 0.00525, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 28s 4s/step - loss: 5.2886e-05 - mae: 0.0062 - val_loss: 2.9235e-05 - val_mae: 0.0053
# Epoch 98/100
# 8/8 [==============================] - ETA: 0s - loss: 5.5695e-05 - mae: 0.0062
# Epoch 98: val_mae improved from 0.00525 to 0.00518, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 5.5695e-05 - mae: 0.0062 - val_loss: 2.8631e-05 - val_mae: 0.0052
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 4.7542e-05 - mae: 0.0060
# Epoch 99: val_mae improved from 0.00518 to 0.00513, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 27s 3s/step - loss: 4.7542e-05 - mae: 0.0060 - val_loss: 2.8007e-05 - val_mae: 0.0051
# Epoch 100/100
# 8/8 [==============================] - ETA: 0s - loss: 5.4704e-05 - mae: 0.0061
# Epoch 100: val_mae improved from 0.00513 to 0.00507, saving model to ./weights/faces/1019_211353\face.t5
# 8/8 [==============================] - 30s 4s/step - loss: 5.4704e-05 - mae: 0.0061 - val_loss: 2.7423e-05 - val_mae: 0.0051

# %% [markdown]
# ### Load weights

# %%
model.load_weights('./weights/faces/1019_211353/face.t5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training data

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//train_ds') 
loss, mae = model.evaluate(train_ds)
(1-mae)*100
# Out:
# 8/8 [==============================] - 18s 2s/step - loss: 2.7423e-05 - mae: 0.0051
# 99.49313807301223

# %%
y_true = np.concatenate([y for x,y in train_ds])
y_pred = model.predict(train_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 8/8 [==============================] - 19s 2s/step
# (array([99.496216, 99.494865, 99.49726 , 99.493996, 99.483345],
#        dtype=float32),
#  99.49313839897513)

# %% [markdown]
# ### Validation data

# %%
valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//val_ds') 
loss, mae = model.evaluate(valid_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 6s 2s/step - loss: 2.7423e-05 - mae: 0.0051
# 99.49313811957836

# %%
y_true = np.concatenate([y for x,y in valid_ds])
y_pred = model.predict(valid_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 6s 2s/step
# (array([99.496216, 99.494865, 99.49726 , 99.493996, 99.483345],
#        dtype=float32),
#  99.49313811957836)

# %% [markdown]
# ### Test data

# %%
test_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface_100//test_ds')
loss, mae = model.evaluate(test_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 6s 2s/step - loss: 2.7423e-05 - mae: 0.0051
# 99.49313811957836

# %%
y_true = np.concatenate([y for x,y in test_ds])
y_pred = model.predict(test_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 6s 2s/step
# (array([99.496216, 99.494865, 99.49726 , 99.493996, 99.483345],
#        dtype=float32),
#  99.49313811957836)

# %%
import matplotlib.pyplot as plt

# 1) Plot Loss
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'],    label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# 2) Plot MAE (atau metric lain yang kamu pakai)
plt.figure(figsize=(8,4))
plt.plot(history.history['mae'],     label='train_mae')
plt.plot(history.history['val_mae'], label='val_mae')
plt.title('Training & Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()
