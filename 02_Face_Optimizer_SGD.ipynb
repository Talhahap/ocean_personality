# %%
import os
import datetime
import warnings
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from sklearn.metrics import mean_absolute_error
from models import create_arcface_model

warnings.filterwarnings('ignore')
print('TensorFlow version:', tf.__version__)
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow version: 2.15.0

# %%
train_ds = tf.data.Dataset.load(r'data\\videoface_100\\train_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.load(r'data\\videoface_100\\val_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds, valid_ds
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>)

# %% [markdown]
# Load Arcface

# %%
# ── [Cell 3] Verifikasi: Load ArcFace pre-trained weights ──────────────────
# Cell ini hanya untuk memastikan create_arcface_model() berjalan dengan benar.
# arcface_112 yang dibuat di sini akan DIGUNAKAN LANGSUNG di Cell 4.
arcface_112 = create_arcface_model(load_weights=True)
arcface_112.trainable = False

print(f'\nArcFace output shape: {arcface_112.output_shape}')  # Harusnya (None, 512)
print(f'Jumlah layer ArcFace : {len(arcface_112.layers)}')
print(f'Trainable            : {arcface_112.trainable}')
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# ✓ ArcFace weights berhasil dimuat dari: c:\Users\ALFIAN\TA_CODING\ZIP_FILE\arcface_oceanmodel\ocean-project-deepface\arcface_weights.h5
#
# ArcFace output shape: (None, 512)
# Jumlah layer ArcFace : 163
# Trainable            : False

# %%
# ── [Cell 4] Bangun model prediksi kepribadian OCEAN ───────────────────────
# CATATAN: arcface_112 sudah di-load di Cell 3, tidak perlu di-load ulang.

inputs = keras.layers.Input(shape=(10, 112, 112, 3), name='Input')

# Rescale [0,255] -> [0,1]
x = keras.layers.TimeDistributed(
    keras.layers.Rescaling(scale=1./255.0), name='Rescaling'
)(inputs)

# Ekstrak ArcFace embedding per-frame -> (batch, 10, 512)
x = keras.layers.TimeDistributed(arcface_112, name='ArcFace')(x)

# Temporal modelling dengan LSTM
x = keras.layers.LSTM(units=128, return_sequences=True, name='LSTM_1')(x)
x = keras.layers.LSTM(units=64, name='LSTM_2')(x)
x = keras.layers.Dropout(0.2, name='Dropout_LSTM')(x)

# Dense head
x = keras.layers.Dense(1024, activation='relu',
                        kernel_regularizer=regularizers.l2(0.01), name='Dense_1')(x)
x = keras.layers.Dropout(0.3, name='Dropout_1')(x)

x = keras.layers.Dense(512, activation='relu',
                        kernel_regularizer=regularizers.l2(0.01), name='Dense_2')(x)
x = keras.layers.Dropout(0.3, name='Dropout_2')(x)

x = keras.layers.Dense(256, activation='relu',
                        kernel_regularizer=regularizers.l2(0.01), name='Dense_3')(x)
x = keras.layers.Dropout(0.5, name='Dropout_3')(x)

# Output: 5 trait OCEAN, nilai antara 0-1
output = keras.layers.Dense(5, activation='sigmoid', name='OCEAN_Output')(x)

model = keras.models.Model(inputs=inputs, outputs=output, name='ArcFace_OCEAN_SGD')
keras.utils.plot_model(model, show_shapes=True)

# %%
# ── [Cell 5] Setup training — Optimizer: SGD (momentum=0.9) ─────────────────
t = datetime.datetime.now().strftime('%m%d_%H%M%S')

optimizer = keras.optimizers.SGD(momentum=0.9)

os.makedirs(f'./weights/faces/{t}', exist_ok=True)
weight_path = f'./weights/faces/{t}/face.h5'

early_stopping = keras.callbacks.EarlyStopping(
    patience=10, verbose=1, restore_best_weights=True
)
check_point = keras.callbacks.ModelCheckpoint(
    filepath=weight_path,
    monitor='val_mae',
    mode='min',
    save_best_only=True,
    save_weights_only=True,
    save_format='h5',
    verbose=1
)

model.compile(loss='mse', optimizer=optimizer, metrics=['mae'])
print(f'Optimizer       : {optimizer}')
print(f'Weights path    : {weight_path}')
# Out:
# Optimizer       : <keras.src.optimizers.sgd.SGD object at 0x000001E232080610>
# Weights path    : ./weights/faces/0415_150207/face.h5

# %%
history = model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=100,
    callbacks=[early_stopping, check_point]
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - ETA: 0s - loss: 11.4312 - mae: 0.1391
# Epoch 1: val_mae improved from inf to 0.13399, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 29s 3s/step - loss: 11.4312 - mae: 0.1391 - val_loss: 11.3333 - val_mae: 0.1340
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 11.2357 - mae: 0.1388
# Epoch 2: val_mae improved from 0.13399 to 0.13314, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 11.2357 - mae: 0.1388 - val_loss: 11.0724 - val_mae: 0.1331
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 10.9393 - mae: 0.1378
# Epoch 3: val_mae improved from 0.13314 to 0.13239, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 10.9393 - mae: 0.1378 - val_loss: 10.7617 - val_mae: 0.1324
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 10.6362 - mae: 0.1374
# Epoch 4: val_mae improved from 0.13239 to 0.13137, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 10.6362 - mae: 0.1374 - val_loss: 10.4356 - val_mae: 0.1314
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 10.3012 - mae: 0.1368
# Epoch 5: val_mae improved from 0.13137 to 0.13071, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 10.3012 - mae: 0.1368 - val_loss: 10.1093 - val_mae: 0.1307
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 9.9745 - mae: 0.1364
# Epoch 6: val_mae improved from 0.13071 to 0.13000, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 9.9745 - mae: 0.1364 - val_loss: 9.7887 - val_mae: 0.1300
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 9.6626 - mae: 0.1353
# Epoch 7: val_mae improved from 0.13000 to 0.12944, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 9.6626 - mae: 0.1353 - val_loss: 9.4765 - val_mae: 0.1294
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 9.3543 - mae: 0.1349
# Epoch 8: val_mae improved from 0.12944 to 0.12874, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 21s 3s/step - loss: 9.3543 - mae: 0.1349 - val_loss: 9.1733 - val_mae: 0.1287
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 9.0456 - mae: 0.1345
# Epoch 9: val_mae improved from 0.12874 to 0.12835, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 9.0456 - mae: 0.1345 - val_loss: 8.8796 - val_mae: 0.1284
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 8.7704 - mae: 0.1346
# Epoch 10: val_mae improved from 0.12835 to 0.12774, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 8.7704 - mae: 0.1346 - val_loss: 8.5951 - val_mae: 0.1277
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 8.4757 - mae: 0.1334
# Epoch 11: val_mae improved from 0.12774 to 0.12741, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 25s 3s/step - loss: 8.4757 - mae: 0.1334 - val_loss: 8.3198 - val_mae: 0.1274
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 8.2090 - mae: 0.1333
# Epoch 12: val_mae improved from 0.12741 to 0.12699, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 25s 3s/step - loss: 8.2090 - mae: 0.1333 - val_loss: 8.0532 - val_mae: 0.1270
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 7.9397 - mae: 0.1328
# Epoch 13: val_mae improved from 0.12699 to 0.12651, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 25s 3s/step - loss: 7.9397 - mae: 0.1328 - val_loss: 7.7952 - val_mae: 0.1265
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 7.6921 - mae: 0.1329
# Epoch 14: val_mae improved from 0.12651 to 0.12611, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 7.6921 - mae: 0.1329 - val_loss: 7.5454 - val_mae: 0.1261
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 7.4478 - mae: 0.1323
# Epoch 15: val_mae improved from 0.12611 to 0.12585, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 7.4478 - mae: 0.1323 - val_loss: 7.3037 - val_mae: 0.1258
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 7.2076 - mae: 0.1321
# Epoch 16: val_mae improved from 0.12585 to 0.12534, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 7.2076 - mae: 0.1321 - val_loss: 7.0697 - val_mae: 0.1253
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 6.9750 - mae: 0.1313
# Epoch 17: val_mae improved from 0.12534 to 0.12498, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 6.9750 - mae: 0.1313 - val_loss: 6.8433 - val_mae: 0.1250
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 6.7501 - mae: 0.1312
# Epoch 18: val_mae improved from 0.12498 to 0.12473, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 6.7501 - mae: 0.1312 - val_loss: 6.6241 - val_mae: 0.1247
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 6.5398 - mae: 0.1317
# Epoch 19: val_mae improved from 0.12473 to 0.12436, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 6.5398 - mae: 0.1317 - val_loss: 6.4120 - val_mae: 0.1244
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 6.3236 - mae: 0.1310
# Epoch 20: val_mae improved from 0.12436 to 0.12412, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 6.3236 - mae: 0.1310 - val_loss: 6.2067 - val_mae: 0.1241
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 6.1264 - mae: 0.1308
# Epoch 21: val_mae improved from 0.12412 to 0.12381, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 6.1264 - mae: 0.1308 - val_loss: 6.0079 - val_mae: 0.1238
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 5.9306 - mae: 0.1305
# Epoch 22: val_mae improved from 0.12381 to 0.12345, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 5.9306 - mae: 0.1305 - val_loss: 5.8156 - val_mae: 0.1235
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 5.7441 - mae: 0.1304
# Epoch 23: val_mae improved from 0.12345 to 0.12330, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 5.7441 - mae: 0.1304 - val_loss: 5.6294 - val_mae: 0.1233
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 5.5620 - mae: 0.1301
# Epoch 24: val_mae improved from 0.12330 to 0.12294, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 5.5620 - mae: 0.1301 - val_loss: 5.4492 - val_mae: 0.1229
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 5.3800 - mae: 0.1298
# Epoch 25: val_mae improved from 0.12294 to 0.12282, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 5.3800 - mae: 0.1298 - val_loss: 5.2748 - val_mae: 0.1228
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 5.2081 - mae: 0.1298
# Epoch 26: val_mae improved from 0.12282 to 0.12264, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 5.2081 - mae: 0.1298 - val_loss: 5.1061 - val_mae: 0.1226
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 5.0405 - mae: 0.1301
# Epoch 27: val_mae improved from 0.12264 to 0.12239, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 5.0405 - mae: 0.1301 - val_loss: 4.9427 - val_mae: 0.1224
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 4.8822 - mae: 0.1300
# Epoch 28: val_mae improved from 0.12239 to 0.12216, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 4.8822 - mae: 0.1300 - val_loss: 4.7845 - val_mae: 0.1222
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 4.7251 - mae: 0.1299
# Epoch 29: val_mae improved from 0.12216 to 0.12198, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 4.7251 - mae: 0.1299 - val_loss: 4.6315 - val_mae: 0.1220
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 4.5777 - mae: 0.1292
# Epoch 30: val_mae improved from 0.12198 to 0.12174, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 4.5777 - mae: 0.1292 - val_loss: 4.4833 - val_mae: 0.1217
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 4.4292 - mae: 0.1293
# Epoch 31: val_mae improved from 0.12174 to 0.12168, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 4.4292 - mae: 0.1293 - val_loss: 4.3400 - val_mae: 0.1217
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 4.2879 - mae: 0.1293
# Epoch 32: val_mae improved from 0.12168 to 0.12157, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 4.2879 - mae: 0.1293 - val_loss: 4.2012 - val_mae: 0.1216
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 4.1523 - mae: 0.1295
# Epoch 33: val_mae improved from 0.12157 to 0.12125, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 4.1523 - mae: 0.1295 - val_loss: 4.0669 - val_mae: 0.1213
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 4.0166 - mae: 0.1293
# Epoch 34: val_mae improved from 0.12125 to 0.12123, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 4.0166 - mae: 0.1293 - val_loss: 3.9369 - val_mae: 0.1212
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 3.8937 - mae: 0.1292
# Epoch 35: val_mae improved from 0.12123 to 0.12110, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.8937 - mae: 0.1292 - val_loss: 3.8111 - val_mae: 0.1211
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 3.7695 - mae: 0.1292
# Epoch 36: val_mae improved from 0.12110 to 0.12086, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.7695 - mae: 0.1292 - val_loss: 3.6893 - val_mae: 0.1209
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 3.6435 - mae: 0.1290
# Epoch 37: val_mae improved from 0.12086 to 0.12083, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.6435 - mae: 0.1290 - val_loss: 3.5714 - val_mae: 0.1208
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 3.5284 - mae: 0.1295
# Epoch 38: val_mae improved from 0.12083 to 0.12081, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.5284 - mae: 0.1295 - val_loss: 3.4573 - val_mae: 0.1208
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 3.4150 - mae: 0.1292
# Epoch 39: val_mae improved from 0.12081 to 0.12072, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.4150 - mae: 0.1292 - val_loss: 3.3469 - val_mae: 0.1207
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 3.3054 - mae: 0.1289
# Epoch 40: val_mae improved from 0.12072 to 0.12060, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.3054 - mae: 0.1289 - val_loss: 3.2400 - val_mae: 0.1206
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 3.2059 - mae: 0.1285
# Epoch 41: val_mae improved from 0.12060 to 0.12042, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.2059 - mae: 0.1285 - val_loss: 3.1366 - val_mae: 0.1204
# Epoch 42/100
# 8/8 [==============================] - ETA: 0s - loss: 3.1032 - mae: 0.1287
# Epoch 42: val_mae improved from 0.12042 to 0.12030, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.1032 - mae: 0.1287 - val_loss: 3.0364 - val_mae: 0.1203
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 3.0036 - mae: 0.1286
# Epoch 43: val_mae improved from 0.12030 to 0.12019, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 3.0036 - mae: 0.1286 - val_loss: 2.9395 - val_mae: 0.1202
# Epoch 44/100
# 8/8 [==============================] - ETA: 0s - loss: 2.9066 - mae: 0.1287
# Epoch 44: val_mae did not improve from 0.12019
# 8/8 [==============================] - 24s 3s/step - loss: 2.9066 - mae: 0.1287 - val_loss: 2.8457 - val_mae: 0.1202
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 2.8117 - mae: 0.1285
# Epoch 45: val_mae did not improve from 0.12019
# 8/8 [==============================] - 24s 3s/step - loss: 2.8117 - mae: 0.1285 - val_loss: 2.7550 - val_mae: 0.1202
# Epoch 46/100
# 8/8 [==============================] - ETA: 0s - loss: 2.7260 - mae: 0.1286
# Epoch 46: val_mae improved from 0.12019 to 0.12006, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 25s 3s/step - loss: 2.7260 - mae: 0.1286 - val_loss: 2.6671 - val_mae: 0.1201
# Epoch 47/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6359 - mae: 0.1291
# Epoch 47: val_mae did not improve from 0.12006
# 8/8 [==============================] - 24s 3s/step - loss: 2.6359 - mae: 0.1291 - val_loss: 2.5821 - val_mae: 0.1202
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5528 - mae: 0.1286
# Epoch 48: val_mae did not improve from 0.12006
# 8/8 [==============================] - 24s 3s/step - loss: 2.5528 - mae: 0.1286 - val_loss: 2.4997 - val_mae: 0.1201
# Epoch 49/100
# 8/8 [==============================] - ETA: 0s - loss: 2.4718 - mae: 0.1289
# Epoch 49: val_mae did not improve from 0.12006
# 8/8 [==============================] - 24s 3s/step - loss: 2.4718 - mae: 0.1289 - val_loss: 2.4201 - val_mae: 0.1202
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3928 - mae: 0.1294
# Epoch 50: val_mae did not improve from 0.12006
# 8/8 [==============================] - 24s 3s/step - loss: 2.3928 - mae: 0.1294 - val_loss: 2.3430 - val_mae: 0.1201
# Epoch 51/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3167 - mae: 0.1289
# Epoch 51: val_mae improved from 0.12006 to 0.12002, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 2.3167 - mae: 0.1289 - val_loss: 2.2683 - val_mae: 0.1200
# Epoch 52/100
# 8/8 [==============================] - ETA: 0s - loss: 2.2468 - mae: 0.1287
# Epoch 52: val_mae improved from 0.12002 to 0.11975, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 2.2468 - mae: 0.1287 - val_loss: 2.1960 - val_mae: 0.1197
# Epoch 53/100
# 8/8 [==============================] - ETA: 0s - loss: 2.1720 - mae: 0.1285
# Epoch 53: val_mae did not improve from 0.11975
# 8/8 [==============================] - 24s 3s/step - loss: 2.1720 - mae: 0.1285 - val_loss: 2.1261 - val_mae: 0.1198
# Epoch 54/100
# 8/8 [==============================] - ETA: 0s - loss: 2.1071 - mae: 0.1285
# Epoch 54: val_mae improved from 0.11975 to 0.11964, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 2.1071 - mae: 0.1285 - val_loss: 2.0584 - val_mae: 0.1196
# Epoch 55/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0387 - mae: 0.1282
# Epoch 55: val_mae did not improve from 0.11964
# 8/8 [==============================] - 24s 3s/step - loss: 2.0387 - mae: 0.1282 - val_loss: 1.9929 - val_mae: 0.1197
# Epoch 56/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9729 - mae: 0.1283
# Epoch 56: val_mae improved from 0.11964 to 0.11958, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.9729 - mae: 0.1283 - val_loss: 1.9295 - val_mae: 0.1196
# Epoch 57/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9114 - mae: 0.1281
# Epoch 57: val_mae improved from 0.11958 to 0.11952, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.9114 - mae: 0.1281 - val_loss: 1.8682 - val_mae: 0.1195
# Epoch 58/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8502 - mae: 0.1286
# Epoch 58: val_mae improved from 0.11952 to 0.11952, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.8502 - mae: 0.1286 - val_loss: 1.8088 - val_mae: 0.1195
# Epoch 59/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7934 - mae: 0.1285
# Epoch 59: val_mae improved from 0.11952 to 0.11949, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.7934 - mae: 0.1285 - val_loss: 1.7513 - val_mae: 0.1195
# Epoch 60/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7339 - mae: 0.1286
# Epoch 60: val_mae improved from 0.11949 to 0.11943, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.7339 - mae: 0.1286 - val_loss: 1.6956 - val_mae: 0.1194
# Epoch 61/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6792 - mae: 0.1284
# Epoch 61: val_mae improved from 0.11943 to 0.11934, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.6792 - mae: 0.1284 - val_loss: 1.6418 - val_mae: 0.1193
# Epoch 62/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6279 - mae: 0.1283
# Epoch 62: val_mae did not improve from 0.11934
# 8/8 [==============================] - 24s 3s/step - loss: 1.6279 - mae: 0.1283 - val_loss: 1.5896 - val_mae: 0.1194
# Epoch 63/100
# 8/8 [==============================] - ETA: 0s - loss: 1.5757 - mae: 0.1288
# Epoch 63: val_mae did not improve from 0.11934
# 8/8 [==============================] - 24s 3s/step - loss: 1.5757 - mae: 0.1288 - val_loss: 1.5392 - val_mae: 0.1194
# Epoch 64/100
# 8/8 [==============================] - ETA: 0s - loss: 1.5258 - mae: 0.1279
# Epoch 64: val_mae did not improve from 0.11934
# 8/8 [==============================] - 24s 3s/step - loss: 1.5258 - mae: 0.1279 - val_loss: 1.4904 - val_mae: 0.1194
# Epoch 65/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4776 - mae: 0.1290
# Epoch 65: val_mae did not improve from 0.11934
# 8/8 [==============================] - 24s 3s/step - loss: 1.4776 - mae: 0.1290 - val_loss: 1.4431 - val_mae: 0.1194
# Epoch 66/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4322 - mae: 0.1289
# Epoch 66: val_mae improved from 0.11934 to 0.11929, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.4322 - mae: 0.1289 - val_loss: 1.3973 - val_mae: 0.1193
# Epoch 67/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3881 - mae: 0.1286
# Epoch 67: val_mae improved from 0.11929 to 0.11925, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.3881 - mae: 0.1286 - val_loss: 1.3531 - val_mae: 0.1193
# Epoch 68/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3418 - mae: 0.1283
# Epoch 68: val_mae did not improve from 0.11925
# 8/8 [==============================] - 24s 3s/step - loss: 1.3418 - mae: 0.1283 - val_loss: 1.3102 - val_mae: 0.1193
# Epoch 69/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3009 - mae: 0.1282
# Epoch 69: val_mae did not improve from 0.11925
# 8/8 [==============================] - 24s 3s/step - loss: 1.3009 - mae: 0.1282 - val_loss: 1.2687 - val_mae: 0.1193
# Epoch 70/100
# 8/8 [==============================] - ETA: 0s - loss: 1.2586 - mae: 0.1281
# Epoch 70: val_mae did not improve from 0.11925
# 8/8 [==============================] - 24s 3s/step - loss: 1.2586 - mae: 0.1281 - val_loss: 1.2286 - val_mae: 0.1193
# Epoch 71/100
# 8/8 [==============================] - ETA: 0s - loss: 1.2197 - mae: 0.1279
# Epoch 71: val_mae did not improve from 0.11925
# 8/8 [==============================] - 24s 3s/step - loss: 1.2197 - mae: 0.1279 - val_loss: 1.1897 - val_mae: 0.1193
# Epoch 72/100
# 8/8 [==============================] - ETA: 0s - loss: 1.1826 - mae: 0.1282
# Epoch 72: val_mae improved from 0.11925 to 0.11913, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.1826 - mae: 0.1282 - val_loss: 1.1521 - val_mae: 0.1191
# Epoch 73/100
# 8/8 [==============================] - ETA: 0s - loss: 1.1449 - mae: 0.1280
# Epoch 73: val_mae did not improve from 0.11913
# 8/8 [==============================] - 24s 3s/step - loss: 1.1449 - mae: 0.1280 - val_loss: 1.1157 - val_mae: 0.1191
# Epoch 74/100
# 8/8 [==============================] - ETA: 0s - loss: 1.1088 - mae: 0.1282
# Epoch 74: val_mae did not improve from 0.11913
# 8/8 [==============================] - 24s 3s/step - loss: 1.1088 - mae: 0.1282 - val_loss: 1.0805 - val_mae: 0.1192
# Epoch 75/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0743 - mae: 0.1277
# Epoch 75: val_mae improved from 0.11913 to 0.11911, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.0743 - mae: 0.1277 - val_loss: 1.0463 - val_mae: 0.1191
# Epoch 76/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0409 - mae: 0.1283
# Epoch 76: val_mae improved from 0.11911 to 0.11904, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 24s 3s/step - loss: 1.0409 - mae: 0.1283 - val_loss: 1.0133 - val_mae: 0.1190
# Epoch 77/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0074 - mae: 0.1282
# Epoch 77: val_mae improved from 0.11904 to 0.11904, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 1.0074 - mae: 0.1282 - val_loss: 0.9814 - val_mae: 0.1190
# Epoch 78/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9760 - mae: 0.1282
# Epoch 78: val_mae did not improve from 0.11904
# 8/8 [==============================] - 21s 3s/step - loss: 0.9760 - mae: 0.1282 - val_loss: 0.9505 - val_mae: 0.1191
# Epoch 79/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9467 - mae: 0.1281
# Epoch 79: val_mae improved from 0.11904 to 0.11893, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 0.9467 - mae: 0.1281 - val_loss: 0.9205 - val_mae: 0.1189
# Epoch 80/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9160 - mae: 0.1281
# Epoch 80: val_mae did not improve from 0.11893
# 8/8 [==============================] - 25s 3s/step - loss: 0.9160 - mae: 0.1281 - val_loss: 0.8915 - val_mae: 0.1190
# Epoch 81/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8882 - mae: 0.1284
# Epoch 81: val_mae did not improve from 0.11893
# 8/8 [==============================] - 23s 3s/step - loss: 0.8882 - mae: 0.1284 - val_loss: 0.8635 - val_mae: 0.1190
# Epoch 82/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8608 - mae: 0.1285
# Epoch 82: val_mae did not improve from 0.11893
# 8/8 [==============================] - 21s 3s/step - loss: 0.8608 - mae: 0.1285 - val_loss: 0.8364 - val_mae: 0.1190
# Epoch 83/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8340 - mae: 0.1290
# Epoch 83: val_mae did not improve from 0.11893
# 8/8 [==============================] - 22s 3s/step - loss: 0.8340 - mae: 0.1290 - val_loss: 0.8101 - val_mae: 0.1190
# Epoch 84/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8080 - mae: 0.1284
# Epoch 84: val_mae improved from 0.11893 to 0.11884, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 0.8080 - mae: 0.1284 - val_loss: 0.7846 - val_mae: 0.1188
# Epoch 85/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7827 - mae: 0.1280
# Epoch 85: val_mae improved from 0.11884 to 0.11882, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 21s 3s/step - loss: 0.7827 - mae: 0.1280 - val_loss: 0.7600 - val_mae: 0.1188
# Epoch 86/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7577 - mae: 0.1282
# Epoch 86: val_mae improved from 0.11882 to 0.11881, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 21s 3s/step - loss: 0.7577 - mae: 0.1282 - val_loss: 0.7362 - val_mae: 0.1188
# Epoch 87/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7350 - mae: 0.1286
# Epoch 87: val_mae did not improve from 0.11881
# 8/8 [==============================] - 23s 3s/step - loss: 0.7350 - mae: 0.1286 - val_loss: 0.7132 - val_mae: 0.1189
# Epoch 88/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7120 - mae: 0.1278
# Epoch 88: val_mae improved from 0.11881 to 0.11876, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 0.7120 - mae: 0.1278 - val_loss: 0.6908 - val_mae: 0.1188
# Epoch 89/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6897 - mae: 0.1278
# Epoch 89: val_mae did not improve from 0.11876
# 8/8 [==============================] - 21s 3s/step - loss: 0.6897 - mae: 0.1278 - val_loss: 0.6693 - val_mae: 0.1189
# Epoch 90/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6686 - mae: 0.1282
# Epoch 90: val_mae did not improve from 0.11876
# 8/8 [==============================] - 22s 3s/step - loss: 0.6686 - mae: 0.1282 - val_loss: 0.6483 - val_mae: 0.1188
# Epoch 91/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6484 - mae: 0.1285
# Epoch 91: val_mae did not improve from 0.11876
# 8/8 [==============================] - 21s 3s/step - loss: 0.6484 - mae: 0.1285 - val_loss: 0.6281 - val_mae: 0.1188
# Epoch 92/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6291 - mae: 0.1290
# Epoch 92: val_mae improved from 0.11876 to 0.11872, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 0.6291 - mae: 0.1290 - val_loss: 0.6085 - val_mae: 0.1187
# Epoch 93/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6091 - mae: 0.1282
# Epoch 93: val_mae did not improve from 0.11872
# 8/8 [==============================] - 22s 3s/step - loss: 0.6091 - mae: 0.1282 - val_loss: 0.5896 - val_mae: 0.1188
# Epoch 94/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5904 - mae: 0.1287
# Epoch 94: val_mae did not improve from 0.11872
# 8/8 [==============================] - 21s 3s/step - loss: 0.5904 - mae: 0.1287 - val_loss: 0.5712 - val_mae: 0.1188
# Epoch 95/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5727 - mae: 0.1282
# Epoch 95: val_mae improved from 0.11872 to 0.11870, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 0.5727 - mae: 0.1282 - val_loss: 0.5534 - val_mae: 0.1187
# Epoch 96/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5553 - mae: 0.1280
# Epoch 96: val_mae improved from 0.11870 to 0.11863, saving model to ./weights/faces/0415_150207\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 0.5553 - mae: 0.1280 - val_loss: 0.5362 - val_mae: 0.1186
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5379 - mae: 0.1282
# Epoch 97: val_mae did not improve from 0.11863
# 8/8 [==============================] - 21s 3s/step - loss: 0.5379 - mae: 0.1282 - val_loss: 0.5196 - val_mae: 0.1187
# Epoch 98/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5213 - mae: 0.1278
# Epoch 98: val_mae did not improve from 0.11863
# 8/8 [==============================] - 22s 3s/step - loss: 0.5213 - mae: 0.1278 - val_loss: 0.5035 - val_mae: 0.1186
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5055 - mae: 0.1285
# Epoch 99: val_mae did not improve from 0.11863
# 8/8 [==============================] - 22s 3s/step - loss: 0.5055 - mae: 0.1285 - val_loss: 0.4879 - val_mae: 0.1187
# Epoch 100/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4904 - mae: 0.1283
# Epoch 100: val_mae did not improve from 0.11863
# 8/8 [==============================] - 23s 3s/step - loss: 0.4904 - mae: 0.1283 - val_loss: 0.4729 - val_mae: 0.1188

# %% [markdown]
# ### Load weights

# %%
# ── [Cell 8] Load weights (OPSIONAL) ──────────────────────────────────────
# PERHATIAN: Jalankan cell ini HANYA jika:
#   - Kamu mau load ulang weights tanpa training dari awal
#   - Atau kernel restart setelah training selesai
#
# Jika baru selesai training (Cell 6 baru dijalankan),
# LEWATI cell ini -- model di memori sudah punya weights terbaik.
#
# Jika perlu load ulang, uncomment baris di bawah dan sesuaikan path:
# model.load_weights(f'weights/faces/{t}/face.h5')
# print(f'Weights di-load dari: weights/faces/{t}/face.h5')
print('Cell 8 di-skip. Model menggunakan weights hasil training terbaru.')
# Out:
# Cell 8 di-skip. Model menggunakan weights hasil training terbaru.

# %%
# ── [Cell 8b] Simpan full model untuk deployment Flask ─────────────────────
full_model_path = f'weights/faces/{t}/face_full_model.h5'
model.save(full_model_path)
print(f'Full model disimpan ke: {full_model_path}')
print('Gunakan di Flask: keras.models.load_model(path)')
# Out:
# Full model disimpan ke: weights/faces/0415_150207/face_full_model.h5
# Gunakan di Flask: keras.models.load_model(path)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training data

# %%
train_ds = tf.data.Dataset.load(r'data\videoface_100\train_ds') 
loss, mae = model.evaluate(train_ds)
(1-mae)*100
# Out:
# 8/8 [==============================] - 17s 2s/step - loss: 0.4818 - mae: 0.1281
# 87.19021528959274

# %%
y_true = np.concatenate([y for x,y in train_ds])
y_pred = model.predict(train_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 8/8 [==============================] - 17s 2s/step
# (array([88.51136, 85.23382, 87.47541, 88.51409, 86.2164 ], dtype=float32),
#  87.19021379947662)

# %% [markdown]
# ### Validation data

# %%
valid_ds = tf.data.Dataset.load(r'data\videoface_100\val_ds') 
loss, mae = model.evaluate(valid_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 0.4729 - mae: 0.1188
# 88.12473565340042

# %%
y_true = np.concatenate([y for x,y in valid_ds])
y_pred = model.predict(valid_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 5s 2s/step
# (array([88.37877, 87.40974, 88.74196, 90.34583, 85.74738], dtype=float32),
#  88.12473565340042)

# %% [markdown]
# ### Test data

# %%
test_ds = tf.data.Dataset.load(r'data\videoface_100\test_ds')
loss, mae = model.evaluate(test_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 0.4856 - mae: 0.1399
# 86.01017594337463

# %%
y_true = np.concatenate([y for x,y in test_ds])
y_pred = model.predict(test_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 5s 2s/step
# (array([88.420364, 84.02952 , 87.30039 , 87.08856 , 83.21205 ],
#        dtype=float32),
#  86.01017594337463)

# %%
import matplotlib.pyplot as plt

# 1) Plot Loss
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'],    label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# 2) Plot MAE (atau metric lain yang kamu pakai)
plt.figure(figsize=(8,4))
plt.plot(history.history['mae'],     label='train_mae')
plt.plot(history.history['val_mae'], label='val_mae')
plt.title('Training & Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## Evaluasi Tambahan

# %%
# ── [Eval 1] Tabel Ringkasan Per Trait OCEAN ─────────────────────────────
import pandas as pd

TRAITS = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']

def compute_summary(ds):
    y_true_list, y_pred_list = [], []
    for x_batch, y_batch in ds:
        y_true_list.append(y_batch.numpy())
        y_pred_list.append(model.predict(x_batch, verbose=0))
    yt = np.vstack(y_true_list)
    yp = np.vstack(y_pred_list)
    mae = np.abs(yt - yp).mean(axis=0)
    acc = (1 - mae) * 100
    return mae, acc

train_ds_e = tf.data.Dataset.load(r'data\\videoface_100\\train_ds')
valid_ds_e = tf.data.Dataset.load(r'data\\videoface_100\\val_ds')
test_ds_e  = tf.data.Dataset.load(r'data\\videoface_100\\test_ds')

mae_tr, acc_tr = compute_summary(train_ds_e)
mae_vl, acc_vl = compute_summary(valid_ds_e)
mae_te, acc_te = compute_summary(test_ds_e)

rows = []
for i, trait in enumerate(TRAITS):
    rows.append({'Trait': trait,
                 'MAE Train': f'{mae_tr[i]:.4f}', 'Acc Train (%)': f'{acc_tr[i]:.2f}',
                 'MAE Val'  : f'{mae_vl[i]:.4f}', 'Acc Val (%)'  : f'{acc_vl[i]:.2f}',
                 'MAE Test' : f'{mae_te[i]:.4f}', 'Acc Test (%)' : f'{acc_te[i]:.2f}'})
rows.append({'Trait': 'RATA-RATA',
             'MAE Train': f'{mae_tr.mean():.4f}', 'Acc Train (%)': f'{acc_tr.mean():.2f}',
             'MAE Val'  : f'{mae_vl.mean():.4f}', 'Acc Val (%)'  : f'{acc_vl.mean():.2f}',
             'MAE Test' : f'{mae_te.mean():.4f}', 'Acc Test (%)' : f'{acc_te.mean():.2f}'})

df_summary = pd.DataFrame(rows).set_index('Trait')
print('\n=== Tabel Ringkasan Evaluasi Per Trait OCEAN ===')
print(df_summary.to_string())
df_summary
# Out:
# === Tabel Ringkasan Evaluasi Per Trait OCEAN ===
#                   MAE Train Acc Train (%) MAE Val Acc Val (%) MAE Test Acc Test (%)
# Trait
# Openness             0.1149         88.51  0.1162       88.38   0.1158        88.42
# Conscientiousness    0.1477         85.23  0.1259       87.41   0.1597        84.03
# Extraversion         0.1252         87.48  0.1126       88.74   0.1270        87.30
# Agreeableness        0.1149         88.51  0.0965       90.35   0.1291        87.09
# Neuroticism          0.1378         86.22  0.1425       85.75   0.1679        83.21
# RATA-RATA            0.1281         87.19  0.1188       88.12   0.1399        86.01
#                   MAE Train Acc Train (%) MAE Val Acc Val (%) MAE Test  \
# Trait
# Openness             0.1149         88.51  0.1162       88.38   0.1158
# Conscientiousness    0.1477         85.23  0.1259       87.41   0.1597
# Extraversion         0.1252         87.48  0.1126       88.74   0.1270
# Agreeableness        0.1149         88.51  0.0965       90.35   0.1291
# Neuroticism          0.1378         86.22  0.1425       85.75   0.1679
# RATA-RATA            0.1281         87.19  0.1188       88.12   0.1399
#
#                   Acc Test (%)
# Trait
# Openness                 88.42
# Conscientiousness        84.03
# Extraversion             87.30
# Agreeableness            87.09
# Neuroticism              83.21
# RATA-RATA                86.01

# %%
# ── [Eval 2] Scatter Plot: Prediksi vs Ground Truth (Test Data) ───────────
import matplotlib.pyplot as plt

test_ds_sc = tf.data.Dataset.load(r'data\\videoface_100\\test_ds')
y_true_all = np.concatenate([y.numpy() for _, y in test_ds_sc])
y_pred_all = model.predict(test_ds_sc, verbose=0)

fig, axes = plt.subplots(1, 5, figsize=(20, 4))
fig.suptitle('Scatter Plot - SGD (momentum=0.9) (Test Data)', fontsize=13, fontweight='bold')

for i, (ax, trait) in enumerate(zip(axes, TRAITS)):
    yt = y_true_all[:, i]; yp = y_pred_all[:, i]
    ax.scatter(yt, yp, alpha=0.4, s=15, color='steelblue')
    lims = [min(yt.min(), yp.min()), max(yt.max(), yp.max())]
    ax.plot(lims, lims, 'r--', linewidth=1.5, label='Ideal')
    ax.set_title(trait, fontweight='bold'); ax.set_xlabel('Ground Truth'); ax.set_ylabel('Prediksi')
    ax.set_xlim(0, 1); ax.set_ylim(0, 1); ax.legend(fontsize=8)
    ax.text(0.05, 0.92, f'MAE={np.abs(yt-yp).mean():.3f}', transform=ax.transAxes, fontsize=9, color='darkred')

plt.tight_layout()
plt.savefig('scatter_sgd_(momentum=0.9).png', dpi=120, bbox_inches='tight')
plt.show()

# %%
# ── [Eval 3] Histogram: Distribusi Prediksi vs Ground Truth ───────────────
fig, axes = plt.subplots(1, 5, figsize=(20, 4))
fig.suptitle('Distribusi Prediksi vs GT - SGD (momentum=0.9)', fontsize=13, fontweight='bold')

for i, (ax, trait) in enumerate(zip(axes, TRAITS)):
    ax.hist(y_true_all[:, i], bins=20, alpha=0.5, color='royalblue', label='Ground Truth', density=True)
    ax.hist(y_pred_all[:, i], bins=20, alpha=0.5, color='tomato',    label='Prediksi',     density=True)
    ax.set_title(trait, fontweight='bold'); ax.set_xlabel('Nilai (0-1)'); ax.set_ylabel('Densitas')
    ax.legend(fontsize=8); ax.set_xlim(0, 1)

plt.tight_layout()
plt.savefig('histogram_sgd_(momentum=0.9).png', dpi=120, bbox_inches='tight')
plt.show()
print('CATATAN: Jika prediksi menumpuk di satu titik -> model STUCK.')
# Out:
# CATATAN: Jika prediksi menumpuk di satu titik -> model STUCK.

# %%
# ── [Eval 4] Training Summary ───────────────────────────────────────────────
val_maes   = history.history['val_mae']
best_epoch = int(np.argmin(val_maes)) + 1
best_val   = min(val_maes)
last_epoch = len(val_maes)

print('=' * 45)
print('         TRAINING SUMMARY')
print('=' * 45)
print('  Notebook        : 02_Face_Optimizer_SGD')
print('  Optimizer       : SGD (momentum=0.9)')
print(f'  Total Epoch     : {last_epoch}')
print(f'  Best Epoch      : {best_epoch}')
print(f'  Best Val MAE    : {best_val:.4f}')
print(f'  Best Val Acc    : {(1-best_val)*100:.2f}%')
print(f'  Test MAE (rata) : {mae_te.mean():.4f}')
print(f'  Test Acc (rata) : {acc_te.mean():.2f}%')
print('=' * 45)
print()
print('Per Trait Test Accuracy:')
for trait, acc in zip(TRAITS, acc_te):
    bar = '#' * int(acc / 5)
    print(f'  {trait:18s}: {acc:5.2f}% |{bar}')
# Out:
# =============================================
#          TRAINING SUMMARY
# =============================================
#   Notebook        : 02_Face_Optimizer_SGD
#   Optimizer       : SGD (momentum=0.9)
#   Total Epoch     : 100
#   Best Epoch      : 96
#   Best Val MAE    : 0.1186
#   Best Val Acc    : 88.14%
#   Test MAE (rata) : 0.1399
#   Test Acc (rata) : 86.01%
# =============================================
#
# Per Trait Test Accuracy:
#   Openness          : 88.42% |#################
#   Conscientiousness : 84.03% |################
#   Extraversion      : 87.30% |#################
#   Agreeableness     : 87.09% |#################
#   Neuroticism       : 83.21% |################
