# %%
import os
import datetime
import warnings
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from sklearn.metrics import mean_absolute_error
from models import create_arcface_model

warnings.filterwarnings('ignore')
print('TensorFlow version:', tf.__version__)
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow version: 2.15.0

# %%
train_ds = tf.data.Dataset.load(r'data\\videoface_100\\train_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.load(r'data\\videoface_100\\val_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds, valid_ds
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>)

# %% [markdown]
# Load Arcface

# %%
# ── [Cell 3] Verifikasi: Load ArcFace pre-trained weights ──────────────────
# Cell ini hanya untuk memastikan create_arcface_model() berjalan dengan benar.
# arcface_112 yang dibuat di sini akan DIGUNAKAN LANGSUNG di Cell 4.
arcface_112 = create_arcface_model(load_weights=True)
arcface_112.trainable = False

print(f'\nArcFace output shape: {arcface_112.output_shape}')  # Harusnya (None, 512)
print(f'Jumlah layer ArcFace : {len(arcface_112.layers)}')
print(f'Trainable            : {arcface_112.trainable}')
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# [OK] ArcFace weights berhasil dimuat dari: c:\Users\ALFIAN\TA_CODING\ZIP_FILE\arcface_oceanmodel\ocean-project-deepface\arcface_weights.h5
#
# ArcFace output shape: (None, 512)
# Jumlah layer ArcFace : 163
# Trainable            : False

# %%
# ── [Cell 4] Bangun model prediksi kepribadian OCEAN ───────────────────────
# CATATAN: arcface_112 sudah di-load di Cell 3, tidak perlu di-load ulang.

inputs = keras.layers.Input(shape=(10, 112, 112, 3), name='Input')

# Rescale [0,255] -> [0,1]
x = keras.layers.TimeDistributed(
    keras.layers.Rescaling(scale=1./255.0), name='Rescaling'
)(inputs)

# Ekstrak ArcFace embedding per-frame -> (batch, 10, 512)
x = keras.layers.TimeDistributed(arcface_112, name='ArcFace')(x)

# Temporal modelling dengan LSTM
x = keras.layers.LSTM(units=128, return_sequences=True, name='LSTM_1')(x)
x = keras.layers.LSTM(units=64, name='LSTM_2')(x)
x = keras.layers.Dropout(0.2, name='Dropout_LSTM')(x)

# Dense head
x = keras.layers.Dense(1024, activation='relu',
                        kernel_regularizer=regularizers.l2(0.01), name='Dense_1')(x)
x = keras.layers.Dropout(0.3, name='Dropout_1')(x)

x = keras.layers.Dense(512, activation='relu',
                        kernel_regularizer=regularizers.l2(0.01), name='Dense_2')(x)
x = keras.layers.Dropout(0.3, name='Dropout_2')(x)

x = keras.layers.Dense(256, activation='relu',
                        kernel_regularizer=regularizers.l2(0.01), name='Dense_3')(x)
x = keras.layers.Dropout(0.5, name='Dropout_3')(x)

# Output: 5 trait OCEAN, nilai antara 0-1
output = keras.layers.Dense(5, activation='sigmoid', name='OCEAN_Output')(x)

model = keras.models.Model(inputs=inputs, outputs=output, name='ArcFace_OCEAN_Adam')
keras.utils.plot_model(model, show_shapes=True)

# %%
# ── [Cell 5] Compile Model ─────────────────────────────────────────────────
# CATATAN: Cell ini hanya untuk COMPILE model.
# Untuk evaluation saja (tidak training ulang): run cell ini lalu langsung ke Cell 8.
# Untuk training ulang: run cell ini lalu lanjut ke Cell 6.

import datetime, os
t = datetime.datetime.now().strftime('%m%d_%H%M%S')
optimizer = keras.optimizers.Adam()
model.compile(loss='mse', optimizer=optimizer, metrics=['mae'])

# Checkpoint hanya diperlukan saat training
os.makedirs(f'./weights/faces/{t}', exist_ok=True)
weight_path = f'./weights/faces/{t}/face.h5'
early_stopping = keras.callbacks.EarlyStopping(
    patience=10, verbose=1, restore_best_weights=True
)
check_point = keras.callbacks.ModelCheckpoint(
    filepath=weight_path, monitor='val_mae', mode='min',
    save_best_only=True, save_weights_only=True,
    save_format='h5', verbose=1
)
print(f'Model ter-compile dengan optimizer: Adam')
print(f'(Jika akan training, weights akan disimpan ke: {weight_path})')
# Out:
# Model ter-compile dengan optimizer: Adam
# (Jika akan training, weights akan disimpan ke: ./weights/faces/0424_232646/face.h5)

# %%
history = model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=100,
    callbacks=[early_stopping, check_point]
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - ETA: 0s - loss: 9.9256 - mae: 0.1372
# Epoch 1: val_mae improved from inf to 0.13005, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 29s 3s/step - loss: 9.9256 - mae: 0.1372 - val_loss: 7.9967 - val_mae: 0.1301
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 6.8348 - mae: 0.1345
# Epoch 2: val_mae improved from 0.13005 to 0.12606, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 6.8348 - mae: 0.1345 - val_loss: 5.3984 - val_mae: 0.1261
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 4.5003 - mae: 0.1326
# Epoch 3: val_mae improved from 0.12606 to 0.12439, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 4.5003 - mae: 0.1326 - val_loss: 3.5427 - val_mae: 0.1244
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 2.9887 - mae: 0.1311
# Epoch 4: val_mae improved from 0.12439 to 0.12133, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 2.9887 - mae: 0.1311 - val_loss: 2.2689 - val_mae: 0.1213
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8832 - mae: 0.1295
# Epoch 5: val_mae improved from 0.12133 to 0.12108, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 1.8832 - mae: 0.1295 - val_loss: 1.4250 - val_mae: 0.1211
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 1.1738 - mae: 0.1274
# Epoch 6: val_mae improved from 0.12108 to 0.11887, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 1.1738 - mae: 0.1274 - val_loss: 0.8819 - val_mae: 0.1189
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7329 - mae: 0.1284
# Epoch 7: val_mae improved from 0.11887 to 0.11868, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 26s 3s/step - loss: 0.7329 - mae: 0.1284 - val_loss: 0.5415 - val_mae: 0.1187
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4526 - mae: 0.1263
# Epoch 8: val_mae improved from 0.11868 to 0.11533, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 25s 3s/step - loss: 0.4526 - mae: 0.1263 - val_loss: 0.3319 - val_mae: 0.1153
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2772 - mae: 0.1252
# Epoch 9: val_mae improved from 0.11533 to 0.11324, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 0.2772 - mae: 0.1252 - val_loss: 0.2051 - val_mae: 0.1132
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1799 - mae: 0.1236
# Epoch 10: val_mae improved from 0.11324 to 0.10721, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 0.1799 - mae: 0.1236 - val_loss: 0.1287 - val_mae: 0.1072
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1156 - mae: 0.1222
# Epoch 11: val_mae did not improve from 0.10721
# 8/8 [==============================] - 23s 3s/step - loss: 0.1156 - mae: 0.1222 - val_loss: 0.0839 - val_mae: 0.1101
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0794 - mae: 0.1199
# Epoch 12: val_mae improved from 0.10721 to 0.10248, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0794 - mae: 0.1199 - val_loss: 0.0565 - val_mae: 0.1025
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0571 - mae: 0.1171
# Epoch 13: val_mae improved from 0.10248 to 0.09674, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0571 - mae: 0.1171 - val_loss: 0.0403 - val_mae: 0.0967
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0441 - mae: 0.1124
# Epoch 14: val_mae did not improve from 0.09674
# 8/8 [==============================] - 23s 3s/step - loss: 0.0441 - mae: 0.1124 - val_loss: 0.0309 - val_mae: 0.0983
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0365 - mae: 0.1143
# Epoch 15: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0365 - mae: 0.1143 - val_loss: 0.0267 - val_mae: 0.1040
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0312 - mae: 0.1079
# Epoch 16: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0312 - mae: 0.1079 - val_loss: 0.0237 - val_mae: 0.1013
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0290 - mae: 0.1124
# Epoch 17: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0290 - mae: 0.1124 - val_loss: 0.0217 - val_mae: 0.1058
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0264 - mae: 0.1072
# Epoch 18: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0264 - mae: 0.1072 - val_loss: 0.0219 - val_mae: 0.0992
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0250 - mae: 0.1049
# Epoch 19: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0250 - mae: 0.1049 - val_loss: 0.0201 - val_mae: 0.1025
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0247 - mae: 0.1058
# Epoch 20: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0247 - mae: 0.1058 - val_loss: 0.0216 - val_mae: 0.0984
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0247 - mae: 0.1025
# Epoch 21: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0247 - mae: 0.1025 - val_loss: 0.0196 - val_mae: 0.1053
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0246 - mae: 0.1071
# Epoch 22: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0246 - mae: 0.1071 - val_loss: 0.0228 - val_mae: 0.1059
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0228 - mae: 0.0968
# Epoch 23: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0228 - mae: 0.0968 - val_loss: 0.0236 - val_mae: 0.1121
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0233 - mae: 0.1015
# Epoch 24: val_mae did not improve from 0.09674
# 8/8 [==============================] - 23s 3s/step - loss: 0.0233 - mae: 0.1015 - val_loss: 0.0243 - val_mae: 0.1131
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0238 - mae: 0.1045
# Epoch 25: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0238 - mae: 0.1045 - val_loss: 0.0246 - val_mae: 0.1119
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0232 - mae: 0.1007
# Epoch 26: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0232 - mae: 0.1007 - val_loss: 0.0237 - val_mae: 0.1152
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0245 - mae: 0.1088
# Epoch 27: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0245 - mae: 0.1088 - val_loss: 0.0244 - val_mae: 0.1049
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0244 - mae: 0.1007
# Epoch 28: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0244 - mae: 0.1007 - val_loss: 0.0221 - val_mae: 0.1100
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0233 - mae: 0.1034
# Epoch 29: val_mae did not improve from 0.09674
# 8/8 [==============================] - 22s 3s/step - loss: 0.0233 - mae: 0.1034 - val_loss: 0.0211 - val_mae: 0.0994
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0227 - mae: 0.1007
# Epoch 30: val_mae improved from 0.09674 to 0.09008, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0227 - mae: 0.1007 - val_loss: 0.0185 - val_mae: 0.0901
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0214 - mae: 0.0958
# Epoch 31: val_mae improved from 0.09008 to 0.08977, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0214 - mae: 0.0958 - val_loss: 0.0203 - val_mae: 0.0898
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0229 - mae: 0.0991
# Epoch 32: val_mae did not improve from 0.08977
# 8/8 [==============================] - 22s 3s/step - loss: 0.0229 - mae: 0.0991 - val_loss: 0.0176 - val_mae: 0.0927
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0238 - mae: 0.1043
# Epoch 33: val_mae did not improve from 0.08977
# 8/8 [==============================] - 22s 3s/step - loss: 0.0238 - mae: 0.1043 - val_loss: 0.0185 - val_mae: 0.0948
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0231 - mae: 0.1041
# Epoch 34: val_mae improved from 0.08977 to 0.08660, saving model to ./weights/faces/0424_232646\face.h5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0231 - mae: 0.1041 - val_loss: 0.0201 - val_mae: 0.0866
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0219 - mae: 0.0952
# Epoch 35: val_mae did not improve from 0.08660
# 8/8 [==============================] - 22s 3s/step - loss: 0.0219 - mae: 0.0952 - val_loss: 0.0184 - val_mae: 0.0975
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0215 - mae: 0.0977
# Epoch 36: val_mae did not improve from 0.08660
# 8/8 [==============================] - 22s 3s/step - loss: 0.0215 - mae: 0.0977 - val_loss: 0.0190 - val_mae: 0.0909
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0224 - mae: 0.0984
# Epoch 37: val_mae did not improve from 0.08660
# 8/8 [==============================] - 22s 3s/step - loss: 0.0224 - mae: 0.0984 - val_loss: 0.0197 - val_mae: 0.0898
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0212 - mae: 0.0973
# Epoch 38: val_mae did not improve from 0.08660
# 8/8 [==============================] - 22s 3s/step - loss: 0.0212 - mae: 0.0973 - val_loss: 0.0191 - val_mae: 0.0903
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0205 - mae: 0.0919
# Epoch 39: val_mae did not improve from 0.08660
# 8/8 [==============================] - 22s 3s/step - loss: 0.0205 - mae: 0.0919 - val_loss: 0.0194 - val_mae: 0.0921
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0217 - mae: 0.0979
# Epoch 40: val_mae did not improve from 0.08660
# 8/8 [==============================] - 22s 3s/step - loss: 0.0217 - mae: 0.0979 - val_loss: 0.0215 - val_mae: 0.0950
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0206 - mae: 0.0915
# Epoch 41: val_mae did not improve from 0.08660
# 8/8 [==============================] - 22s 3s/step - loss: 0.0206 - mae: 0.0915 - val_loss: 0.0203 - val_mae: 0.0974
# Epoch 42/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0210 - mae: 0.0961Restoring model weights from the end of the best epoch: 32.
#
# Epoch 42: val_mae did not improve from 0.08660
# 8/8 [==============================] - 22s 3s/step - loss: 0.0210 - mae: 0.0961 - val_loss: 0.0193 - val_mae: 0.0916
# Epoch 42: early stopping

# %% [markdown]
# ### Load weights

# %%
# ── [Cell 8] Load Weights untuk Evaluation ─────────────────────────────────
# Load weights hasil training terbaik Adam (epoch 24, val_mae=0.0878).
# Gunakan cell ini untuk evaluation tanpa training ulang.

# BEST_WEIGHT_PATH = 'weights/faces/0410_095054/face.h5'  # hasil training Adam

# # Compile ulang sebelum load (antisipasi jika Cell 5 tidak dirun)
# model.compile(loss='mse', optimizer=keras.optimizers.Adam(), metrics=['mae'])

# model.load_weights(BEST_WEIGHT_PATH)
# print(f'Weights berhasil di-load dari: {BEST_WEIGHT_PATH}')
# print('Model siap untuk evaluation.')

# %%
# ── [Cell 8b] Simpan full model untuk deployment Flask ─────────────────────
# Jalankan setelah training selesai ATAU setelah load weights dari Cell 8.
import os
full_model_path = 'weights/faces/0424_232646/face_full_model.h5'
model.save(full_model_path)
print(f'Full model disimpan ke: {full_model_path}')
print('Gunakan di Flask: keras.models.load_model(path)')
# Out:
# Full model disimpan ke: weights/faces/0424_232646/face_full_model.h5
# Gunakan di Flask: keras.models.load_model(path)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training data

# %%
train_ds = tf.data.Dataset.load(r'data\videoface_100\train_ds')
loss, mae = model.evaluate(train_ds)
(1-mae)*100
# Out:
# 8/8 [==============================] - 17s 2s/step - loss: 0.0213 - mae: 0.0980
# 90.2001641690731

# %%
y_true = np.concatenate([y for x,y in train_ds])
y_pred = model.predict(train_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 8/8 [==============================] - 18s 2s/step
# (array([90.403114, 88.701355, 90.18082 , 91.69526 , 90.02028 ],
#        dtype=float32),
#  90.20016342401505)

# %% [markdown]
# ### Validation data

# %%
valid_ds = tf.data.Dataset.load(r'data\videoface_100\val_ds')
loss, mae = model.evaluate(valid_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 6s 2s/step - loss: 0.0176 - mae: 0.0927
# 90.72500243782997

# %%
y_true = np.concatenate([y for x,y in valid_ds])
y_pred = model.predict(valid_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 6s 2s/step
# (array([90.90079, 89.36024, 91.68883, 92.26067, 89.4145 ], dtype=float32),
#  90.72500318288803)

# %% [markdown]
# ### Test data

# %%
test_ds = tf.data.Dataset.load(r'data\videoface_100\test_ds')
loss, mae = model.evaluate(test_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 6s 2s/step - loss: 0.0228 - mae: 0.1099
# 89.01348263025284

# %%
y_true = np.concatenate([y for x,y in test_ds])
y_pred = model.predict(test_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 6s 2s/step
# (array([90.65943 , 87.86324 , 89.14263 , 89.79736 , 87.604744],
#        dtype=float32),
#  89.01348263025284)

# %%
import matplotlib.pyplot as plt

# 1) Plot Loss
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'],    label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# 2) Plot MAE (atau metric lain yang kamu pakai)
plt.figure(figsize=(8,4))
plt.plot(history.history['mae'],     label='train_mae')
plt.plot(history.history['val_mae'], label='val_mae')
plt.title('Training & Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## Evaluasi Tambahan

# %%
# ── [Eval 1] Tabel Ringkasan Per Trait OCEAN ─────────────────────────────
import pandas as pd

TRAITS = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']

def compute_summary(ds):
    y_true_list, y_pred_list = [], []
    for x_batch, y_batch in ds:
        y_true_list.append(y_batch.numpy())
        y_pred_list.append(model.predict(x_batch, verbose=0))
    yt = np.vstack(y_true_list)
    yp = np.vstack(y_pred_list)
    mae = np.abs(yt - yp).mean(axis=0)
    acc = (1 - mae) * 100
    return mae, acc

train_ds_e = tf.data.Dataset.load(r'data\\videoface_100\\train_ds')
valid_ds_e = tf.data.Dataset.load(r'data\\videoface_100\\val_ds')
test_ds_e  = tf.data.Dataset.load(r'data\\videoface_100\\test_ds')

mae_tr, acc_tr = compute_summary(train_ds_e)
mae_vl, acc_vl = compute_summary(valid_ds_e)
mae_te, acc_te = compute_summary(test_ds_e)

rows = []
for i, trait in enumerate(TRAITS):
    rows.append({'Trait': trait,
                 'MAE Train': f'{mae_tr[i]:.4f}', 'Acc Train (%)': f'{acc_tr[i]:.2f}',
                 'MAE Val'  : f'{mae_vl[i]:.4f}', 'Acc Val (%)'  : f'{acc_vl[i]:.2f}',
                 'MAE Test' : f'{mae_te[i]:.4f}', 'Acc Test (%)' : f'{acc_te[i]:.2f}'})
rows.append({'Trait': 'RATA-RATA',
             'MAE Train': f'{mae_tr.mean():.4f}', 'Acc Train (%)': f'{acc_tr.mean():.2f}',
             'MAE Val'  : f'{mae_vl.mean():.4f}', 'Acc Val (%)'  : f'{acc_vl.mean():.2f}',
             'MAE Test' : f'{mae_te.mean():.4f}', 'Acc Test (%)' : f'{acc_te.mean():.2f}'})

df_summary = pd.DataFrame(rows).set_index('Trait')
print('\n=== Tabel Ringkasan Evaluasi Per Trait OCEAN ===')
print(df_summary.to_string())
df_summary
# Out:
# === Tabel Ringkasan Evaluasi Per Trait OCEAN ===
#                   MAE Train Acc Train (%) MAE Val Acc Val (%) MAE Test Acc Test (%)
# Trait
# Openness             0.0960         90.40  0.0910       90.90   0.0934        90.66
# Conscientiousness    0.1130         88.70  0.1064       89.36   0.1214        87.86
# Extraversion         0.0982         90.18  0.0831       91.69   0.1086        89.14
# Agreeableness        0.0830         91.70  0.0774       92.26   0.1020        89.80
# Neuroticism          0.0998         90.02  0.1059       89.41   0.1240        87.60
# RATA-RATA            0.0980         90.20  0.0927       90.72   0.1099        89.01
#                   MAE Train Acc Train (%) MAE Val Acc Val (%) MAE Test  \
# Trait
# Openness             0.0960         90.40  0.0910       90.90   0.0934
# Conscientiousness    0.1130         88.70  0.1064       89.36   0.1214
# Extraversion         0.0982         90.18  0.0831       91.69   0.1086
# Agreeableness        0.0830         91.70  0.0774       92.26   0.1020
# Neuroticism          0.0998         90.02  0.1059       89.41   0.1240
# RATA-RATA            0.0980         90.20  0.0927       90.72   0.1099
#
#                   Acc Test (%)
# Trait
# Openness                 90.66
# Conscientiousness        87.86
# Extraversion             89.14
# Agreeableness            89.80
# Neuroticism              87.60
# RATA-RATA                89.01

# %%
# ── [Eval 2] Scatter Plot: Prediksi vs Ground Truth (Test Data) ───────────
import matplotlib.pyplot as plt

test_ds_sc = tf.data.Dataset.load(r'data\\videoface_100\\test_ds')
y_true_all = np.concatenate([y.numpy() for _, y in test_ds_sc])
y_pred_all = model.predict(test_ds_sc, verbose=0)

fig, axes = plt.subplots(1, 5, figsize=(20, 4))
fig.suptitle('Scatter Plot - Adam (Test Data)', fontsize=13, fontweight='bold')

for i, (ax, trait) in enumerate(zip(axes, TRAITS)):
    yt = y_true_all[:, i]; yp = y_pred_all[:, i]
    ax.scatter(yt, yp, alpha=0.4, s=15, color='steelblue')
    lims = [min(yt.min(), yp.min()), max(yt.max(), yp.max())]
    ax.plot(lims, lims, 'r--', linewidth=1.5, label='Ideal')
    ax.set_title(trait, fontweight='bold'); ax.set_xlabel('Ground Truth'); ax.set_ylabel('Prediksi')
    ax.set_xlim(0, 1); ax.set_ylim(0, 1); ax.legend(fontsize=8)
    ax.text(0.05, 0.92, f'MAE={np.abs(yt-yp).mean():.3f}', transform=ax.transAxes, fontsize=9, color='darkred')

plt.tight_layout()
plt.savefig('scatter_adam.png', dpi=120, bbox_inches='tight')
plt.show()

# %%
# ── [Eval 3] Histogram: Distribusi Prediksi vs Ground Truth ───────────────
fig, axes = plt.subplots(1, 5, figsize=(20, 4))
fig.suptitle('Distribusi Prediksi vs GT - Adam', fontsize=13, fontweight='bold')

for i, (ax, trait) in enumerate(zip(axes, TRAITS)):
    ax.hist(y_true_all[:, i], bins=20, alpha=0.5, color='royalblue', label='Ground Truth', density=True)
    ax.hist(y_pred_all[:, i], bins=20, alpha=0.5, color='tomato',    label='Prediksi',     density=True)
    ax.set_title(trait, fontweight='bold'); ax.set_xlabel('Nilai (0-1)'); ax.set_ylabel('Densitas')
    ax.legend(fontsize=8); ax.set_xlim(0, 1)

plt.tight_layout()
plt.savefig('histogram_adam.png', dpi=120, bbox_inches='tight')
plt.show()
print('CATATAN: Jika prediksi menumpuk di satu titik -> model STUCK.')
# Out:
# CATATAN: Jika prediksi menumpuk di satu titik -> model STUCK.

# %%
# ── [Eval 4] Training Summary ───────────────────────────────────────────────
val_maes   = history.history['val_mae']
best_epoch = int(np.argmin(val_maes)) + 1
best_val   = min(val_maes)
last_epoch = len(val_maes)

print('=' * 45)
print('         TRAINING SUMMARY')
print('=' * 45)
print('  Notebook        : 02_Face_Optimizer_Adam')
print('  Optimizer       : Adam')
print(f'  Total Epoch     : {last_epoch}')
print(f'  Best Epoch      : {best_epoch}')
print(f'  Best Val MAE    : {best_val:.4f}')
print(f'  Best Val Acc    : {(1-best_val)*100:.2f}%')
print(f'  Test MAE (rata) : {mae_te.mean():.4f}')
print(f'  Test Acc (rata) : {acc_te.mean():.2f}%')
print('=' * 45)
print()
print('Per Trait Test Accuracy:')
for trait, acc in zip(TRAITS, acc_te):
    bar = '#' * int(acc / 5)
    print(f'  {trait:18s}: {acc:5.2f}% |{bar}')
# Out:
# =============================================
#          TRAINING SUMMARY
# =============================================
#   Notebook        : 02_Face_Optimizer_Adam
#   Optimizer       : Adam
#   Total Epoch     : 42
#   Best Epoch      : 34
#   Best Val MAE    : 0.0866
#   Best Val Acc    : 91.34%
#   Test MAE (rata) : 0.1099
#   Test Acc (rata) : 89.01%
# =============================================
#
# Per Trait Test Accuracy:
#   Openness          : 90.66% |##################
#   Conscientiousness : 87.86% |#################
#   Extraversion      : 89.14% |#################
#   Agreeableness     : 89.80% |#################
#   Neuroticism       : 87.60% |#################
