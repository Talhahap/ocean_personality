# %%
import tensorflow as tf 
from tensorflow import keras 
import tensorflow_addons as tfa
import tensorflow_hub as hub 
from sklearn.metrics import mean_absolute_error 
import numpy as np 
import datetime
from deepface import DeepFace
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten,
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    BatchNormalization,
    PReLU,  # <-- DITAMBAHKAN: Impor PReLU yang hilang
)
import os
import warnings

# Ignore irrelevant warning messages for cleaner output
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %% [markdown]
# Load Arcface

# %%
from deepface import DeepFace
import keras

# Load ArcFace model dari DeepFace
print("Loading ArcFace model...")
try:
    arcface_client = DeepFace.build_model('ArcFace')
    # Akses model Keras yang sebenarnya
    arcface_model = arcface_client.model
    print("✓ ArcFace model loaded successfully")
except Exception as e:
    print(f"✗ Error loading ArcFace model: {e}")
    raise

# Set model tidak dapat dilatih (frozen)
arcface_model.trainable = False

# Cetak summary ArcFace model
print("\n" + "="*80)
print("ARCFACE BASE MODEL ARCHITECTURE")
print("="*80)
arcface_model.summary()
print(f"\nArcFace Input Shape: {arcface_model.input_shape}")
print(f"ArcFace Output Shape: {arcface_model.output_shape}")
print(f"ArcFace Embedding Dimension: {arcface_model.output_shape[-1]}")

# Buat model transfer learning dengan ArcFace
print("\n" + "="*80)
print("BUILDING TRANSFER LEARNING MODEL WITH ARCFACE")
print("="*80)

try:
    inputs = keras.layers.Input(shape=(10, 112, 112, 3), name='Input')
    print(f"✓ Input layer created: {inputs.shape}")
    
    x = keras.layers.TimeDistributed(keras.layers.Rescaling(scale=1./255.0), name='Rescaling')(inputs)
    print(f"✓ Rescaling layer added: {x.shape}")
    
    x = keras.layers.TimeDistributed(arcface_model, name='ArcFace_TimeDistributed')(x)
    print(f"✓ ArcFace TimeDistributed layer added: {x.shape}")
    
    x = keras.layers.LSTM(units=128, return_sequences=True, name='LSTM_1')(x)
    print(f"✓ LSTM_1 layer added: {x.shape}")
    
    x = keras.layers.LSTM(units=64, name='LSTM_2')(x)
    print(f"✓ LSTM_2 layer added: {x.shape}")
    
    x = keras.layers.Dropout(0.2, name='Dropout_1')(x)
    print(f"✓ Dropout_1 layer added: {x.shape}")
    
    x = keras.layers.Dense(units=1024, name='Dense_1024')(x)
    print(f"✓ Dense_1024 layer added: {x.shape}")
    
    x = keras.layers.Dense(units=512, activation='relu', name='Dense_512')(x)
    print(f"✓ Dense_512 layer added: {x.shape}")
    
    x = keras.layers.Dense(256, activation='relu', name='Dense_256')(x)
    print(f"✓ Dense_256 layer added: {x.shape}")
    
    x = keras.layers.Dropout(0.5, name='Dropout_2')(x)
    print(f"✓ Dropout_2 layer added: {x.shape}")
    
    x = keras.layers.Dense(5, activation='sigmoid', name='Output')(x)
    print(f"✓ Output layer added: {x.shape}")
    
    model = keras.models.Model(inputs=inputs, outputs=x, name='ArcFace_Transfer_Learning')
    print("✓ Model compiled successfully\n")
    
except Exception as e:
    print(f"✗ Error building model: {e}")
    import traceback
    traceback.print_exc()
    raise

# Cetak summary model lengkap
print("\n" + "="*80)
print("COMPLETE TRANSFER LEARNING MODEL ARCHITECTURE")
print("="*80)
model.summary()

# Visualisasi model
print("\n" + "="*80)
print("GENERATING MODEL VISUALIZATION")
print("="*80)
try:
    keras.utils.plot_model(
        model, 
        to_file='arcface_transfer_learning_model.png', 
        show_shapes=True, 
        show_layer_names=True, 
        rankdir='TB', 
        expand_nested=True, 
        dpi=96
    )
    print("✓ Model diagram saved as 'arcface_transfer_learning_model.png'")
except Exception as e:
    print(f"✗ Error generating visualization: {e}")
    print("  (This is optional - model is still usable)")

# Informasi tambahan
print("\n" + "="*80)
print("MODEL INFORMATION SUMMARY")
print("="*80)

total_params = model.count_params()
trainable_params = sum([keras.backend.count_params(w) for w in model.trainable_weights])
non_trainable_params = sum([keras.backend.count_params(w) for w in model.non_trainable_weights])

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Non-trainable parameters (frozen ArcFace): {non_trainable_params:,}")
print(f"Percentage trainable: {(trainable_params/total_params)*100:.2f}%")

print(f"\nInput shape: {model.input_shape}")
print(f"Output shape: {model.output_shape}")
print(f"\nModel expects:")
print(f"  - Batch of 10 frames per sequence")
print(f"  - Each frame: 112x112x3 (RGB)")
print(f"  - Output: 5 classes with sigmoid activation")

print("\n" + "="*80)
print("LAYER-BY-LAYER OUTPUT SHAPES")
print("="*80)
for i, layer in enumerate(model.layers, 1):
    trainable_status = "Yes" if layer.trainable else "No"
    print(f"{i:2d}. {layer.name:35s} -> {str(layer.output_shape):30s} | Trainable: {trainable_status}")

# Informasi khusus ArcFace
print("\n" + "="*80)
print("ARCFACE MODEL DETAILS")
print("="*80)
print(f"ArcFace layers: {len(arcface_model.layers)}")
print(f"ArcFace parameters: {arcface_model.count_params():,}")
print(f"All ArcFace layers frozen: {not arcface_model.trainable}")

print("\n✓ Model setup complete and ready for training!")
# Out:
# Loading ArcFace model...
# ✓ ArcFace model loaded successfully
#
# ================================================================================
# ARCFACE BASE MODEL ARCHITECTURE
# ================================================================================
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 112, 112, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 114, 114, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         1728      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_prelu (PReLU)         (None, 112, 112, 64)         64        ['conv1_bn[0][0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 112, 112, 64)         256       ['conv1_prelu[0][0]']
#  rmalization)
#
#  conv2_block1_1_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_bn[0][0]']
#  dding2D)
#
#  conv2_block1_1_conv (Conv2  (None, 112, 112, 64)         36864     ['conv2_block1_1_pad[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 112, 112, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_prelu (PReL  (None, 112, 112, 64)         64        ['conv2_block1_2_bn[0][0]']
#  U)
#
#  conv2_block1_2_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 64)           4096      ['conv1_prelu[0][0]']
#  D)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_add[0][0]']
#  rmalization)
#
#  conv2_block2_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_bn[0][0]']
#  dding2D)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_1_pad[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block2_2_bn[0][0]']
#  U)
#
#  conv2_block2_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_add[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_add[0][0]']
#  rmalization)
#
#  conv2_block3_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_bn[0][0]']
#  dding2D)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_1_pad[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block3_2_bn[0][0]']
#  U)
#
#  conv2_block3_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_2_pad[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 64)           0         ['conv2_block2_add[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_add[0][0]']
#  rmalization)
#
#  conv3_block1_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv3_block1_1_bn[0][0]']
#  dding2D)
#
#  conv3_block1_1_conv (Conv2  (None, 56, 56, 128)          73728     ['conv3_block1_1_pad[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 56, 56, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_prelu (PReL  (None, 56, 56, 128)          128       ['conv3_block1_2_bn[0][0]']
#  U)
#
#  conv3_block1_2_pad (ZeroPa  (None, 58, 58, 128)          0         ['conv3_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 128)          8192      ['conv2_block3_add[0][0]']
#  D)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_add[0][0]']
#  rmalization)
#
#  conv3_block2_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_bn[0][0]']
#  dding2D)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_1_pad[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block2_2_bn[0][0]']
#  U)
#
#  conv3_block2_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_add[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_add[0][0]']
#  rmalization)
#
#  conv3_block3_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_bn[0][0]']
#  dding2D)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_1_pad[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block3_2_bn[0][0]']
#  U)
#
#  conv3_block3_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 128)          0         ['conv3_block2_add[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_add[0][0]']
#  rmalization)
#
#  conv3_block4_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_bn[0][0]']
#  dding2D)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_1_pad[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block4_2_bn[0][0]']
#  U)
#
#  conv3_block4_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_2_pad[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 128)          0         ['conv3_block3_add[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_add[0][0]']
#  rmalization)
#
#  conv4_block1_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv4_block1_1_bn[0][0]']
#  dding2D)
#
#  conv4_block1_1_conv (Conv2  (None, 28, 28, 256)          294912    ['conv4_block1_1_pad[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_prelu (PReL  (None, 28, 28, 256)          256       ['conv4_block1_2_bn[0][0]']
#  U)
#
#  conv4_block1_2_pad (ZeroPa  (None, 30, 30, 256)          0         ['conv4_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 256)          32768     ['conv3_block4_add[0][0]']
#  D)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block1_2_pad[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_add[0][0]']
#  rmalization)
#
#  conv4_block2_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  dding2D)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_1_pad[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block2_2_bn[0][0]']
#  U)
#
#  conv4_block2_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_2_pad[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_add[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_add[0][0]']
#  rmalization)
#
#  conv4_block3_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  dding2D)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_1_pad[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block3_2_bn[0][0]']
#  U)
#
#  conv4_block3_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_2_pad[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 256)          0         ['conv4_block2_add[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_add[0][0]']
#  rmalization)
#
#  conv4_block4_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  dding2D)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_1_pad[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block4_2_bn[0][0]']
#  U)
#
#  conv4_block4_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_2_pad[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 256)          0         ['conv4_block3_add[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_add[0][0]']
#  rmalization)
#
#  conv4_block5_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_bn[0][0]']
#  dding2D)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_1_pad[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block5_2_bn[0][0]']
#  U)
#
#  conv4_block5_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_2_pad[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 256)          0         ['conv4_block4_add[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_add[0][0]']
#  rmalization)
#
#  conv4_block6_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_bn[0][0]']
#  dding2D)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_1_pad[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block6_2_bn[0][0]']
#  U)
#
#  conv4_block6_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_2_pad[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 256)          0         ['conv4_block5_add[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv5_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_add[0][0]']
#  rmalization)
#
#  conv5_block1_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv5_block1_1_bn[0][0]']
#  dding2D)
#
#  conv5_block1_1_conv (Conv2  (None, 14, 14, 512)          1179648   ['conv5_block1_1_pad[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 14, 14, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_prelu (PReL  (None, 14, 14, 512)          512       ['conv5_block1_2_bn[0][0]']
#  U)
#
#  conv5_block1_2_pad (ZeroPa  (None, 16, 16, 512)          0         ['conv5_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 512)            131072    ['conv4_block6_add[0][0]']
#  D)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block1_2_pad[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_add[0][0]']
#  rmalization)
#
#  conv5_block2_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_bn[0][0]']
#  dding2D)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_1_pad[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block2_2_bn[0][0]']
#  U)
#
#  conv5_block2_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_2_pad[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_add[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_add[0][0]']
#  rmalization)
#
#  conv5_block3_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_bn[0][0]']
#  dding2D)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_1_pad[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block3_2_bn[0][0]']
#  U)
#
#  conv5_block3_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_2_pad[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 512)            0         ['conv5_block2_add[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  batch_normalization (Batch  (None, 7, 7, 512)            2048      ['conv5_block3_add[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 7, 7, 512)            0         ['batch_normalization[0][0]']
#
#  flatten (Flatten)           (None, 25088)                0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 512)                  1284556   ['flatten[0][0]']
#                                                           8
#
#  embedding (BatchNormalizat  (None, 512)                  2048      ['dense[0][0]']
#  ion)
#
# ==================================================================================================
# Total params: 34165184 (130.33 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 34165184 (130.33 MB)
# __________________________________________________________________________________________________
#
# ArcFace Input Shape: (None, 112, 112, 3)
# ArcFace Output Shape: (None, 512)
# ArcFace Embedding Dimension: 512
#
# ================================================================================
# BUILDING TRANSFER LEARNING MODEL WITH ARCFACE
# ================================================================================
# ✓ Input layer created: (None, 10, 112, 112, 3)
# ✓ Rescaling layer added: (None, 10, 112, 112, 3)
# ✓ ArcFace TimeDistributed layer added: (None, 10, 512)
# ✓ LSTM_1 layer added: (None, 10, 128)
# ✓ LSTM_2 layer added: (None, 64)
# ✓ Dropout_1 layer added: (None, 64)
# ✓ Dense_1024 layer added: (None, 1024)
# ✓ Dense_512 layer added: (None, 512)
# ✓ Dense_256 layer added: (None, 256)
# ✓ Dropout_2 layer added: (None, 256)
# ✓ Output layer added: (None, 5)
# ✓ Model compiled successfully
#
#
# ================================================================================
# COMPLETE TRANSFER LEARNING MODEL ARCHITECTURE
# ================================================================================
# Model: "ArcFace_Transfer_Learning"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 10, 112, 112, 3   0
#                              )]
#
#  Rescaling (TimeDistributed  (None, 10, 112, 112, 3)   0
#  )
#
#  ArcFace_TimeDistributed (T  (None, 10, 512)           34165184
#  imeDistributed)
#
#  LSTM_1 (LSTM)               (None, 10, 128)           328192
#
#  LSTM_2 (LSTM)               (None, 64)                49408
#
#  Dropout_1 (Dropout)         (None, 64)                0
#
#  Dense_1024 (Dense)          (None, 1024)              66560
#
#  Dense_512 (Dense)           (None, 512)               524800
#
#  Dense_256 (Dense)           (None, 256)               131328
#
#  Dropout_2 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 5)                 1285
#
# =================================================================
# Total params: 35266757 (134.53 MB)
# Trainable params: 1101573 (4.20 MB)
# Non-trainable params: 34165184 (130.33 MB)
# _________________________________________________________________
#
# ================================================================================
# GENERATING MODEL VISUALIZATION
# ================================================================================
# ✓ Model diagram saved as 'arcface_transfer_learning_model.png'
#
# ================================================================================
# MODEL INFORMATION SUMMARY
# ================================================================================
# Total parameters: 35,266,757
# Trainable parameters: 1,101,573
# Non-trainable parameters (frozen ArcFace): 34,165,184
# Percentage trainable: 3.12%
#
# Input shape: (None, 10, 112, 112, 3)
# Output shape: (None, 5)
#
# Model expects:
#   - Batch of 10 frames per sequence
#   - Each frame: 112x112x3 (RGB)
#   - Output: 5 classes with sigmoid activation
#
# ================================================================================
# LAYER-BY-LAYER OUTPUT SHAPES
# ================================================================================
#  1. Input                               -> [(None, 10, 112, 112, 3)]      | Trainable: Yes
#  2. Rescaling                           -> (None, 10, 112, 112, 3)        | Trainable: Yes
#  3. ArcFace_TimeDistributed             -> (None, 10, 512)                | Trainable: Yes
#  4. LSTM_1                              -> (None, 10, 128)                | Trainable: Yes
#  5. LSTM_2                              -> (None, 64)                     | Trainable: Yes
#  6. Dropout_1                           -> (None, 64)                     | Trainable: Yes
#  7. Dense_1024                          -> (None, 1024)                   | Trainable: Yes
#  8. Dense_512                           -> (None, 512)                    | Trainable: Yes
#  9. Dense_256                           -> (None, 256)                    | Trainable: Yes
# 10. Dropout_2                           -> (None, 256)                    | Trainable: Yes
# 11. Output                              -> (None, 5)                      | Trainable: Yes
#
# ================================================================================
# ARCFACE MODEL DETAILS
# ================================================================================
# ArcFace layers: 162
# ArcFace parameters: 34,165,184
# All ArcFace layers frozen: True
#
# ✓ Model setup complete and ready for training!

# %% [markdown]
# ### Load data

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//ocean-project-deepface-20250529T023947Z-1-001//ocean-project-deepface//data//videoface//train_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//ocean-project-deepface-20250529T023947Z-1-001//ocean-project-deepface//data//videoface//val_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds, valid_ds
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>)

# %% [markdown]
# ### Compile model

# %%
t = datetime.datetime.now().strftime("%m%d_%H%M%S")

# optimizer = keras.optimizers.Adam(learning_rate=0.001)
# optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
optimizer = tfa.optimizers.RectifiedAdam(learning_rate=0.001)

early_stopping = keras.callbacks.EarlyStopping(patience=10, verbose=0)
check_point    = keras.callbacks.ModelCheckpoint(filepath='./weights/faces/'+str(t)+'/face.t5',
                            monitor='val_mae',
                            mode='min',
                            save_best_only=True,
                            save_weights_only=True,
                            verbose=0)

model.compile(loss='mse', optimizer=optimizer, metrics=['mae'])

# %% [markdown]
# ### Train

# %%
history = model.fit(train_ds, validation_data=valid_ds, batch_size=8, epochs=100, callbacks=[early_stopping, check_point])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 28s 3s/step - loss: 0.2502 - mae: 0.5001 - val_loss: 0.2503 - val_mae: 0.5002
# Epoch 2/100
# 8/8 [==============================] - 20s 3s/step - loss: 0.2429 - mae: 0.4926 - val_loss: 0.2396 - val_mae: 0.4894
# Epoch 3/100
# 8/8 [==============================] - 21s 3s/step - loss: 0.2256 - mae: 0.4744 - val_loss: 0.2193 - val_mae: 0.4679
# Epoch 4/100
# 8/8 [==============================] - 21s 3s/step - loss: 0.1905 - mae: 0.4344 - val_loss: 0.1711 - val_mae: 0.4115
# Epoch 5/100
# 8/8 [==============================] - 21s 3s/step - loss: 0
100
# 8/8 [==============================] - 22s 3s/step - loss: 3.3097e-07 - mae: 1.7963e-04 - val_loss: 3.2250e-08 - val_mae: 9.2232e-05
# Epoch 94/100
# 8/8 [==============================] - 22s 3s/step - loss: 3.0168e-06 - mae: 2.8745e-04 - val_loss: 3.1599e-08 - val_mae: 9.1209e-05
# Epoch 95/100
# 8/8 [==============================] - 22s 3s/step - loss: 4.6965e-07 - mae: 1.9455e-04 - val_loss: 3.0491e-08 - val_mae: 8.9251e-05
# Epoch 96/100
# 8/8 [==============================] - 22s 3s/step - loss: 1.0914e-06 - mae: 2.2504e-04 - val_loss: 2.9587e-08 - val_mae: 8.7673e-05
# Epoch 97/100
# 8/8 [==============================] - 22s 3s/step - loss: 1.6845e-05 - mae: 5.4126e-04 - val_loss: 2.7759e-08 - val_mae: 8.4106e-05
# Epoch 98/100
# 8/8 [==============================] - 22s 3s/step - loss: 3.4053e-07 - mae: 1.4523e-04 - val_loss: 2.4945e-08 - val_mae: 7.8284e-05
# Epoch 99/100
# 8/8 [==============================] - 22s 3s/step - loss: 3.2010e-06 - mae: 2.2282e-04 - val_loss: 2.3367e-08 - val_mae: 7.5310e-05
# Epoch 100/100
# 8/8 [==============================] - 22s 3s/step - loss: 3.6286e-06 - mae: 2.5655e-04 - val_loss: 2.0669e-08 - val_mae: 7.1293e-05

# %% [markdown]
# ### Load weights

# %%
model.load_weights('./weights/faces/1010_001412/face.t5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training data

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//ocean-project-deepface-20250529T023947Z-1-001//ocean-project-deepface//data//videoface//train_ds') 
loss, mae = model.evaluate(train_ds)
(1-mae)*100
# Out:
# 8/8 [==============================] - 16s 2s/step - loss: 2.6114e-09 - mae: 2.3986e-05
# 99.9976014083586

# %%
y_true = np.concatenate([y for x,y in train_ds])
y_pred = model.predict(train_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 8/8 [==============================] - 17s 2s/step
# (array([99.99846, 99.99408, 99.99875, 99.99883, 99.99789], dtype=float32),
#  99.9976014083586)

# %% [markdown]
# ### Validation data

# %%
valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//ocean-project-deepface-20250529T023947Z-1-001//ocean-project-deepface//data//videoface//val_ds') 
loss, mae = model.evaluate(valid_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 2.0669e-08 - mae: 7.1293e-05
# 99.99287067330442

# %%
y_true = np.concatenate([y for x,y in valid_ds])
y_pred = model.predict(valid_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 6s 2s/step
# (array([99.99512, 99.98353, 99.99586, 99.99623, 99.99361], dtype=float32),
#  99.99287067257683)

# %% [markdown]
# ### Test data

# %%
test_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//ocean-project-deepface-20250529T023947Z-1-001//ocean-project-deepface//data//videoface//test_ds')
loss, mae = model.evaluate(test_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 2.2084e-08 - mae: 6.8221e-05
# 99.99317788387998

# %%
y_true = np.concatenate([y for x,y in test_ds])
y_pred = model.predict(test_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 5s 1s/step
# (array([99.99527 , 99.98451 , 99.99606 , 99.99629 , 99.993744],
#        dtype=float32),
#  99.99317788315238)

# %%
from utils import loss_val_graph

# Tampilkan grafik training vs validation
loss_val_graph(history)
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from utils import loss_val_graph
#       3 # Tampilkan grafik training vs validation
# ----> 4 loss_val_graph(history)
#
# NameError: name 'history' is not defined
