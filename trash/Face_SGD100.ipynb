# %%
import tensorflow as tf 
from tensorflow import keras 
import tensorflow_addons as tfa
import tensorflow_hub as hub 
from sklearn.metrics import mean_absolute_error 
import numpy as np 
import datetime
from deepface import DeepFace
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten,
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    BatchNormalization,
    PReLU,  # <-- DITAMBAHKAN: Impor PReLU yang hilang
)
import os
import warnings

# Ignore irrelevant warning messages for cleaner output
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# c:\Users\ALFIAN\anaconda3\envs\env_insightface\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %% [markdown]
# Load Arcface

# %%
from deepface import DeepFace
import keras

# Load ArcFace model dari DeepFace
print("Loading ArcFace model...")
try:
    arcface_client = DeepFace.build_model('ArcFace')
    # Akses model Keras yang sebenarnya
    arcface_model = arcface_client.model
    print("✓ ArcFace model loaded successfully")
except Exception as e:
    print(f"✗ Error loading ArcFace model: {e}")
    raise

# Set model tidak dapat dilatih (frozen)
arcface_model.trainable = False

# Cetak summary ArcFace model
print("\n" + "="*80)
print("ARCFACE BASE MODEL ARCHITECTURE")
print("="*80)
arcface_model.summary()
print(f"\nArcFace Input Shape: {arcface_model.input_shape}")
print(f"ArcFace Output Shape: {arcface_model.output_shape}")
print(f"ArcFace Embedding Dimension: {arcface_model.output_shape[-1]}")

# Buat model transfer learning dengan ArcFace
print("\n" + "="*80)
print("BUILDING TRANSFER LEARNING MODEL WITH ARCFACE")
print("="*80)

try:
    inputs = keras.layers.Input(shape=(10, 112, 112, 3), name='Input')
    print(f"✓ Input layer created: {inputs.shape}")
    
    x = keras.layers.TimeDistributed(keras.layers.Rescaling(scale=1./255.0), name='Rescaling')(inputs)
    print(f"✓ Rescaling layer added: {x.shape}")
    
    x = keras.layers.TimeDistributed(arcface_model, name='ArcFace_TimeDistributed')(x)
    print(f"✓ ArcFace TimeDistributed layer added: {x.shape}")
    
    x = keras.layers.LSTM(units=128, return_sequences=True, name='LSTM_1')(x)
    print(f"✓ LSTM_1 layer added: {x.shape}")
    
    x = keras.layers.LSTM(units=64, name='LSTM_2')(x)
    print(f"✓ LSTM_2 layer added: {x.shape}")
    
    x = keras.layers.Dropout(0.2, name='Dropout_1')(x)
    print(f"✓ Dropout_1 layer added: {x.shape}")
    
    x = keras.layers.Dense(units=1024, name='Dense_1024')(x)
    print(f"✓ Dense_1024 layer added: {x.shape}")
    
    x = keras.layers.Dense(units=512, activation='relu', name='Dense_512')(x)
    print(f"✓ Dense_512 layer added: {x.shape}")
    
    x = keras.layers.Dense(256, activation='relu', name='Dense_256')(x)
    print(f"✓ Dense_256 layer added: {x.shape}")
    
    x = keras.layers.Dropout(0.5, name='Dropout_2')(x)
    print(f"✓ Dropout_2 layer added: {x.shape}")
    
    x = keras.layers.Dense(5, activation='sigmoid', name='Output')(x)
    print(f"✓ Output layer added: {x.shape}")
    
    model = keras.models.Model(inputs=inputs, outputs=x, name='ArcFace_Transfer_Learning')
    print("✓ Model compiled successfully\n")
    
except Exception as e:
    print(f"✗ Error building model: {e}")
    import traceback
    traceback.print_exc()
    raise

# Cetak summary model lengkap
print("\n" + "="*80)
print("COMPLETE TRANSFER LEARNING MODEL ARCHITECTURE")
print("="*80)
model.summary()

# Visualisasi model
print("\n" + "="*80)
print("GENERATING MODEL VISUALIZATION")
print("="*80)
try:
    keras.utils.plot_model(
        model, 
        to_file='arcface_transfer_learning_model.png', 
        show_shapes=True, 
        show_layer_names=True, 
        rankdir='TB', 
        expand_nested=True, 
        dpi=96
    )
    print("✓ Model diagram saved as 'arcface_transfer_learning_model.png'")
except Exception as e:
    print(f"✗ Error generating visualization: {e}")
    print("  (This is optional - model is still usable)")

# Informasi tambahan
print("\n" + "="*80)
print("MODEL INFORMATION SUMMARY")
print("="*80)

total_params = model.count_params()
trainable_params = sum([keras.backend.count_params(w) for w in model.trainable_weights])
non_trainable_params = sum([keras.backend.count_params(w) for w in model.non_trainable_weights])

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Non-trainable parameters (frozen ArcFace): {non_trainable_params:,}")
print(f"Percentage trainable: {(trainable_params/total_params)*100:.2f}%")

print(f"\nInput shape: {model.input_shape}")
print(f"Output shape: {model.output_shape}")
print(f"\nModel expects:")
print(f"  - Batch of 10 frames per sequence")
print(f"  - Each frame: 112x112x3 (RGB)")
print(f"  - Output: 5 classes with sigmoid activation")

print("\n" + "="*80)
print("LAYER-BY-LAYER OUTPUT SHAPES")
print("="*80)
for i, layer in enumerate(model.layers, 1):
    trainable_status = "Yes" if layer.trainable else "No"
    print(f"{i:2d}. {layer.name:35s} -> {str(layer.output_shape):30s} | Trainable: {trainable_status}")

# Informasi khusus ArcFace
print("\n" + "="*80)
print("ARCFACE MODEL DETAILS")
print("="*80)
print(f"ArcFace layers: {len(arcface_model.layers)}")
print(f"ArcFace parameters: {arcface_model.count_params():,}")
print(f"All ArcFace layers frozen: {not arcface_model.trainable}")

print("\n✓ Model setup complete and ready for training!")
# Out:
# Loading ArcFace model...
# ✓ ArcFace model loaded successfully
#
# ================================================================================
# ARCFACE BASE MODEL ARCHITECTURE
# ================================================================================
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 112, 112, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 114, 114, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         1728      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_prelu (PReLU)         (None, 112, 112, 64)         64        ['conv1_bn[0][0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 112, 112, 64)         256       ['conv1_prelu[0][0]']
#  rmalization)
#
#  conv2_block1_1_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_bn[0][0]']
#  dding2D)
#
#  conv2_block1_1_conv (Conv2  (None, 112, 112, 64)         36864     ['conv2_block1_1_pad[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 112, 112, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_prelu (PReL  (None, 112, 112, 64)         64        ['conv2_block1_2_bn[0][0]']
#  U)
#
#  conv2_block1_2_pad (ZeroPa  (None, 114, 114, 64)         0         ['conv2_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 64)           4096      ['conv1_prelu[0][0]']
#  D)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_add[0][0]']
#  rmalization)
#
#  conv2_block2_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_bn[0][0]']
#  dding2D)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_1_pad[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block2_2_bn[0][0]']
#  U)
#
#  conv2_block2_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 64)           0         ['conv2_block1_add[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_add[0][0]']
#  rmalization)
#
#  conv2_block3_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_bn[0][0]']
#  dding2D)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_1_pad[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_prelu (PReL  (None, 56, 56, 64)           64        ['conv2_block3_2_bn[0][0]']
#  U)
#
#  conv2_block3_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block3_2_pad[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 64)           0         ['conv2_block2_add[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_add[0][0]']
#  rmalization)
#
#  conv3_block1_1_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv3_block1_1_bn[0][0]']
#  dding2D)
#
#  conv3_block1_1_conv (Conv2  (None, 56, 56, 128)          73728     ['conv3_block1_1_pad[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 56, 56, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_prelu (PReL  (None, 56, 56, 128)          128       ['conv3_block1_2_bn[0][0]']
#  U)
#
#  conv3_block1_2_pad (ZeroPa  (None, 58, 58, 128)          0         ['conv3_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 128)          8192      ['conv2_block3_add[0][0]']
#  D)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_add[0][0]']
#  rmalization)
#
#  conv3_block2_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_bn[0][0]']
#  dding2D)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_1_pad[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block2_2_bn[0][0]']
#  U)
#
#  conv3_block2_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 128)          0         ['conv3_block1_add[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_add[0][0]']
#  rmalization)
#
#  conv3_block3_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_bn[0][0]']
#  dding2D)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_1_pad[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block3_2_bn[0][0]']
#  U)
#
#  conv3_block3_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 128)          0         ['conv3_block2_add[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_add[0][0]']
#  rmalization)
#
#  conv3_block4_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_bn[0][0]']
#  dding2D)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_1_pad[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_prelu (PReL  (None, 28, 28, 128)          128       ['conv3_block4_2_bn[0][0]']
#  U)
#
#  conv3_block4_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block4_2_pad[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 128)          0         ['conv3_block3_add[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_add[0][0]']
#  rmalization)
#
#  conv4_block1_1_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv4_block1_1_bn[0][0]']
#  dding2D)
#
#  conv4_block1_1_conv (Conv2  (None, 28, 28, 256)          294912    ['conv4_block1_1_pad[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_prelu (PReL  (None, 28, 28, 256)          256       ['conv4_block1_2_bn[0][0]']
#  U)
#
#  conv4_block1_2_pad (ZeroPa  (None, 30, 30, 256)          0         ['conv4_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 256)          32768     ['conv3_block4_add[0][0]']
#  D)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block1_2_pad[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_add[0][0]']
#  rmalization)
#
#  conv4_block2_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  dding2D)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_1_pad[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block2_2_bn[0][0]']
#  U)
#
#  conv4_block2_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_2_pad[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 256)          0         ['conv4_block1_add[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_add[0][0]']
#  rmalization)
#
#  conv4_block3_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  dding2D)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_1_pad[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block3_2_bn[0][0]']
#  U)
#
#  conv4_block3_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_2_pad[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 256)          0         ['conv4_block2_add[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_add[0][0]']
#  rmalization)
#
#  conv4_block4_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  dding2D)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_1_pad[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block4_2_bn[0][0]']
#  U)
#
#  conv4_block4_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_2_pad[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 256)          0         ['conv4_block3_add[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_add[0][0]']
#  rmalization)
#
#  conv4_block5_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_bn[0][0]']
#  dding2D)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_1_pad[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block5_2_bn[0][0]']
#  U)
#
#  conv4_block5_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_2_pad[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 256)          0         ['conv4_block4_add[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_add[0][0]']
#  rmalization)
#
#  conv4_block6_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_bn[0][0]']
#  dding2D)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_1_pad[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_prelu (PReL  (None, 14, 14, 256)          256       ['conv4_block6_2_bn[0][0]']
#  U)
#
#  conv4_block6_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_prelu[0][0]']
#  dding2D)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_2_pad[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 256)          0         ['conv4_block5_add[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv5_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_add[0][0]']
#  rmalization)
#
#  conv5_block1_1_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv5_block1_1_bn[0][0]']
#  dding2D)
#
#  conv5_block1_1_conv (Conv2  (None, 14, 14, 512)          1179648   ['conv5_block1_1_pad[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 14, 14, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_prelu (PReL  (None, 14, 14, 512)          512       ['conv5_block1_2_bn[0][0]']
#  U)
#
#  conv5_block1_2_pad (ZeroPa  (None, 16, 16, 512)          0         ['conv5_block1_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 512)            131072    ['conv4_block6_add[0][0]']
#  D)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block1_2_pad[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_add[0][0]']
#  rmalization)
#
#  conv5_block2_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_bn[0][0]']
#  dding2D)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_1_pad[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block2_2_bn[0][0]']
#  U)
#
#  conv5_block2_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_2_pad[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 512)            0         ['conv5_block1_add[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_add[0][0]']
#  rmalization)
#
#  conv5_block3_1_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_bn[0][0]']
#  dding2D)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_1_pad[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_prelu (PReL  (None, 7, 7, 512)            512       ['conv5_block3_2_bn[0][0]']
#  U)
#
#  conv5_block3_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_prelu[0][0]']
#  dding2D)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_2_pad[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 512)            0         ['conv5_block2_add[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  batch_normalization (Batch  (None, 7, 7, 512)            2048      ['conv5_block3_add[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 7, 7, 512)            0         ['batch_normalization[0][0]']
#
#  flatten (Flatten)           (None, 25088)                0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 512)                  1284556   ['flatten[0][0]']
#                                                           8
#
#  embedding (BatchNormalizat  (None, 512)                  2048      ['dense[0][0]']
#  ion)
#
# ==================================================================================================
# Total params: 34165184 (130.33 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 34165184 (130.33 MB)
# __________________________________________________________________________________________________
#
# ArcFace Input Shape: (None, 112, 112, 3)
# ArcFace Output Shape: (None, 512)
# ArcFace Embedding Dimension: 512
#
# ================================================================================
# BUILDING TRANSFER LEARNING MODEL WITH ARCFACE
# ================================================================================
# ✓ Input layer created: (None, 10, 112, 112, 3)
# ✓ Rescaling layer added: (None, 10, 112, 112, 3)
# ✓ ArcFace TimeDistributed layer added: (None, 10, 512)
# ✓ LSTM_1 layer added: (None, 10, 128)
# ✓ LSTM_2 layer added: (None, 64)
# ✓ Dropout_1 layer added: (None, 64)
# ✓ Dense_1024 layer added: (None, 1024)
# ✓ Dense_512 layer added: (None, 512)
# ✓ Dense_256 layer added: (None, 256)
# ✓ Dropout_2 layer added: (None, 256)
# ✓ Output layer added: (None, 5)
# ✓ Model compiled successfully
#
#
# ================================================================================
# COMPLETE TRANSFER LEARNING MODEL ARCHITECTURE
# ================================================================================
# Model: "ArcFace_Transfer_Learning"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 10, 112, 112, 3   0
#                              )]
#
#  Rescaling (TimeDistributed  (None, 10, 112, 112, 3)   0
#  )
#
#  ArcFace_TimeDistributed (T  (None, 10, 512)           34165184
#  imeDistributed)
#
#  LSTM_1 (LSTM)               (None, 10, 128)           328192
#
#  LSTM_2 (LSTM)               (None, 64)                49408
#
#  Dropout_1 (Dropout)         (None, 64)                0
#
#  Dense_1024 (Dense)          (None, 1024)              66560
#
#  Dense_512 (Dense)           (None, 512)               524800
#
#  Dense_256 (Dense)           (None, 256)               131328
#
#  Dropout_2 (Dropout)         (None, 256)               0
#
#  Output (Dense)              (None, 5)                 1285
#
# =================================================================
# Total params: 35266757 (134.53 MB)
# Trainable params: 1101573 (4.20 MB)
# Non-trainable params: 34165184 (130.33 MB)
# _________________________________________________________________
#
# ================================================================================
# GENERATING MODEL VISUALIZATION
# ================================================================================
# ✓ Model diagram saved as 'arcface_transfer_learning_model.png'
#
# ================================================================================
# MODEL INFORMATION SUMMARY
# ================================================================================
# Total parameters: 35,266,757
# Trainable parameters: 1,101,573
# Non-trainable parameters (frozen ArcFace): 34,165,184
# Percentage trainable: 3.12%
#
# Input shape: (None, 10, 112, 112, 3)
# Output shape: (None, 5)
#
# Model expects:
#   - Batch of 10 frames per sequence
#   - Each frame: 112x112x3 (RGB)
#   - Output: 5 classes with sigmoid activation
#
# ================================================================================
# LAYER-BY-LAYER OUTPUT SHAPES
# ================================================================================
#  1. Input                               -> [(None, 10, 112, 112, 3)]      | Trainable: Yes
#  2. Rescaling                           -> (None, 10, 112, 112, 3)        | Trainable: Yes
#  3. ArcFace_TimeDistributed             -> (None, 10, 512)                | Trainable: Yes
#  4. LSTM_1                              -> (None, 10, 128)                | Trainable: Yes
#  5. LSTM_2                              -> (None, 64)                     | Trainable: Yes
#  6. Dropout_1                           -> (None, 64)                     | Trainable: Yes
#  7. Dense_1024                          -> (None, 1024)                   | Trainable: Yes
#  8. Dense_512                           -> (None, 512)                    | Trainable: Yes
#  9. Dense_256                           -> (None, 256)                    | Trainable: Yes
# 10. Dropout_2                           -> (None, 256)                    | Trainable: Yes
# 11. Output                              -> (None, 5)                      | Trainable: Yes
#
# ================================================================================
# ARCFACE MODEL DETAILS
# ================================================================================
# ArcFace layers: 162
# ArcFace parameters: 34,165,184
# All ArcFace layers frozen: True
#
# ✓ Model setup complete and ready for training!

# %% [markdown]
# ### Load data

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//ocean-project-deepface-20250529T023947Z-1-001//ocean-project-deepface//data//videoface//train_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//ocean-project-deepface-20250529T023947Z-1-001//ocean-project-deepface//data//videoface//val_ds') \
    .cache().shuffle(buffer_size=1000, seed=42).prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds, valid_ds
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 112, 112, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>)

# %% [markdown]
# ### Compile model

# %%
t = datetime.datetime.now().strftime("%m%d_%H%M%S")

# optimizer = keras.optimizers.Adam(learning_rate=0.001)
optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
# optimizer = tfa.optimizers.RectifiedAdam(learning_rate=0.001)

early_stopping = keras.callbacks.EarlyStopping(patience=10, verbose=1)
check_point    = keras.callbacks.ModelCheckpoint(filepath='./weights/faces/'+str(t)+'/face.t5',
                            monitor='val_mae',
                            mode='min',
                            save_best_only=True,
                            save_weights_only=True,
                            verbose=1)

model.compile(loss='mse', optimizer=optimizer, metrics=['mae'])

# %% [markdown]
# ### Train

# %%
history = model.fit(train_ds, validation_data=valid_ds, batch_size=8, epochs=100, callbacks=[early_stopping, check_point])
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2438 - mae: 0.4936
# Epoch 1: val_mae improved from inf to 0.48775, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 29s 3s/step - loss: 0.2438 - mae: 0.4936 - val_loss: 0.2380 - val_mae: 0.4877
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2291 - mae: 0.4784
# Epoch 2: val_mae improved from 0.48775 to 0.46696, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.2291 - mae: 0.4784 - val_loss: 0.2181 - val_mae: 0.4670
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2047 - mae: 0.4521
# Epoch 3: val_mae improved from 0.46696 to 0.43869, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.2047 - mae: 0.4521 - val_loss: 0.1925 - val_mae: 0.4387
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1786 - mae: 0.4220
# Epoch 4: val_mae improved from 0.43869 to 0.40305, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.1786 - mae: 0.4220 - val_loss: 0.1626 - val_mae: 0.4031
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1460 - mae: 0.3809
# Epoch 5: val_mae improved from 0.40305 to 0.35904, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.1460 - mae: 0.3809 - val_loss: 0.1291 - val_mae: 0.3590
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1076 - mae: 0.3259
# Epoch 6: val_mae improved from 0.35904 to 0.30591, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.1076 - mae: 0.3259 - val_loss: 0.0938 - val_mae: 0.3059
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0784 - mae: 0.2766
# Epoch 7: val_mae improved from 0.30591 to 0.24627, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 0.0784 - mae: 0.2766 - val_loss: 0.0610 - val_mae: 0.2463
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0509 - mae: 0.2205
# Epoch 8: val_mae improved from 0.24627 to 0.18748, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0509 - mae: 0.2205 - val_loss: 0.0355 - val_mae: 0.1875
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0260 - mae: 0.1547
# Epoch 9: val_mae improved from 0.18748 to 0.13925, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0260 - mae: 0.1547 - val_loss: 0.0197 - val_mae: 0.1392
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0169 - mae: 0.1218
# Epoch 10: val_mae improved from 0.13925 to 0.10467, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0169 - mae: 0.1218 - val_loss: 0.0112 - val_mae: 0.1047
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0090 - mae: 0.0870
# Epoch 11: val_mae improved from 0.10467 to 0.08213, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0090 - mae: 0.0870 - val_loss: 0.0069 - val_mae: 0.0821
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0067 - mae: 0.0723
# Epoch 12: val_mae improved from 0.08213 to 0.06780, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0067 - mae: 0.0723 - val_loss: 0.0047 - val_mae: 0.0678
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0055 - mae: 0.0634
# Epoch 13: val_mae improved from 0.06780 to 0.05777, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0055 - mae: 0.0634 - val_loss: 0.0034 - val_mae: 0.0578
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0031 - mae: 0.0475
# Epoch 14: val_mae improved from 0.05777 to 0.05096, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0031 - mae: 0.0475 - val_loss: 0.0027 - val_mae: 0.0510
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0038 - mae: 0.0545
# Epoch 15: val_mae improved from 0.05096 to 0.04557, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0038 - mae: 0.0545 - val_loss: 0.0022 - val_mae: 0.0456
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0027 - mae: 0.0437
# Epoch 16: val_mae improved from 0.04557 to 0.04138, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0027 - mae: 0.0437 - val_loss: 0.0018 - val_mae: 0.0414
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0026 - mae: 0.0430
# Epoch 17: val_mae improved from 0.04138 to 0.03804, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0026 - mae: 0.0430 - val_loss: 0.0015 - val_mae: 0.0380
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0370
# Epoch 18: val_mae improved from 0.03804 to 0.03526, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0019 - mae: 0.0370 - val_loss: 0.0013 - val_mae: 0.0353
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0373
# Epoch 19: val_mae improved from 0.03526 to 0.03293, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0019 - mae: 0.0373 - val_loss: 0.0011 - val_mae: 0.0329
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0016 - mae: 0.0326
# Epoch 20: val_mae improved from 0.03293 to 0.03091, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0016 - mae: 0.0326 - val_loss: 9.9992e-04 - val_mae: 0.0309
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0017 - mae: 0.0340
# Epoch 21: val_mae improved from 0.03091 to 0.02906, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0017 - mae: 0.0340 - val_loss: 8.8473e-04 - val_mae: 0.0291
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0289
# Epoch 22: val_mae improved from 0.02906 to 0.02747, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0012 - mae: 0.0289 - val_loss: 7.9213e-04 - val_mae: 0.0275
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0010 - mae: 0.0266
# Epoch 23: val_mae improved from 0.02747 to 0.02619, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0010 - mae: 0.0266 - val_loss: 7.2061e-04 - val_mae: 0.0262
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0272
# Epoch 24: val_mae improved from 0.02619 to 0.02503, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0011 - mae: 0.0272 - val_loss: 6.5917e-04 - val_mae: 0.0250
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0248
# Epoch 25: val_mae improved from 0.02503 to 0.02391, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0012 - mae: 0.0248 - val_loss: 6.0222e-04 - val_mae: 0.0239
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0256
# Epoch 26: val_mae improved from 0.02391 to 0.02288, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0011 - mae: 0.0256 - val_loss: 5.5199e-04 - val_mae: 0.0229
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 8.7414e-04 - mae: 0.0235
# Epoch 27: val_mae improved from 0.02288 to 0.02202, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 8.7414e-04 - mae: 0.0235 - val_loss: 5.1158e-04 - val_mae: 0.0220
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0253
# Epoch 28: val_mae improved from 0.02202 to 0.02120, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 0.0012 - mae: 0.0253 - val_loss: 4.7467e-04 - val_mae: 0.0212
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 7.1645e-04 - mae: 0.0212
# Epoch 29: val_mae improved from 0.02120 to 0.02044, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 7.1645e-04 - mae: 0.0212 - val_loss: 4.4173e-04 - val_mae: 0.0204
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0263
# Epoch 30: val_mae improved from 0.02044 to 0.01966, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 0.0011 - mae: 0.0263 - val_loss: 4.0925e-04 - val_mae: 0.0197
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 7.5832e-04 - mae: 0.0220
# Epoch 31: val_mae improved from 0.01966 to 0.01891, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 7.5832e-04 - mae: 0.0220 - val_loss: 3.7887e-04 - val_mae: 0.0189
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 6.7998e-04 - mae: 0.0212
# Epoch 32: val_mae improved from 0.01891 to 0.01824, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 6.7998e-04 - mae: 0.0212 - val_loss: 3.5299e-04 - val_mae: 0.0182
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 5.7624e-04 - mae: 0.0188
# Epoch 33: val_mae improved from 0.01824 to 0.01770, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 5.7624e-04 - mae: 0.0188 - val_loss: 3.3257e-04 - val_mae: 0.0177
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 7.7634e-04 - mae: 0.0212
# Epoch 34: val_mae improved from 0.01770 to 0.01715, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 7.7634e-04 - mae: 0.0212 - val_loss: 3.1246e-04 - val_mae: 0.0172
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 7.3772e-04 - mae: 0.0206
# Epoch 35: val_mae improved from 0.01715 to 0.01662, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 7.3772e-04 - mae: 0.0206 - val_loss: 2.9353e-04 - val_mae: 0.0166
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 5.3748e-04 - mae: 0.0177
# Epoch 36: val_mae improved from 0.01662 to 0.01613, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 5.3748e-04 - mae: 0.0177 - val_loss: 2.7671e-04 - val_mae: 0.0161
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 6.3892e-04 - mae: 0.0192
# Epoch 37: val_mae improved from 0.01613 to 0.01569, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 6.3892e-04 - mae: 0.0192 - val_loss: 2.6196e-04 - val_mae: 0.0157
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 5.5572e-04 - mae: 0.0184
# Epoch 38: val_mae improved from 0.01569 to 0.01529, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 5.5572e-04 - mae: 0.0184 - val_loss: 2.4891e-04 - val_mae: 0.0153
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 4.2429e-04 - mae: 0.0159
# Epoch 39: val_mae improved from 0.01529 to 0.01491, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 4.2429e-04 - mae: 0.0159 - val_loss: 2.3675e-04 - val_mae: 0.0149
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 4.9981e-04 - mae: 0.0168
# Epoch 40: val_mae improved from 0.01491 to 0.01455, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 4.9981e-04 - mae: 0.0168 - val_loss: 2.2574e-04 - val_mae: 0.0145
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 6.0847e-04 - mae: 0.0187
# Epoch 41: val_mae improved from 0.01455 to 0.01419, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 6.0847e-04 - mae: 0.0187 - val_loss: 2.1477e-04 - val_mae: 0.0142
# Epoch 42/100
# 8/8 [==============================] - ETA: 0s - loss: 5.6842e-04 - mae: 0.0181
# Epoch 42: val_mae improved from 0.01419 to 0.01383, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 5.6842e-04 - mae: 0.0181 - val_loss: 2.0414e-04 - val_mae: 0.0138
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 5.4792e-04 - mae: 0.0175
# Epoch 43: val_mae improved from 0.01383 to 0.01347, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 5.4792e-04 - mae: 0.0175 - val_loss: 1.9398e-04 - val_mae: 0.0135
# Epoch 44/100
# 8/8 [==============================] - ETA: 0s - loss: 4.8361e-04 - mae: 0.0161
# Epoch 44: val_mae improved from 0.01347 to 0.01314, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 4.8361e-04 - mae: 0.0161 - val_loss: 1.8483e-04 - val_mae: 0.0131
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 4.1108e-04 - mae: 0.0150
# Epoch 45: val_mae improved from 0.01314 to 0.01288, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 4.1108e-04 - mae: 0.0150 - val_loss: 1.7748e-04 - val_mae: 0.0129
# Epoch 46/100
# 8/8 [==============================] - ETA: 0s - loss: 5.8240e-04 - mae: 0.0175
# Epoch 46: val_mae improved from 0.01288 to 0.01258, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 5.8240e-04 - mae: 0.0175 - val_loss: 1.6951e-04 - val_mae: 0.0126
# Epoch 47/100
# 8/8 [==============================] - ETA: 0s - loss: 2.9755e-04 - mae: 0.0133
# Epoch 47: val_mae improved from 0.01258 to 0.01231, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 21s 3s/step - loss: 2.9755e-04 - mae: 0.0133 - val_loss: 1.6251e-04 - val_mae: 0.0123
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 3.0620e-04 - mae: 0.0133
# Epoch 48: val_mae improved from 0.01231 to 0.01208, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.0620e-04 - mae: 0.0133 - val_loss: 1.5653e-04 - val_mae: 0.0121
# Epoch 49/100
# 8/8 [==============================] - ETA: 0s - loss: 3.3096e-04 - mae: 0.0132
# Epoch 49: val_mae improved from 0.01208 to 0.01188, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.3096e-04 - mae: 0.0132 - val_loss: 1.5146e-04 - val_mae: 0.0119
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 4.6144e-04 - mae: 0.0154
# Epoch 50: val_mae improved from 0.01188 to 0.01166, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 4.6144e-04 - mae: 0.0154 - val_loss: 1.4606e-04 - val_mae: 0.0117
# Epoch 51/100
# 8/8 [==============================] - ETA: 0s - loss: 3.3557e-04 - mae: 0.0139
# Epoch 51: val_mae improved from 0.01166 to 0.01143, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.3557e-04 - mae: 0.0139 - val_loss: 1.4038e-04 - val_mae: 0.0114
# Epoch 52/100
# 8/8 [==============================] - ETA: 0s - loss: 4.7816e-04 - mae: 0.0140
# Epoch 52: val_mae improved from 0.01143 to 0.01120, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 4.7816e-04 - mae: 0.0140 - val_loss: 1.3485e-04 - val_mae: 0.0112
# Epoch 53/100
# 8/8 [==============================] - ETA: 0s - loss: 3.5311e-04 - mae: 0.0142
# Epoch 53: val_mae improved from 0.01120 to 0.01100, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.5311e-04 - mae: 0.0142 - val_loss: 1.3012e-04 - val_mae: 0.0110
# Epoch 54/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9093e-04 - mae: 0.0103
# Epoch 54: val_mae improved from 0.01100 to 0.01083, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.9093e-04 - mae: 0.0103 - val_loss: 1.2618e-04 - val_mae: 0.0108
# Epoch 55/100
# 8/8 [==============================] - ETA: 0s - loss: 5.0949e-04 - mae: 0.0146
# Epoch 55: val_mae improved from 0.01083 to 0.01065, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 5.0949e-04 - mae: 0.0146 - val_loss: 1.2213e-04 - val_mae: 0.0107
# Epoch 56/100
# 8/8 [==============================] - ETA: 0s - loss: 3.3652e-04 - mae: 0.0121
# Epoch 56: val_mae improved from 0.01065 to 0.01046, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.3652e-04 - mae: 0.0121 - val_loss: 1.1790e-04 - val_mae: 0.0105
# Epoch 57/100
# 8/8 [==============================] - ETA: 0s - loss: 4.9348e-04 - mae: 0.0160
# Epoch 57: val_mae improved from 0.01046 to 0.01028, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 4.9348e-04 - mae: 0.0160 - val_loss: 1.1383e-04 - val_mae: 0.0103
# Epoch 58/100
# 8/8 [==============================] - ETA: 0s - loss: 4.8789e-04 - mae: 0.0144
# Epoch 58: val_mae improved from 0.01028 to 0.01006, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 4.8789e-04 - mae: 0.0144 - val_loss: 1.0913e-04 - val_mae: 0.0101
# Epoch 59/100
# 8/8 [==============================] - ETA: 0s - loss: 3.8311e-04 - mae: 0.0124
# Epoch 59: val_mae improved from 0.01006 to 0.00986, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.8311e-04 - mae: 0.0124 - val_loss: 1.0487e-04 - val_mae: 0.0099
# Epoch 60/100
# 8/8 [==============================] - ETA: 0s - loss: 3.2493e-04 - mae: 0.0121
# Epoch 60: val_mae improved from 0.00986 to 0.00968, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.2493e-04 - mae: 0.0121 - val_loss: 1.0112e-04 - val_mae: 0.0097
# Epoch 61/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6601e-04 - mae: 0.0112
# Epoch 61: val_mae improved from 0.00968 to 0.00952, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.6601e-04 - mae: 0.0112 - val_loss: 9.7908e-05 - val_mae: 0.0095
# Epoch 62/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0288e-04 - mae: 0.0104
# Epoch 62: val_mae improved from 0.00952 to 0.00938, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.0288e-04 - mae: 0.0104 - val_loss: 9.4991e-05 - val_mae: 0.0094
# Epoch 63/100
# 8/8 [==============================] - ETA: 0s - loss: 3.5966e-04 - mae: 0.0120
# Epoch 63: val_mae improved from 0.00938 to 0.00923, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.5966e-04 - mae: 0.0120 - val_loss: 9.2024e-05 - val_mae: 0.0092
# Epoch 64/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8314e-04 - mae: 0.0101
# Epoch 64: val_mae improved from 0.00923 to 0.00910, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.8314e-04 - mae: 0.0101 - val_loss: 8.9511e-05 - val_mae: 0.0091
# Epoch 65/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0335e-04 - mae: 0.0111
# Epoch 65: val_mae improved from 0.00910 to 0.00898, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.0335e-04 - mae: 0.0111 - val_loss: 8.7141e-05 - val_mae: 0.0090
# Epoch 66/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6324e-04 - mae: 0.0121
# Epoch 66: val_mae improved from 0.00898 to 0.00885, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.6324e-04 - mae: 0.0121 - val_loss: 8.4752e-05 - val_mae: 0.0089
# Epoch 67/100
# 8/8 [==============================] - ETA: 0s - loss: 3.5531e-04 - mae: 0.0106
# Epoch 67: val_mae improved from 0.00885 to 0.00873, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.5531e-04 - mae: 0.0106 - val_loss: 8.2420e-05 - val_mae: 0.0087
# Epoch 68/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5752e-04 - mae: 0.0105
# Epoch 68: val_mae improved from 0.00873 to 0.00860, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.5752e-04 - mae: 0.0105 - val_loss: 8.0039e-05 - val_mae: 0.0086
# Epoch 69/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9964e-04 - mae: 0.0099
# Epoch 69: val_mae improved from 0.00860 to 0.00848, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.9964e-04 - mae: 0.0099 - val_loss: 7.7868e-05 - val_mae: 0.0085
# Epoch 70/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7222e-04 - mae: 0.0095
# Epoch 70: val_mae improved from 0.00848 to 0.00838, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.7222e-04 - mae: 0.0095 - val_loss: 7.6023e-05 - val_mae: 0.0084
# Epoch 71/100
# 8/8 [==============================] - ETA: 0s - loss: 2.7860e-04 - mae: 0.0119
# Epoch 71: val_mae improved from 0.00838 to 0.00827, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.7860e-04 - mae: 0.0119 - val_loss: 7.4102e-05 - val_mae: 0.0083
# Epoch 72/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9897e-04 - mae: 0.0101
# Epoch 72: val_mae improved from 0.00827 to 0.00816, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.9897e-04 - mae: 0.0101 - val_loss: 7.2129e-05 - val_mae: 0.0082
# Epoch 73/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7254e-04 - mae: 0.0096
# Epoch 73: val_mae improved from 0.00816 to 0.00806, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.7254e-04 - mae: 0.0096 - val_loss: 7.0464e-05 - val_mae: 0.0081
# Epoch 74/100
# 8/8 [==============================] - ETA: 0s - loss: 3.7640e-04 - mae: 0.0130
# Epoch 74: val_mae improved from 0.00806 to 0.00794, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 3.7640e-04 - mae: 0.0130 - val_loss: 6.8416e-05 - val_mae: 0.0079
# Epoch 75/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0719e-04 - mae: 0.0099
# Epoch 75: val_mae improved from 0.00794 to 0.00782, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.0719e-04 - mae: 0.0099 - val_loss: 6.6379e-05 - val_mae: 0.0078
# Epoch 76/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0684e-04 - mae: 0.0080
# Epoch 76: val_mae improved from 0.00782 to 0.00773, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 24s 3s/step - loss: 1.0684e-04 - mae: 0.0080 - val_loss: 6.4908e-05 - val_mae: 0.0077
# Epoch 77/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6181e-04 - mae: 0.0101
# Epoch 77: val_mae improved from 0.00773 to 0.00765, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 23s 3s/step - loss: 2.6181e-04 - mae: 0.0101 - val_loss: 6.3482e-05 - val_mae: 0.0076
# Epoch 78/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4784e-04 - mae: 0.0089
# Epoch 78: val_mae improved from 0.00765 to 0.00757, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.4784e-04 - mae: 0.0089 - val_loss: 6.2186e-05 - val_mae: 0.0076
# Epoch 79/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9303e-04 - mae: 0.0100
# Epoch 79: val_mae improved from 0.00757 to 0.00748, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.9303e-04 - mae: 0.0100 - val_loss: 6.0847e-05 - val_mae: 0.0075
# Epoch 80/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0412e-04 - mae: 0.0099
# Epoch 80: val_mae improved from 0.00748 to 0.00740, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.0412e-04 - mae: 0.0099 - val_loss: 5.9475e-05 - val_mae: 0.0074
# Epoch 81/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6471e-04 - mae: 0.0088
# Epoch 81: val_mae improved from 0.00740 to 0.00732, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.6471e-04 - mae: 0.0088 - val_loss: 5.8179e-05 - val_mae: 0.0073
# Epoch 82/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5137e-04 - mae: 0.0100
# Epoch 82: val_mae improved from 0.00732 to 0.00723, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.5137e-04 - mae: 0.0100 - val_loss: 5.6851e-05 - val_mae: 0.0072
# Epoch 83/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6789e-04 - mae: 0.0084
# Epoch 83: val_mae improved from 0.00723 to 0.00716, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.6789e-04 - mae: 0.0084 - val_loss: 5.5777e-05 - val_mae: 0.0072
# Epoch 84/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0689e-04 - mae: 0.0070
# Epoch 84: val_mae improved from 0.00716 to 0.00709, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.0689e-04 - mae: 0.0070 - val_loss: 5.4732e-05 - val_mae: 0.0071
# Epoch 85/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5110e-04 - mae: 0.0101
# Epoch 85: val_mae improved from 0.00709 to 0.00702, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.5110e-04 - mae: 0.0101 - val_loss: 5.3666e-05 - val_mae: 0.0070
# Epoch 86/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6602e-04 - mae: 0.0088
# Epoch 86: val_mae improved from 0.00702 to 0.00694, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.6602e-04 - mae: 0.0088 - val_loss: 5.2429e-05 - val_mae: 0.0069
# Epoch 87/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9629e-04 - mae: 0.0093
# Epoch 87: val_mae improved from 0.00694 to 0.00686, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.9629e-04 - mae: 0.0093 - val_loss: 5.1291e-05 - val_mae: 0.0069
# Epoch 88/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4470e-04 - mae: 0.0083
# Epoch 88: val_mae improved from 0.00686 to 0.00679, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.4470e-04 - mae: 0.0083 - val_loss: 5.0236e-05 - val_mae: 0.0068
# Epoch 89/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8826e-04 - mae: 0.0092
# Epoch 89: val_mae improved from 0.00679 to 0.00673, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.8826e-04 - mae: 0.0092 - val_loss: 4.9283e-05 - val_mae: 0.0067
# Epoch 90/100
# 8/8 [==============================] - ETA: 0s - loss: 1.5920e-04 - mae: 0.0083
# Epoch 90: val_mae improved from 0.00673 to 0.00666, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.5920e-04 - mae: 0.0083 - val_loss: 4.8313e-05 - val_mae: 0.0067
# Epoch 91/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4240e-04 - mae: 0.0085
# Epoch 91: val_mae improved from 0.00666 to 0.00659, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.4240e-04 - mae: 0.0085 - val_loss: 4.7399e-05 - val_mae: 0.0066
# Epoch 92/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0070e-04 - mae: 0.0071
# Epoch 92: val_mae improved from 0.00659 to 0.00654, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.0070e-04 - mae: 0.0071 - val_loss: 4.6566e-05 - val_mae: 0.0065
# Epoch 93/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3557e-04 - mae: 0.0077
# Epoch 93: val_mae improved from 0.00654 to 0.00648, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.3557e-04 - mae: 0.0077 - val_loss: 4.5815e-05 - val_mae: 0.0065
# Epoch 94/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4092e-04 - mae: 0.0081
# Epoch 94: val_mae improved from 0.00648 to 0.00643, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.4092e-04 - mae: 0.0081 - val_loss: 4.5126e-05 - val_mae: 0.0064
# Epoch 95/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6455e-04 - mae: 0.0101
# Epoch 95: val_mae improved from 0.00643 to 0.00637, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 2.6455e-04 - mae: 0.0101 - val_loss: 4.4223e-05 - val_mae: 0.0064
# Epoch 96/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4837e-04 - mae: 0.0083
# Epoch 96: val_mae improved from 0.00637 to 0.00630, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.4837e-04 - mae: 0.0083 - val_loss: 4.3298e-05 - val_mae: 0.0063
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4339e-04 - mae: 0.0083
# Epoch 97: val_mae improved from 0.00630 to 0.00624, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.4339e-04 - mae: 0.0083 - val_loss: 4.2457e-05 - val_mae: 0.0062
# Epoch 98/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4904e-04 - mae: 0.0088
# Epoch 98: val_mae improved from 0.00624 to 0.00618, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.4904e-04 - mae: 0.0088 - val_loss: 4.1644e-05 - val_mae: 0.0062
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8787e-04 - mae: 0.0091
# Epoch 99: val_mae improved from 0.00618 to 0.00612, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.8787e-04 - mae: 0.0091 - val_loss: 4.0844e-05 - val_mae: 0.0061
# Epoch 100/100
# 8/8 [==============================] - ETA: 0s - loss: 1.2434e-04 - mae: 0.0078
# Epoch 100: val_mae improved from 0.00612 to 0.00605, saving model to ./weights/faces/1010_040845\face.t5
# 8/8 [==============================] - 22s 3s/step - loss: 1.2434e-04 - mae: 0.0078 - val_loss: 4.0035e-05 - val_mae: 0.0061

# %% [markdown]
# ### Load weights

# %%
model.load_weights('./weights/faces/1010_040845/face.t5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training data

# %%
train_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface//train_ds')
loss, mae = model.evaluate(train_ds)
(1-mae)*100
# Out:
# 8/8 [==============================] - 19s 2s/step - loss: 3.0334e-05 - mae: 0.0051
# 99.49154616333544

# %%
y_true = np.concatenate([y for x,y in train_ds])
y_pred = model.predict(train_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 8/8 [==============================] - 18s 2s/step
# (array([99.42582 , 99.535995, 99.489914, 99.514404, 99.4916  ],
#        dtype=float32),
#  99.49154607020319)

# %% [markdown]
# ### Validation data

# %%
valid_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface//val_ds') 
loss, mae = model.evaluate(valid_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 4.0035e-05 - mae: 0.0061
# 99.39463892951608

# %%
y_true = np.concatenate([y for x,y in valid_ds])
y_pred = model.predict(valid_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 5s 2s/step
# (array([99.32186, 99.44676, 99.39527, 99.41705, 99.39225], dtype=float32),
#  99.39463892951608)

# %% [markdown]
# ### Test data

# %%
test_ds = tf.data.Dataset.load('C://Users//ALFIAN//TA CODING//ZIP FILE//arcface_oceanmodel//ocean-project-deepface//data//videoface//test_ds')
loss, mae = model.evaluate(test_ds)
(1-mae)*100
# Out:
# 3/3 [==============================] - 6s 2s/step - loss: 4.2756e-05 - mae: 0.0061
# 99.38915334641933

# %%
y_true = np.concatenate([y for x,y in test_ds])
y_pred = model.predict(test_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 3/3 [==============================] - 6s 2s/step
# (array([99.31509 , 99.44855 , 99.394035, 99.40329 , 99.38482 ],
#        dtype=float32),
#  99.38915325328708)

# %%
from utils import loss_val_graph

# Tampilkan grafik training vs validation
loss_val_graph(history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 from utils import loss_val_graph
#       3 # Tampilkan grafik training vs validation
# ----> 4 loss_val_graph(history)
#
# NameError: name 'history' is not defined
