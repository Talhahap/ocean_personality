# %%
import tensorflow as tf 
from tensorflow import keras 
import tensorflow_addons as tfa 
import pandas as pd
import numpy as np 
from models import load_scene_model, load_face_model, load_audio_model, load_text_glove_model
# Out:
# c:\Users\SIA\anaconda3\envs\deepface-env\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ### Load models

# %%
scene_model = load_scene_model()
face_model  = load_face_model()
audio_model = load_audio_model()
text_model  = load_text_glove_model()

# %% [markdown]
# ### Freeze layers

# %%
for layer in scene_model.layers:
    layer.trainable = False 
    layer._name = 'Scene_' + layer._name
scene_model.summary()
# Out:
# Model: "scene_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Scene_Input (InputLayer)       [(None, 10, 224, 22  0           []
#                                 4, 3)]
#
#  Scene_Rescaling (TimeDistribut  (None, 10, 224, 224  0          ['Scene_Input[0][0]']
#  ed)                            , 3)
#
#  Scene_time_distributed (TimeDi  (None, 10, 224, 224  0          ['Scene_Input[0][0]']
#  stributed)                     , 3)
#
#  Scene_vgg16 (TimeDistributed)  (None, 10, 512)      14714688    ['Scene_Rescaling[0][0]']
#
#  Scene_time_distributed_1 (Time  (None, 10, 768)     85798656    ['Scene_time_distributed[0][0]']
#  Distributed)
#
#  Scene_lstm (LSTM)              (None, 10, 128)      328192      ['Scene_vgg16[0][0]']
#
#  Scene_lstm_2 (LSTM)            (None, 10, 128)      459264      ['Scene_time_distributed_1[0][0]'
#                                                                  ]
#
#  Scene_lstm_1 (LSTM)            (None, 64)           49408       ['Scene_lstm[0][0]']
#
#  Scene_lstm_3 (LSTM)            (None, 64)           49408       ['Scene_lstm_2[0][0]']
#
#  Scene_dropout (Dropout)        (None, 64)           0           ['Scene_lstm_1[0][0]']
#
#  Scene_dropout_1 (Dropout)      (None, 64)           0           ['Scene_lstm_3[0][0]']
#
#  Scene_dense (Dense)            (None, 1024)         66560       ['Scene_dropout[0][0]']
#
#  Scene_dense_2 (Dense)          (None, 1024)         66560       ['Scene_dropout_1[0][0]']
#
#  Scene_dense_1 (Dense)          (None, 512)          524800      ['Scene_dense[0][0]']
#
#  Scene_dense_3 (Dense)          (None, 512)          524800      ['Scene_dense_2[0][0]']
#
#  Scene_average (Average)        (None, 512)          0           ['Scene_dense_1[0][0]',
#                                                                   'Scene_dense_3[0][0]']
#
#  Scene_dense_4 (Dense)          (None, 256)          131328      ['Scene_average[0][0]']
#
#  Scene_dropout_2 (Dropout)      (None, 256)          0           ['Scene_dense_4[0][0]']
#
#  Scene_dense_5 (Dense)          (None, 5)            1285        ['Scene_dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 102,714,949
# Trainable params: 0
# Non-trainable params: 102,714,949
# __________________________________________________________________________________________________

# %%
for layer in face_model.layers:
    layer.trainable = False 
    layer._name = 'Face_' + layer._name
face_model.summary()
# Out:
# Model: "face_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Face_Input (InputLayer)        [(None, 10, 224, 22  0           []
#                                 4, 3)]
#
#  Face_Rescaling (TimeDistribute  (None, 10, 224, 224  0          ['Face_Input[0][0]']
#  d)                             , 3)
#
#  Face_time_distributed_2 (TimeD  (None, 10, 224, 224  0          ['Face_Input[0][0]']
#  istributed)                    , 3)
#
#  Face_vgg16 (TimeDistributed)   (None, 10, 512)      14714688    ['Face_Rescaling[0][0]']
#
#  Face_time_distributed_3 (TimeD  (None, 10, 768)     85798656    ['Face_time_distributed_2[0][0]']
#  istributed)
#
#  Face_lstm_4 (LSTM)             (None, 10, 128)      328192      ['Face_vgg16[0][0]']
#
#  Face_lstm_6 (LSTM)             (None, 10, 128)      459264      ['Face_time_distributed_3[0][0]']
#
#  Face_lstm_5 (LSTM)             (None, 64)           49408       ['Face_lstm_4[0][0]']
#
#  Face_lstm_7 (LSTM)             (None, 64)           49408       ['Face_lstm_6[0][0]']
#
#  Face_dropout_3 (Dropout)       (None, 64)           0           ['Face_lstm_5[0][0]']
#
#  Face_dropout_4 (Dropout)       (None, 64)           0           ['Face_lstm_7[0][0]']
#
#  Face_dense_6 (Dense)           (None, 1024)         66560       ['Face_dropout_3[0][0]']
#
#  Face_dense_8 (Dense)           (None, 1024)         66560       ['Face_dropout_4[0][0]']
#
#  Face_dense_7 (Dense)           (None, 512)          524800      ['Face_dense_6[0][0]']
#
#  Face_dense_9 (Dense)           (None, 512)          524800      ['Face_dense_8[0][0]']
#
#  Face_average_1 (Average)       (None, 512)          0           ['Face_dense_7[0][0]',
#                                                                   'Face_dense_9[0][0]']
#
#  Face_dense_10 (Dense)          (None, 256)          131328      ['Face_average_1[0][0]']
#
#  Face_dropout_5 (Dropout)       (None, 256)          0           ['Face_dense_10[0][0]']
#
#  Face_dense_11 (Dense)          (None, 5)            1285        ['Face_dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 102,714,949
# Trainable params: 0
# Non-trainable params: 102,714,949
# __________________________________________________________________________________________________

# %%
for layer in audio_model.layers:
    layer.trainable = False
    layer._name = 'Audio_' + layer._name
audio_model.summary()
# Out:
# Model: "audio_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Audio_input_2 (InputLayer)  [(None, 15, 128)]         0
#
#  Audio_conv1d (Conv1D)       (None, 14, 32)            8224
#
#  Audio_dropout_6 (Dropout)   (None, 14, 32)            0
#
#  Audio_conv1d_1 (Conv1D)     (None, 13, 64)            4160
#
#  Audio_dropout_7 (Dropout)   (None, 13, 64)            0
#
#  Audio_lstm_8 (LSTM)         (None, 13, 512)           1181696
#
#  Audio_lstm_9 (LSTM)         (None, 256)               787456
#
#  Audio_dense_12 (Dense)      (None, 256)               65792
#
#  Audio_dropout_8 (Dropout)   (None, 256)               0
#
#  Audio_dense_13 (Dense)      (None, 5)                 1285
#
# =================================================================
# Total params: 2,048,613
# Trainable params: 0
# Non-trainable params: 2,048,613
# _________________________________________________________________

# %%
for layer in text_model.layers:
    layer.trainable = False 
    layer._name = 'Text_' + layer._name
text_model.summary()
# Out:
# Model: "text_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Text_input_3 (InputLayer)      [(None, 50)]         0           []
#
#  Text_embedding (Embedding)     (None, 50, 100)      8900        ['Text_input_3[0][0]']
#
#  Text_conv1d_2 (Conv1D)         (None, 48, 16)       4816        ['Text_embedding[0][0]']
#
#  Text_conv1d_4 (Conv1D)         (None, 48, 32)       9632        ['Text_embedding[0][0]']
#
#  Text_conv1d_3 (Conv1D)         (None, 46, 8)        392         ['Text_conv1d_2[0][0]']
#
#  Text_conv1d_5 (Conv1D)         (None, 46, 16)       1552        ['Text_conv1d_4[0][0]']
#
#  Text_flatten (Flatten)         (None, 368)          0           ['Text_conv1d_3[0][0]']
#
#  Text_flatten_1 (Flatten)       (None, 736)          0           ['Text_conv1d_5[0][0]']
#
#  Text_dense_14 (Dense)          (None, 50)           18450       ['Text_flatten[0][0]']
#
#  Text_dense_15 (Dense)          (None, 50)           36850       ['Text_flatten_1[0][0]']
#
#  Text_concatenate (Concatenate)  (None, 100)         0           ['Text_dense_14[0][0]',
#                                                                   'Text_dense_15[0][0]']
#
#  Text_dense_16 (Dense)          (None, 256)          25856       ['Text_concatenate[0][0]']
#
#  Text_dense_17 (Dense)          (None, 5)            1285        ['Text_dense_16[0][0]']
#
# ==================================================================================================
# Total params: 107,733
# Trainable params: 0
# Non-trainable params: 107,733
# __________________________________________________________________________________________________

# %% [markdown]
# ### Build model

# %%
scene_inputs = keras.layers.Input(shape=(10,224,224,3), name='Scene_input')
face_inputs  = keras.layers.Input(shape=(10,224,224,3), name='Face_input')
audio_inputs = keras.layers.Input(shape=(15,128), name='Audio_input')
text_inputs  = keras.layers.Input(shape=(50), name='Text_input')

x = scene_model.layers[-13].output
x = keras.layers.Dense(64, activation='relu')(x)
x = keras.layers.MultiHeadAttention(num_heads=2, key_dim=64)(x,x)
print('Scene shape:', x.shape)

y = face_model.layers[-13].output
y = keras.layers.Dense(64, activation='relu')(y)
y = keras.layers.MultiHeadAttention(num_heads=2,key_dim=64)(y,y)
print('Face shape:', y.shape)

z = audio_model.layers[-6].output
z = keras.layers.MultiHeadAttention(num_heads=2,key_dim=64)(z,z)
print('Audio shape:', z.shape)

w = text_model.layers[-8].output
w = keras.layers.Dense(64, activation='relu')(w)
w = keras.layers.MultiHeadAttention(num_heads=2,key_dim=64)(w,w)
print('Text shape:', w.shape)

o = keras.layers.Concatenate(axis=1)([x,y,z,w])

o = keras.layers.GlobalAveragePooling1D()(o)


o = keras.layers.Dense(128, activation='relu')(o)
o = keras.layers.Dropout(0.2)(o)
o = keras.layers.Dense(5, activation='sigmoid')(o)
# x.shape, y.shape, z.shape, w.shape, o.shape



atten_model = keras.models.Model(inputs=[scene_model.input, face_model.input, audio_model.input, text_model.input], outputs=o)
atten_model.compile(loss='mse', optimizer=tfa.optimizers.RectifiedAdam(), metrics=['mae'])


# keras.utils.plot_model(atten_model, show_shapes=True)
atten_model.summary()
# Out:
# Scene shape: (None, 10, 64)
# Face shape: (None, 10, 64)
# Audio shape: (None, 13, 64)
# Text shape: (None, 46, 64)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Scene_Input (InputLayer)       [(None, 10, 224, 22  0           []
#                                 4, 3)]
#
#  Face_Input (InputLayer)        [(None, 10, 224, 22  0           []
#                                 4, 3)]
#
#  Audio_input_2 (InputLayer)     [(None, 15, 128)]    0           []
#
#  Text_input_3 (InputLayer)      [(None, 50)]         0           []
#
#  Scene_time_distributed (TimeDi  (None, 10, 224, 224  0          ['Scene_Input[0][0]']
#  stributed)                     , 3)
#
#  Face_time_distributed_2 (TimeD  (None, 10, 224, 224  0          ['Face_Input[0][0]']
#  istributed)                    , 3)
#
#  Audio_conv1d (Conv1D)          (None, 14, 32)       8224        ['Audio_input_2[0][0]']
#
#  Text_embedding (Embedding)     (None, 50, 100)      8900        ['Text_input_3[0][0]']
#
#  Scene_time_distributed_1 (Time  (None, 10, 768)     85798656    ['Scene_time_distributed[0][0]']
#  Distributed)
#
#  Face_time_distributed_3 (TimeD  (None, 10, 768)     85798656    ['Face_time_distributed_2[0][0]']
#  istributed)
#
#  Audio_dropout_6 (Dropout)      (None, 14, 32)       0           ['Audio_conv1d[0][0]']
#
#  Text_conv1d_4 (Conv1D)         (None, 48, 32)       9632        ['Text_embedding[0][0]']
#
#  Scene_lstm_2 (LSTM)            (None, 10, 128)      459264      ['Scene_time_distributed_1[0][0]'
#                                                                  ]
#
#  Face_lstm_6 (LSTM)             (None, 10, 128)      459264      ['Face_time_distributed_3[0][0]']
#
#  Audio_conv1d_1 (Conv1D)        (None, 13, 64)       4160        ['Audio_dropout_6[0][0]']
#
#  Text_conv1d_5 (Conv1D)         (None, 46, 16)       1552        ['Text_conv1d_4[0][0]']
#
#  dense_18 (Dense)               (None, 10, 64)       8256        ['Scene_lstm_2[0][0]']
#
#  dense_19 (Dense)               (None, 10, 64)       8256        ['Face_lstm_6[0][0]']
#
#  Audio_dropout_7 (Dropout)      (None, 13, 64)       0           ['Audio_conv1d_1[0][0]']
#
#  dense_20 (Dense)               (None, 46, 64)       1088        ['Text_conv1d_5[0][0]']
#
#  multi_head_attention (MultiHea  (None, 10, 64)      33216       ['dense_18[0][0]',
#  dAttention)                                                      'dense_18[0][0]']
#
#  multi_head_attention_1 (MultiH  (None, 10, 64)      33216       ['dense_19[0][0]',
#  eadAttention)                                                    'dense_19[0][0]']
#
#  multi_head_attention_2 (MultiH  (None, 13, 64)      33216       ['Audio_dropout_7[0][0]',
#  eadAttention)                                                    'Audio_dropout_7[0][0]']
#
#  multi_head_attention_3 (MultiH  (None, 46, 64)      33216       ['dense_20[0][0]',
#  eadAttention)                                                    'dense_20[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 79, 64)       0           ['multi_head_attention[0][0]',
#                                                                   'multi_head_attention_1[0][0]',
#                                                                   'multi_head_attention_2[0][0]',
#                                                                   'multi_head_attention_3[0][0]']
#
#  global_average_pooling1d (Glob  (None, 64)          0           ['concatenate_1[0][0]']
#  alAveragePooling1D)
#
#  dense_21 (Dense)               (None, 128)          8320        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_9 (Dropout)            (None, 128)          0           ['dense_21[0][0]']
#
#  dense_22 (Dense)               (None, 5)            645         ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 172,707,737
# Trainable params: 159,429
# Non-trainable params: 172,548,308
# __________________________________________________________________________________________________

# %%
import datetime
t = datetime.datetime.now().strftime("%m%d_%H%M%S")

early_stopping = keras.callbacks.EarlyStopping(patience=10, verbose=0)
check_point    = keras.callbacks.ModelCheckpoint(filepath='./weights/self_attention/attention.t5',
                             monitor='val_mae',
                             mode='min',
                             save_best_only=True,
                             save_weights_only=True,
                             verbose=0)

# %% [markdown]
# ### Load data

# %%
AUTOTUNE = tf.data.AUTOTUNE

# Train
scene_train_ds = tf.data.experimental.load('./data/fullscene/train_ds/')
face_train_ds  = tf.data.experimental.load('./data/faces/train_ds/')
audio_train_ds = tf.data.experimental.load('./data/audio/train_ds/')
text_train_ds  = tf.data.experimental.load('./data/text/train_ds/').batch(batch_size=32)

scene_xtrain = scene_train_ds.map(lambda x,y: x)
face_xtrain  = face_train_ds.map(lambda x,y: x)
audio_xtrain = audio_train_ds.map(lambda x,y: x)
text__xtrain = text_train_ds.map(lambda x,y: x)
y_train      = scene_train_ds.map(lambda x,y: y)

train_ds = tf.data.Dataset.zip(((scene_xtrain, face_xtrain, audio_xtrain, text__xtrain), y_train)).shuffle(buffer_size=1000).prefetch(buffer_size=AUTOTUNE)


# Valid
scene_valid_ds = tf.data.experimental.load('./data/fullscene/val_ds/')
face_valid_ds  = tf.data.experimental.load('./data/faces/val_ds/')
audio_valid_ds = tf.data.experimental.load('./data/audio/val_ds') 
text_valid_ds  = tf.data.experimental.load('./data/text/val_ds/').batch(batch_size=32)

scene_xvalid = scene_valid_ds.map(lambda x,y: x)
face_xvalid  = face_valid_ds.map(lambda x,y: x)
audio_xvalid = audio_valid_ds.map(lambda x,y: x)
text_xvalid  = text_valid_ds.map(lambda x,y: x)
y_valid      = scene_valid_ds.map(lambda x,y: y)

valid_ds = tf.data.Dataset.zip(((scene_xvalid, face_xvalid, audio_xvalid, text_xvalid), y_valid)).shuffle(buffer_size=1000).prefetch(buffer_size=AUTOTUNE)

train_ds, valid_ds
# Out:
# WARNING:tensorflow:From C:\Users\SIA\AppData\Local\Temp\ipykernel_19940\259294993.py:4: load (from tensorflow.python.data.experimental.ops.io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.load(...)` instead.
# WARNING:tensorflow:From C:\Users\SIA\AppData\Local\Temp\ipykernel_19940\259294993.py:4: load (from tensorflow.python.data.experimental.ops.io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.load(...)` instead.
# (<_PrefetchDataset element_spec=((TensorSpec(shape=(None, 10, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 15, 128), dtype=tf.float32, name=None), TensorSpec(shape=(None, 50), dtype=tf.int32, name=None)), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=((TensorSpec(shape=(None, 10, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 15, 128), dtype=tf.float32, name=None), TensorSpec(shape=(None, 50), dtype=tf.int32, name=None)), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>)

# %% [markdown]
# ### Train model

# %%
history = atten_model.fit(train_ds, validation_data=valid_ds, batch_size=4, epochs=100, callbacks=[early_stopping, check_point], verbose=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 42s 42s/step - loss: 0.0328 - mae: 0.1687 - val_loss: 0.0136 - val_mae: 0.1107
# Epoch 2/100
# 1/1 [==============================] - 14s 14s/step - loss: 0.0329 - mae: 0.1696 - val_loss: 0.0136 - val_mae: 0.1107
# Epoch 3/100
# 1/1 [==============================] - 12s 12s/step - loss: 0.0324 - mae: 0.1683 - val_loss: 0.0136 - val_mae: 0.1107
# Epoch 4/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.0328 - mae: 0.1689 - val_loss: 0.0136 - val_mae: 0.1107
# Epoch 5/100
# 1/1 [==============================] - 25s 25s/step - loss: 0.0325 - mae: 0.1685 - val_loss: 0.0136 - val_mae: 0.1106
# Epoch 6/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.0331 - mae: 0.1699 - val_loss: 0.0135 - val_mae: 0.1104
# Epoch 7/100
# 1/1 [==============================] - 13s 13s/step - loss: 0.0324 - mae: 0.1675 - val_loss: 0.0134 - val_mae: 0.1100
# Epoch 8/100
# 1/1 [==============================] - 14s 14s/step - loss: 0.0326 - mae: 0.1685 - val_loss: 0.0133 - val_mae: 0.1096
# Epoch 9/100
# 1/1 [==============================] - 24s 24s/step - loss: 0.0326 - mae: 0.1683 - val_loss: 0.0132 - val_mae: 0.1092
# Epoch 10/100
# 1/1 [==============================] - 22s 22s/step - loss: 0.0323 - mae: 0.1673 - val_loss: 0.0131 - val_mae: 0.1087
# Epoch 11/100
# 1/1 [==============================] - 13s 13s/step - loss: 0.0319 - mae: 0.1669 - val_loss: 0.0130 - val_mae: 0.1082
# Epoch 12/100
# 1/1 [==============================] - 16s 16s/step - loss: 0.0318 - mae: 0.1668 - val_loss: 0.0128 - val_mae: 0.1077
# Epoch 13/100
# 1/1 [==============================] - 24s 24s/step - loss: 0.0311 - mae: 0.1644 - val_loss: 0.0127 - val_mae: 0.1071
# Epoch 14/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.0317 - mae: 0.1664 - val_loss: 0.0125 - val_mae: 0.1065
# Epoch 15/100
# 1/1 [==============================] - 13s 13s/step - loss: 0.0310 - mae: 0.1638 - val_loss: 0.0124 - val_mae: 0.1058
# Epoch 16/100
# 1/1 [==============================] - 25s 25s/step - loss: 0.0314 - mae: 0.1653 - val_loss: 0.0122 - val_mae: 0.1052
# Epoch 17/100
# 1/1 [==============================] - 26s 26s/step - loss: 0.0306 - mae: 0.1632 - val_loss: 0.0120 - val_mae: 0.1045
# Epoch 18/100
# 1/1 [==============================] - 14s 14s/step - loss: 0.0304 - mae: 0.1624 - val_loss: 0.0119 - val_mae: 0.1037
# Epoch 19/100
# 1/1 [==============================] - 28s 28s/step - loss: 0.0298 - mae: 0.1607 - val_loss: 0.0117 - val_mae: 0.1029
# Epoch 20/100
# 1/1 [==============================] - 28s 28s/step - loss: 0.0295 - mae: 0.1601 - val_loss: 0.0115 - val_mae: 0.1021
# Epoch 21/100
# 1/1 [==============================] - 15s 15s/step - loss: 0.0295 - mae: 0.1599 - val_loss: 0.0113 - val_mae: 0.1012
# Epoch 22/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.0291 - mae: 0.1585 - val_loss: 0.0111 - val_mae: 0.1004
# Epoch 23/100
# 1/1 [==============================] - 32s 32s/step - loss: 0.0290 - mae: 0.1584 - val_loss: 0.0109 - val_mae: 0.0995
# Epoch 24/100
# 1/1 [==============================] - 27s 27s/step - loss: 0.0284 - mae: 0.1570 - val_loss: 0.0107 - val_mae: 0.0986
# Epoch 25/100
# 1/1 [==============================] - 15s 15s/step - loss: 0.0288 - mae: 0.1576 - val_loss: 0.0105 - val_mae: 0.0977
# Epoch 26/100
# 1/1 [==============================] - 25s 25s/step - loss: 0.0284 - mae: 0.1575 - val_loss: 0.0103 - val_mae: 0.0968
# Epoch 27/100
# 1/1 [==============================] - 36s 36s/step - loss: 0.0275 - mae: 0.1546 - val_loss: 0.0101 - val_mae: 0.0958
# Epoch 28/100
# 1/1 [==============================] - 29s 29s/step - loss: 0.0272 - mae: 0.1537 - val_loss: 0.0099 - val_mae: 0.0948
# Epoch 29/100
# 1/1 [==============================] - 23s 23s/step - loss: 0.0264 - mae: 0.1513 - val_loss: 0.0097 - val_mae: 0.0938
# Epoch 30/100
# 1/1 [==============================] - 34s 34s/step - loss: 0.0265 - mae: 0.1515 - val_loss: 0.0094 - val_mae: 0.0927
# Epoch 31/100
# 1/1 [==============================] - 29s 29s/step - loss: 0.0259 - mae: 0.1497 - val_loss: 0.0092 - val_mae: 0.0915
# Epoch 32/100
# 1/1 [==============================] - 23s 23s/step - loss: 0.0268 - mae: 0.1525 - val_loss: 0.0090 - val_mae: 0.0904
# Epoch 33/100
# 1/1 [==============================] - 39s 39s/step - loss: 0.0254 - mae: 0.1482 - val_loss: 0.0088 - val_mae: 0.0891
# Epoch 34/100
# 1/1 [==============================] - 30s 30s/step - loss: 0.0257 - mae: 0.1487 - val_loss: 0.0085 - val_mae: 0.0878
# Epoch 35/100
# 1/1 [==============================] - 29s 29s/step - loss: 0.0247 - mae: 0.1463 - val_loss: 0.0083 - val_mae: 0.0864
# Epoch 36/100
# 1/1 [==============================] - 41s 41s/step - loss: 0.0249 - mae: 0.1475 - val_loss: 0.0080 - val_mae: 0.0850
# Epoch 37/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.0237 - mae: 0.1430 - val_loss: 0.0078 - val_mae: 0.0835
# Epoch 38/100
# 1/1 [==============================] - 23s 23s/step - loss: 0.0230 - mae: 0.1405 - val_loss: 0.0075 - val_mae: 0.0819
# Epoch 39/100
# 1/1 [==============================] - 37s 37s/step - loss: 0.0229 - mae: 0.1411 - val_loss: 0.0073 - val_mae: 0.0802
# Epoch 40/100
# 1/1 [==============================] - 22s 22s/step - loss: 0.0214 - mae: 0.1349 - val_loss: 0.0070 - val_mae: 0.0785
# Epoch 41/100
# 1/1 [==============================] - 28s 28s/step - loss: 0.0210 - mae: 0.1332 - val_loss: 0.0067 - val_mae: 0.0766
# Epoch 42/100
# 1/1 [==============================] - 32s 32s/step - loss: 0.0227 - mae: 0.1394 - val_loss: 0.0064 - val_mae: 0.0747
# Epoch 43/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.0219 - mae: 0.1361 - val_loss: 0.0061 - val_mae: 0.0727
# Epoch 44/100
# 1/1 [==============================] - 21s 21s/step - loss: 0.0194 - mae: 0.1284 - val_loss: 0.0058 - val_mae: 0.0707
# Epoch 45/100
# 1/1 [==============================] - 28s 28s/step - loss: 0.0183 - mae: 0.1235 - val_loss: 0.0056 - val_mae: 0.0685
# Epoch 46/100
# 1/1 [==============================] - 32s 32s/step - loss: 0.0191 - mae: 0.1272 - val_loss: 0.0053 - val_mae: 0.0662
# Epoch 47/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.0175 - mae: 0.1221 - val_loss: 0.0050 - val_mae: 0.0639
# Epoch 48/100
# 1/1 [==============================] - 27s 27s/step - loss: 0.0172 - mae: 0.1180 - val_loss: 0.0047 - val_mae: 0.0614
# Epoch 49/100
# 1/1 [==============================] - 35s 35s/step - loss: 0.0177 - mae: 0.1221 - val_loss: 0.0044 - val_mae: 0.0588
# Epoch 50/100
# 1/1 [==============================] - 25s 25s/step - loss: 0.0175 - mae: 0.1202 - val_loss: 0.0041 - val_mae: 0.0561
# Epoch 51/100
# 1/1 [==============================] - 33s 33s/step - loss: 0.0173 - mae: 0.1184 - val_loss: 0.0039 - val_mae: 0.0535
# Epoch 52/100
# 1/1 [==============================] - 53s 53s/step - loss: 0.0162 - mae: 0.1128 - val_loss: 0.0036 - val_mae: 0.0523
# Epoch 53/100
# 1/1 [==============================] - 46s 46s/step - loss: 0.0156 - mae: 0.1120 - val_loss: 0.0033 - val_mae: 0.0511
# Epoch 54/100
# 1/1 [==============================] - 34s 34s/step - loss: 0.0140 - mae: 0.1045 - val_loss: 0.0031 - val_mae: 0.0497
# Epoch 55/100
# 1/1 [==============================] - 34s 34s/step - loss: 0.0131 - mae: 0.1000 - val_loss: 0.0029 - val_mae: 0.0483
# Epoch 56/100
# 1/1 [==============================] - 35s 35s/step - loss: 0.0138 - mae: 0.1044 - val_loss: 0.0026 - val_mae: 0.0467
# Epoch 57/100
# 1/1 [==============================] - 35s 35s/step - loss: 0.0105 - mae: 0.0870 - val_loss: 0.0024 - val_mae: 0.0451
# Epoch 58/100
# 1/1 [==============================] - 35s 35s/step - loss: 0.0139 - mae: 0.1017 - val_loss: 0.0022 - val_mae: 0.0434
# Epoch 59/100
# 1/1 [==============================] - 33s 33s/step - loss: 0.0128 - mae: 0.0964 - val_loss: 0.0021 - val_mae: 0.0417
# Epoch 60/100
# 1/1 [==============================] - 22s 22s/step - loss: 0.0088 - mae: 0.0795 - val_loss: 0.0019 - val_mae: 0.0399
# Epoch 61/100
# 1/1 [==============================] - 30s 30s/step - loss: 0.0105 - mae: 0.0853 - val_loss: 0.0018 - val_mae: 0.0380
# Epoch 62/100
# 1/1 [==============================] - 40s 40s/step - loss: 0.0090 - mae: 0.0733 - val_loss: 0.0017 - val_mae: 0.0361
# Epoch 63/100
# 1/1 [==============================] - 34s 34s/step - loss: 0.0077 - mae: 0.0666 - val_loss: 0.0017 - val_mae: 0.0341
# Epoch 64/100
# 1/1 [==============================] - 36s 36s/step - loss: 0.0079 - mae: 0.0707 - val_loss: 0.0017 - val_mae: 0.0331
# Epoch 65/100
# 1/1 [==============================] - 35s 35s/step - loss: 0.0063 - mae: 0.0611 - val_loss: 0.0017 - val_mae: 0.0329
# Epoch 66/100
# 1/1 [==============================] - 34s 34s/step - loss: 0.0081 - mae: 0.0648 - val_loss: 0.0017 - val_mae: 0.0327
# Epoch 67/100
# 1/1 [==============================] - 35s 35s/step - loss: 0.0065 - mae: 0.0572 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 68/100
# 1/1 [==============================] - 31s 31s/step - loss: 0.0065 - mae: 0.0622 - val_loss: 0.0019 - val_mae: 0.0326
# Epoch 69/100
# 1/1 [==============================] - 31s 31s/step - loss: 0.0046 - mae: 0.0487 - val_loss: 0.0021 - val_mae: 0.0339
# Epoch 70/100
# 1/1 [==============================] - 37s 37s/step - loss: 0.0062 - mae: 0.0568 - val_loss: 0.0022 - val_mae: 0.0351
# Epoch 71/100
# 1/1 [==============================] - 29s 29s/step - loss: 0.0062 - mae: 0.0593 - val_loss: 0.0024 - val_mae: 0.0361
# Epoch 72/100
# 1/1 [==============================] - 28s 28s/step - loss: 0.0040 - mae: 0.0488 - val_loss: 0.0026 - val_mae: 0.0371
# Epoch 73/100
# 1/1 [==============================] - 34s 34s/step - loss: 0.0052 - mae: 0.0555 - val_loss: 0.0028 - val_mae: 0.0390
# Epoch 74/100
# 1/1 [==============================] - 25s 25s/step - loss: 0.0056 - mae: 0.0600 - val_loss: 0.0030 - val_mae: 0.0410

# %% [markdown]
# ### Load weights

# %%
atten_model.load_weights('./weights/self_attention/attention.t5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Validation data

# %%
AUTOTUNE = tf.data.AUTOTUNE
scene_valid_ds = tf.data.experimental.load('./data/fullscene/val_ds/')
face_valid_ds  = tf.data.experimental.load('./data/faces/val_ds/')
audio_valid_ds = tf.data.experimental.load('./data/audio/val_ds') 
text_valid_ds  = tf.data.experimental.load('./data/text/val_ds/').batch(batch_size=32)

scene_xvalid = scene_valid_ds.map(lambda x,y: x)
face_xvalid  = face_valid_ds.map(lambda x,y: x)
audio_xvalid = audio_valid_ds.map(lambda x,y: x)
text_xvalid  = text_valid_ds.map(lambda x,y: x)
y_valid      = scene_valid_ds.map(lambda x,y: y)

valid_ds = tf.data.Dataset.zip(((scene_xvalid, face_xvalid, audio_xvalid, text_xvalid), y_valid)).prefetch(buffer_size=AUTOTUNE)

# %%
from sklearn.metrics import mean_absolute_error 

y_true = np.concatenate([y for x,y in valid_ds], axis=0)
y_pred = atten_model.predict(valid_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 1/1 [==============================] - 9s 9s/step
# (array([95.417305, 99.69521 , 98.47027 , 92.02346 , 98.207695],
#        dtype=float32),
#  96.76278717815876)

# %% [markdown]
# ### Test data

# %%
scene_test_ds = tf.data.experimental.load('./data/fullscene/test_ds/')
face_test_ds  = tf.data.experimental.load('./data/faces/test_ds/')
audio_test_ds = tf.data.experimental.load('./data/audio/test_ds') 
text_test_ds  = tf.data.experimental.load('./data/text/test_ds/').batch(batch_size=32)


scene_xtest = scene_test_ds.map(lambda x,y: x)
face_xtest  = face_test_ds.map(lambda x,y: x)
audio_xtest = audio_test_ds.map(lambda x,y: x)
text_xtest  = text_test_ds.map(lambda x,y: x)

y_test      = scene_test_ds.map(lambda x,y: y)

test_ds = tf.data.Dataset.zip(((scene_xtest, face_xtest, audio_xtest, text_xtest), y_test)).prefetch(buffer_size=AUTOTUNE)

test_ds
# Out:
# <_PrefetchDataset element_spec=((TensorSpec(shape=(None, 10, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 15, 128), dtype=tf.float32, name=None), TensorSpec(shape=(None, 50), dtype=tf.int32, name=None)), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>

# %%
y_true = np.concatenate([y for x,y in test_ds], axis=0)
y_pred = atten_model.predict(test_ds)

mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
(1-mae)*100, (1-np.mean(mae))*100
# Out:
# 1/1 [==============================] - 4s 4s/step
# (array([88.9684  , 87.04037 , 95.321785, 95.74899 , 88.99976 ],
#        dtype=float32),
#  91.21586307883263)

# %%
import pickle
with open('./histories/attention_conc.pkl', 'wb') as f:
    pickle.dump(history.history, f)
